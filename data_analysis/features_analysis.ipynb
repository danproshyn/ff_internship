# %% [markdown]
# # Feature analysis

# %%
import pandas as pd

from utils import plot_categorical_cols_distribution, read_df_dtype

# %%
pd.set_option('display.float_format', '{:.3f}'.format)
pd.set_option('display.max_columns', None)

# %% [markdown]
# ## Initialize dataframe

# %%
DF_PATH = '../data/features/features_auto_v5_raw.csv'
DF_DTYPE_PATH = '../data/features/features_auto_v5_raw_dtype.json'

# %%
df_dtype, df_date_cols = read_df_dtype(DF_DTYPE_PATH)
df = pd.read_csv(DF_PATH, dtype=df_dtype, parse_dates=df_date_cols)

# %% [markdown]
# ## Categorical data

# %% [markdown]
# ### Transactions

# %%
tx_cat_cols = ['MODE(transactions.cat_c2)', 'MODE(transactions.cat_c3)', 'MODE(transactions.cat_c4)']
plot_categorical_cols_distribution(df, tx_cat_cols)

# %% [markdown]
# ### Activities

# %%
act_cat_cols = ['MODE(activities.cat_c3)', 'MODE(activities.cat_c4)', 'MODE(activities.cat_c5)', 'MODE(activities.cat_c6)', 'MODE(activities.cat_c9)']
plot_categorical_cols_distribution(df, act_cat_cols)

# %% [markdown]
# ### Communications

# %%
comm_cat_cols = ['MODE(comms.cat_c2)', 'MODE(comms.cat_c3)', 'MODE(comms.cat_c4)', 'MODE(comms.cat_c5)']
plot_categorical_cols_distribution(df, comm_cat_cols)
