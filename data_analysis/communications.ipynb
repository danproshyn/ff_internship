# %% [markdown]
# # Communications

# %% [markdown]
# ## Initialization

# %%
import pandas as pd

pd.set_option('display.float_format', '{:.3f}'.format)

# %%
from utils import read_communications

df = read_communications('../data/samples/COMMUNICATIONS_SAMPLE.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 978647 entries, 0 to 978646
# Data columns (total 6 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   client_id     978647 non-null  uint64
#  1   contact_date  978647 non-null  datetime64[ns]
#  2   cat_c2        978647 non-null  category
#  3   cat_c3        978647 non-null  int32
#  4   cat_c4        978647 non-null  int32
#  5   cat_c5        978647 non-null  category
# dtypes: category(2), datetime64[ns](1), int32(2), uint64(1)
# memory usage: 25.2 MB

# %%
# Preprocess
from utils import preprocess_comm_data

df = preprocess_comm_data(df)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 978647 entries, 0 to 978646
# Data columns (total 6 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   client_id     978647 non-null  uint64
#  1   contact_date  978647 non-null  datetime64[ns]
#  2   cat_c2        978647 non-null  category
#  3   cat_c3        978647 non-null  int32
#  4   cat_c4        978647 non-null  int32
#  5   cat_c5        978647 non-null  category
# dtypes: category(2), datetime64[ns](1), int32(2), uint64(1)
# memory usage: 25.2 MB

# %%
df.head()
# Out:
#           client_id contact_date cat_c2  cat_c3  cat_c4 cat_c5
# 0  4130085634078954   2025-08-21  S3736       4       1      4
# 1  4130085634078954   2025-08-21  S3564       4       1      4
# 2  4130085634078954   2025-08-21  S3565       4       1      4
# 3  4130085634078954   2025-08-21  S3564       4       1      4
# 4  4130085634078954   2025-08-21  S3677       4       1      4

# %%
df.describe()
# Out:
#                      client_id                   contact_date     cat_c3  \
# count               978647.000                         978647 978647.000
# mean   9450110126815272960.000  2025-04-19 04:28:48.549722368      4.020
# min       4130085634078954.000            2024-12-01 00:00:00      1.000
# 25%    5043164002605022208.000            2025-03-05 00:00:00      4.000
# 50%    9798487912828250112.000            2025-04-22 00:00:00      4.000
# 75%   13847707596200960000.000            2025-06-04 00:00:00      4.000
# max   18440239832994052096.000            2025-08-31 00:00:00      8.000
# std    5227965673660423168.000                            NaN      0.414
#
#           cat_c4
# count 978647.000
# mean       1.094
# min        1.000
# 25%        1.000
# 50%        1.000
# 75%        1.000
# max        3.000
# std        0.322

# %%
print('Mean of communications by client:')
df.groupby('client_id').size().mean()
# Out:
# Mean of communications by client:
# np.float64(544.6004451864218)

# %% [markdown]
# ## Categorical data

# %%
cat_cols = ['cat_c2', 'cat_c3', 'cat_c4', 'cat_c5']

# %%
# Plots
from utils import plot_categorical_cols_distribution

plot_categorical_cols_distribution(df, cat_cols)

# %%
# Counts
for col in cat_cols:
    print(df[col].value_counts().sort_index())
# Out:
# cat_c2
# B10355    5
# B11321    5
# B11324    7
# B11667    6
# B11774    6
#          ..
# S7477     1
# S8034     2
# M10105    2
# M11733    3
# M18168    1
# Name: count, Length: 804, dtype: int64
# cat_c3
# 1       437
# 2        28
# 3     23660
# 4    940043
# 5         1
# 6         2
# 7     13020
# 8      1456
# Name: count, dtype: int64
# cat_c4
# 1    895392
# 2     74281
# 3      8974
# Name: count, dtype: int64
# cat_c5
# 0        2292
# 11          8
# 4      935915
# 6        6771
# 7       25720
# 8        2549
# 9          62
# BR         10
# CG        434
# DD        192
# DL       1446
# F1        283
# F11        57
# F12         9
# F14        13
# F16        42
# F18         6
# F19         7
# F2         26
# F20         3
# F21         3
# F29         1
# F38         1
# F4         40
# F5         65
# F6          5
# F8         16
# G17         2
# LE        624
# SSB      1344
# SSQ        68
# UC        541
# 5          25
# F47         2
# ...
