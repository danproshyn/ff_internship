# %%
import pandas as pd
import numpy as np

from utils import fill_feature_nan_values, get_series_first_mode_or_nan

# %% [markdown]
# # Transactions

# %%
from utils import read_transactions

TRANSACTIONS_PATH = 'data/initial/TRANSACTIONS.csv'
# TRANSACTIONS_PATH = 'data/samples/TRANSACTIONS_SAMPLE.csv'

transactions = read_transactions(TRANSACTIONS_PATH)
transactions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15654626 entries, 0 to 15654625
# Data columns (total 21 columns):
#  #   Column     Dtype
# ---  ------     -----
#  0   client_id  uint64
#  1   tran_date  datetime64[ns]
#  2   cat_c2     int32
#  3   cat_c3     int32
#  4   cat_c4     int32
#  5   fl_c6      int8
#  6   fl_c7      int8
#  7   fl_c8      int8
#  8   fl_c9      int8
#  9   fl_c10     int8
#  10  fl_c11     int8
#  11  fl_c12     int8
#  12  fl_c13     int8
#  13  fl_c14     int8
#  14  fl_c15     int8
#  15  float_c16  float32
#  16  float_c17  float32
#  17  float_c18  float32
#  18  int_c19    int32
#  19  float_c20  float32
#  20  float_c21  float32
# dtypes: datetime64[ns](1), float32(5), int32(4), int8(10), uint64(1)
# memory usage: 925.6 MB

# %%
# Date variables

tx_agg_dates = transactions.groupby('client_id').agg(
    tx_count=('tran_date', 'count'),
    tx_days=('tran_date', 'nunique'),
    first_tx_date=('tran_date', 'min'),
    last_tx_date=('tran_date', 'max'),
).reset_index()

tx_agg_dates['tx_avg_per_day'] = tx_agg_dates['tx_count'] / tx_agg_dates['tx_days']
tx_agg_dates['tx_period_days'] = (tx_agg_dates['last_tx_date'] - tx_agg_dates['first_tx_date']).dt.days

reference_date = transactions['tran_date'].max()
tx_agg_dates['days_since_last_tx'] = (reference_date - tx_agg_dates['last_tx_date']).dt.days

# Replace dates with days from starting point
min_date = transactions['tran_date'].min()
tx_agg_dates['first_tx_day'] = (tx_agg_dates['first_tx_date'] - min_date).dt.days
tx_agg_dates['last_tx_day'] = (tx_agg_dates['last_tx_date'] - min_date).dt.days
tx_agg_dates = tx_agg_dates.drop(columns=['first_tx_date', 'last_tx_date'])

# %%
# Numerical variables

num_cols = ['float_c16', 'float_c17', 'float_c18', 'int_c19', 'float_c20', 'float_c21']

tx_agg_nums = transactions.groupby('client_id')[num_cols].agg(['mean', 'std', 'min', 'max', 'sum'])
tx_agg_nums.columns = ['tx_' + '_'.join(col) for col in tx_agg_nums.columns]
tx_agg_nums = tx_agg_nums.reset_index()

# Handle NULL-values in "_std" columns
std_cols = [c for c in tx_agg_nums.columns if c.endswith('_std')]
tx_agg_nums['has_single_tx'] = tx_agg_nums[std_cols].isna().any(axis=1).astype('int8')
tx_agg_nums[std_cols] = tx_agg_nums[std_cols].fillna(0.0)

# %%
# Flag variables

flag_cols = [col for col in transactions.columns if col.startswith('fl_')]

tx_agg_flags = transactions.groupby('client_id')[flag_cols].mean()
tx_agg_flags.columns = [f'tx_{c}_ratio' for c in flag_cols]
tx_agg_flags = tx_agg_flags.reset_index()

# %%
# Categorical variables

cat_cols = ['cat_c2', 'cat_c3', 'cat_c4']
aggregates = {f'tx_{col}_nunique': (col, 'nunique') for col in cat_cols}
aggregates |= {f'tx_{col}_mode': (col, get_series_first_mode_or_nan) for col in cat_cols}

tx_agg_cat = transactions.groupby('client_id').agg(**aggregates).reset_index()

# %%
# Merge all features

tx_features = (
    tx_agg_dates
    .merge(tx_agg_nums, on='client_id', how='left')
    .merge(tx_agg_flags, on='client_id', how='left')
    .merge(tx_agg_cat, on='client_id', how='left')
)
tx_features.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35070 entries, 0 to 35069
# Data columns (total 55 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   client_id           35070 non-null  uint64
#  1   tx_count            35070 non-null  int64
#  2   tx_days             35070 non-null  int64
#  3   tx_avg_per_day      35070 non-null  float64
#  4   tx_period_days      35070 non-null  int64
#  5   days_since_last_tx  35070 non-null  int64
#  6   first_tx_day        35070 non-null  int64
#  7   last_tx_day         35070 non-null  int64
#  8   tx_float_c16_mean   35070 non-null  float32
#  9   tx_float_c16_std    35070 non-null  float32
#  10  tx_float_c16_min    35070 non-null  float32
#  11  tx_float_c16_max    35070 non-null  float32
#  12  tx_float_c16_sum    35070 non-null  float32
#  13  tx_float_c17_mean   35070 non-null  float32
#  14  tx_float_c17_std    35070 non-null  float32
#  15  tx_float_c17_min    35070 non-null  float32
#  16  tx_float_c17_max    35070 non-null  float32
#  17  tx_float_c17_sum    35070 non-null  float32
#  18  tx_float_c18_mean   35070 non-null  float32
#  19  tx_float_c18_std    35070 non-null  float32
#  20  tx_float_c18_min    35070 non-null  float32
#  21  tx_float_c18_max    35070 non-null  float32
#  22  tx_float_c18_sum    35070 non-null  float32
#  23  tx_int_c19_mean     35070 non-null  float64
#  24  tx_int_c19_std      35070 non-null  float64
#  25  tx_int_c19_min      35070 non-null  int32
#  26  tx_int_c19_max      35070 non-null  int32
#  27  tx_int_c19_sum      35070 non-null  int32
#  28  tx_float_c20_mean   35070 non-null  float32
#  29  tx_float_c20_std    35070 non-null  float32
#  30  tx_float_c20_min    35070 non-null  float32
#  31  tx_float_c20_max    35070 non-null  float32
#  32  tx_float_c20_sum    35070 non-null  float32
#  33  tx_float_c21_mean   35070 non-null  float32
#  34  tx_float_c21_std    35070 non-null  float32
#  35  tx_float_c21_min    35070 non-null  float32
#  36  tx_float_c21_max    35070 non-null  float32
#  37  tx_float_c21_sum    35070 non-null  float32
#  38  has_single_tx       35070 non-null  int8
#  39  tx_fl_c6_ratio      35070 non-null  float64
#  40  tx_fl_c7_ratio      35070 non-null  float64
#  41  tx_fl_c8_ratio      35070 non-null  float64
#  42  tx_fl_c9_ratio      35070 non-null  float64
#  43  tx_fl_c10_ratio     35070 non-null  float64
#  44  tx_fl_c11_ratio     35070 non-null  float64
#  45  tx_fl_c12_ratio     35070 non-null  float64
#  46  tx_fl_c13_ratio     35070 non-null  float64
#  47  tx_fl_c14_ratio     35070 non-null  float64
#  48  tx_fl_c15_ratio     35070 non-null  float64
#  49  tx_cat_c2_nunique   35070 non-null  int64
#  50  tx_cat_c3_nunique   35070 non-null  int64
#  51  tx_cat_c4_nunique   35070 non-null  int64
#  52  tx_cat_c2_mode      35070 non-null  int32
#  53  tx_cat_c3_mode      35070 non-null  int32
#  54  tx_cat_c4_mode      35070 non-null  int32
# dtypes: float32(25), float64(13), int32(6), int64(9), int8(1), uint64(1)
# memory usage: 10.3 MB

# %% [markdown]
# # App activity

# %%
from utils import preprocess_app_activity_data, read_app_activity

ACTIVITY_PATH = 'data/initial/APP_ACTIVITY.csv'
# ACTIVITY_PATH = 'data/samples/APP_ACTIVITY_SAMPLE.csv'

activities = read_app_activity(ACTIVITY_PATH)
# activities = preprocess_app_activity_data(activities)
activities.info(show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17738592 entries, 0 to 17738591
# Data columns (total 17 columns):
#  #   Column         Non-Null Count     Dtype
# ---  ------         --------------     -----
#  0   client_id      17738592 non-null  uint64
#  1   device_id      17738592 non-null  uint64
#  2   activity_date  17738592 non-null  datetime64[ns]
#  3   cat_c3         17734699 non-null  Int32
#  4   cat_c4         17600200 non-null  Int32
#  5   cat_c5         17738445 non-null  Int32
#  6   cat_c6         17738592 non-null  Int32
#  7   cat_c8         17673411 non-null  Int8
#  8   cat_c9         17693001 non-null  Int32
#  9   cat_c10        17695745 non-null  Int8
#  10  float_c11      17695744 non-null  float32
#  11  float_c12      17695744 non-null  float32
#  12  float_c13      3741017 non-null   float32
#  13  float_c14      17695744 non-null  float32
#  14  float_c15      10185047 non-null  float32
#  15  float_c16      10185047 non-null  float32
#  16  float_c17      10185047 non-null  float32
# dtypes: Int32(5), Int8(2), datetime64[ns](1), float32(7), uint64(2)
# memory usage: 1.3 GB

# %%
# Date variables

activities_agg_dates = activities.groupby('client_id').agg(
    activity_count=('activity_date', 'count'),
    activity_days=('activity_date', 'nunique'),
    first_activity_date=('activity_date', 'min'),
    last_activity_date=('activity_date', 'max'),
).reset_index()

activities_agg_dates['activity_avg_per_day'] = activities_agg_dates['activity_count'] / activities_agg_dates['activity_days']
activities_agg_dates['activity_period_days'] = (activities_agg_dates['last_activity_date'] - activities_agg_dates['first_activity_date']).dt.days

max_date = activities['activity_date'].max()
activities_agg_dates['days_since_last_activity'] = (max_date - activities_agg_dates['last_activity_date']).dt.days

# Replace dates with days from starting point
min_date = activities['activity_date'].min()
activities_agg_dates['first_activity_day'] = (activities_agg_dates['first_activity_date'] - min_date).dt.days
activities_agg_dates['last_activity_day'] = (activities_agg_dates['last_activity_date'] - min_date).dt.days
activities_agg_dates = activities_agg_dates.drop(columns=['first_activity_date', 'last_activity_date'])
activities_agg_dates.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35672 entries, 0 to 35671
# Data columns (total 8 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   client_id                 35672 non-null  uint64
#  1   activity_count            35672 non-null  int64
#  2   activity_days             35672 non-null  int64
#  3   activity_avg_per_day      35672 non-null  float64
#  4   activity_period_days      35672 non-null  int64
#  5   days_since_last_activity  35672 non-null  int64
#  6   first_activity_day        35672 non-null  int64
#  7   last_activity_day         35672 non-null  int64
# dtypes: float64(1), int64(6), uint64(1)
# memory usage: 2.2 MB

# %%
# Numerical variables

# num_cols = ['float_c11', 'float_c12', 'float_c14']
num_cols = ['float_c11', 'float_c12', 'float_c13', 'float_c14', 'float_c15', 'float_c16', 'float_c17']

activity_agg_nums = activities.groupby('client_id')[num_cols].agg(['mean', 'std', 'min', 'max', 'sum'])
activity_agg_nums.columns = ['activity_' + '_'.join(col) for col in activity_agg_nums.columns]
activity_agg_nums = activity_agg_nums.reset_index()

# Handle NULL-values in "_std" columns
std_cols = [c for c in activity_agg_nums.columns if c.endswith('_std')]
activity_agg_nums['has_single_activity'] = activity_agg_nums[std_cols].isna().any(axis=1).astype('int8')
activity_agg_nums[std_cols] = activity_agg_nums[std_cols].fillna(0.0)
activity_agg_nums.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35672 entries, 0 to 35671
# Data columns (total 37 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   client_id                35672 non-null  uint64
#  1   activity_float_c11_mean  35672 non-null  float32
#  2   activity_float_c11_std   35672 non-null  float32
#  3   activity_float_c11_min   35672 non-null  float32
#  4   activity_float_c11_max   35672 non-null  float32
#  5   activity_float_c11_sum   35672 non-null  float32
#  6   activity_float_c12_mean  35672 non-null  float32
#  7   activity_float_c12_std   35672 non-null  float32
#  8   activity_float_c12_min   35672 non-null  float32
#  9   activity_float_c12_max   35672 non-null  float32
#  10  activity_float_c12_sum   35672 non-null  float32
#  11  activity_float_c13_mean  35333 non-null  float32
#  12  activity_float_c13_std   35672 non-null  float32
#  13  activity_float_c13_min   35333 non-null  float32
#  14  activity_float_c13_max   35333 non-null  float32
#  15  activity_float_c13_sum   35672 non-null  float32
#  16  activity_float_c14_mean  35672 non-null  float32
#  17  activity_float_c14_std   35672 non-null  float32
#  18  activity_float_c14_min   35672 non-null  float32
#  19  activity_float_c14_max   35672 non-null  float32
#  20  activity_float_c14_sum   35672 non-null  float32
#  21  activity_float_c15_mean  22443 non-null  float32
#  22  activity_float_c15_std   35672 non-null  float32
#  23  activity_float_c15_min   22443 non-null  float32
#  24  activity_float_c15_max   22443 non-null  float32
#  25  activity_float_c15_sum   35672 non-null  float32
#  26  activity_float_c16_mean  22443 non-null  float32
#  27  activity_float_c16_std   35672 non-null  float32
#  28  activity_float_c16_min   22443 non-null  float32
#  29  activity_float_c16_max   22443 non-null  float32
#  30  activity_float_c16_sum   35672 non-null  float32
#  31  activity_float_c17_mean  22443 non-null  float32
#  32  activity_float_c17_std   35672 non-null  float32
#  33  activity_float_c17_min   22443 non-null  float32
#  34  activity_float_c17_max   22443 non-null  float32
#  35  activity_float_c17_sum   35672 non-null  float32
#  36  has_single_activity      35672 non-null  int8
# dtypes: float32(35), int8(1), uint64(1)
# memory usage: 5.1 MB

# %%
activity_agg_nums.describe()
# Out:
#           client_id  activity_float_c11_mean  activity_float_c11_std  \
# count  3.567200e+04             35672.000000            35672.000000
# mean   9.232191e+18                37.792583                6.649549
# std    5.313957e+18                26.735794                7.348373
# min    8.446579e+14                 0.000000                0.000000
# 25%    4.667330e+18                11.492629                2.074277
# 50%    9.215637e+18                36.564026                3.888989
# 75%    1.380215e+19                61.288026                7.910980
# max    1.844580e+19                95.963638               44.761478
#
#        activity_float_c11_min  activity_float_c11_max  activity_float_c11_sum  \
# count            35672.000000            35672.000000            35672.000000
# mean                25.837099               51.359524            19137.029297
# std                 26.914335               28.174850            27379.166016
# min                 -1.000000                0.000000                0.000000
# 25%                  1.000000               25.000000             2477.000000
# 50%                 17.000000               54.000000             9491.000000
# 75%                 49.000000               77.000000            25288.000000
# max                 95.000000               99.000000           643924.000000
#
#        activity_float_c12_mean  activity_float_c12_std  \
# count             35672.000000            35672.000000
# mean                 56.773373               22.270895
# std                  12.244381                4.382798
# min                   3.750000                0.000000
# 25%                  48.328691               20.067261
# 50%                  56.526180               22.837740
# 75%                  65.051586               25.075394
# max                 100.000000               46.475800
#
#        activity_float_c12_min  activity_float_c12_max  ...  \
# count            35672.000000            35672.000000  ...
# mean                 9.567280               98.224907  ...
# std                 11.761169                6.320566  ...
# min                  0.000000                5.000000  ...
# 25%                  1.000000              100.000000  ...
# 50%                  5.000000              100.000000  ...
# 75%                 13.000000              100.000000  ...
# max                100.000000              100.000000  ...
#
#        activity_float_c16_std  activity_float_c16_min  activity_float_c16_max  \
# count            35672.000000            22443.000000            22443.000000
# mean                 1.603135               -4.834176               10.086658
# std                  1.347729                6.009652                1.800422
# min                  0.000000              -78.443626               -1.762050
# 25%                  0.000000               -9.641515                9.660389
# 50%                  2.093808               -2.470816                9.888053
# 75%                  2.639877               -0.276521               10.280882
# max                  8.857243                9.806650               78.482330
#
#        activity_float_c16_sum  activity_float_c17_mean  \
# count            35672.000000             22443.000000
# mean              1512.785034                 6.677791
# std               2434.085693                 1.266891
# min               -112.512207                -8.073355
# 25%                  0.000000                 6.064535
# 50%                549.505219                 6.852714
# 75%               2153.651245                 7.492867
# max              53059.531250                13.493124
#
#        activity_float_c17_std  activity_float_c17_min  activity_float_c17_max  \
# count            35672.000000            22443.000000            22443.000000
# mean                 1.975121               -5.643444               13.107902
# std                  1.700666                4.516261                3.933831
# min                  0.000000              -83.054871               -5.050950
# 25%                  0.000000               -8.419050               10.776841
# 50%                  2.416202               -5.881199               12.430051
# 75%                  3.345726               -3.681670               14.472475
# max                 12.401772               13.467001              102.414375
#
#        activity_float_c17_sum  has_single_activity
# count            35672.000000         35672.000000
# mean              1910.251221             0.386325
# std               2992.792236             0.486913
# min              -1766.154663             0.000000
# 25%                  0.000000             0.000000
# 50%                666.816437             0.000000
# 75%               2782.461609             1.000000
# max              51292.566406             1.000000
#
# [8 rows x 37 columns]

# %%
# Postprocess numerical features (replace NULL-values with medians)
for initial_col in ('float_c13', 'float_c15', 'float_c16', 'float_c17'):
    # feature_cols = [col for col in activity_agg_nums.columns if initial_col in col]
    # feature_cols_medians = [activity_agg_nums[col].median() for col in feature_cols]
    # rows_with_nulls = activity_agg_nums[activity_agg_nums[feature_cols].isna().any(axis=1)]
    # activity_agg_nums.loc[rows_with_nulls.index, feature_cols] = feature_cols_medians
    #
    # # Add new column to indicate which rows had blanks
    # new_missing_col = f'activity_{initial_col}_is_missing'
    # activity_agg_nums[new_missing_col] = 0
    # activity_agg_nums[new_missing_col] = activity_agg_nums[new_missing_col].astype('int8')
    # activity_agg_nums.loc[rows_with_nulls.index, new_missing_col] = 1

    feature_cols = [col for col in activity_agg_nums.columns if initial_col in col]
    feature_cols_medians = [activity_agg_nums[col].median() for col in feature_cols]
    new_missing_col = f'activity_{initial_col}_is_missing'
    fill_feature_nan_values(activity_agg_nums, feature_cols, feature_cols_medians, new_missing_col)

activity_agg_nums.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35672 entries, 0 to 35671
# Data columns (total 41 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   client_id                      35672 non-null  uint64
#  1   activity_float_c11_mean        35672 non-null  float32
#  2   activity_float_c11_std         35672 non-null  float32
#  3   activity_float_c11_min         35672 non-null  float32
#  4   activity_float_c11_max         35672 non-null  float32
#  5   activity_float_c11_sum         35672 non-null  float32
#  6   activity_float_c12_mean        35672 non-null  float32
#  7   activity_float_c12_std         35672 non-null  float32
#  8   activity_float_c12_min         35672 non-null  float32
#  9   activity_float_c12_max         35672 non-null  float32
#  10  activity_float_c12_sum         35672 non-null  float32
#  11  activity_float_c13_mean        35672 non-null  float32
#  12  activity_float_c13_std         35672 non-null  float32
#  13  activity_float_c13_min         35672 non-null  float32
#  14  activity_float_c13_max         35672 non-null  float32
#  15  activity_float_c13_sum         35672 non-null  float32
#  16  activity_float_c14_mean        35672 non-null  float32
#  17  activity_float_c14_std         35672 non-null  float32
#  18  activity_float_c14_min         35672 non-null  float32
#  19  activity_float_c14_max         35672 non-null  float32
#  20  activity_float_c14_sum         35672 non-null  float32
#  21  activity_float_c15_mean        35672 non-null  float32
#  22  activity_float_c15_std         35672 non-null  float32
#  23  activity_float_c15_min         35672 non-null  float32
#  24  activity_float_c15_max         35672 non-null  float32
#  25  activity_float_c15_sum         35672 non-null  float32
#  26  activity_float_c16_mean        35672 non-null  float32
#  27  activity_float_c16_std         35672 non-null  float32
#  28  activity_float_c16_min         35672 non-null  float32
#  29  activity_float_c16_max         35672 non-null  float32
#  30  activity_float_c16_sum         35672 non-null  float32
#  31  activity_float_c17_mean        35672 non-null  float32
#  32  activity_float_c17_std         35672 non-null  float32
#  33  activity_float_c17_min         35672 non-null  float32
#  34  activity_float_c17_max         35672 non-null  float32
#  35  activity_float_c17_sum         35672 non-null  float32
#  36  has_single_activity            35672 non-null  int8
#  37  activity_float_c13_is_missing  35672 non-null  int8
#  38  activity_float_c15_is_missing  35672 non-null  int8
#  39  activity_float_c16_is_missing  35672 non-null  int8
#  40  activity_float_c17_is_missing  35672 non-null  int8
# dtypes: float32(35), int8(5), uint64(1)
# memory usage: 5.2 MB

# %%
# Flag variables
flag_cols = ['cat_c8', 'cat_c10']

activity_agg_flags = activities.groupby('client_id')[flag_cols].mean()
activity_agg_flags.columns = [f'activity_{c}_ratio' for c in flag_cols]
activity_agg_flags = activity_agg_flags.reset_index()
activity_agg_flags.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35672 entries, 0 to 35671
# Data columns (total 3 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   client_id               35672 non-null  uint64
#  1   activity_cat_c8_ratio   35669 non-null  Float64
#  2   activity_cat_c10_ratio  35672 non-null  Float64
# dtypes: Float64(2), uint64(1)
# memory usage: 905.9 KB

# %%
# Postprocess flag features
cols_with_nulls = ['activity_cat_c8_ratio']
for col in cols_with_nulls:
    # val_to_fill = activity_agg_flags[col].median()
    # rows_with_nulls = activity_agg_flags[activity_agg_flags[col].isna()]
    # activity_agg_flags.loc[rows_with_nulls.index, col] = val_to_fill
    #
    # # Add new column to indicate which rows had blanks
    # new_missing_col = f'{col}_is_missing'
    # activity_agg_flags[new_missing_col] = 0
    # activity_agg_flags[new_missing_col] = activity_agg_flags[new_missing_col].astype('int8')
    # activity_agg_flags.loc[rows_with_nulls.index, new_missing_col] = 1

    val_to_fill = activity_agg_flags[col].median()
    new_missing_col = f'{col}_is_missing'
    fill_feature_nan_values(activity_agg_flags, [col], [val_to_fill], new_missing_col)

activity_agg_flags.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35672 entries, 0 to 35671
# Data columns (total 4 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   client_id                         35672 non-null  uint64
#  1   activity_cat_c8_ratio             35672 non-null  Float64
#  2   activity_cat_c10_ratio            35672 non-null  Float64
#  3   activity_cat_c8_ratio_is_missing  35672 non-null  int8
# dtypes: Float64(2), int8(1), uint64(1)
# memory usage: 940.7 KB

# %%
# Categorical variables
cat_cols = ['cat_c3', 'cat_c4', 'cat_c5', 'cat_c6', 'cat_c9']
aggregates = {f'activity_{col}_nunique': (col, 'nunique') for col in cat_cols}
aggregates |= {f'activity_{col}_mode': (col, get_series_first_mode_or_nan) for col in cat_cols}

activity_agg_cat = activities.groupby('client_id').agg(**aggregates).reset_index()
activity_agg_cat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35672 entries, 0 to 35671
# Data columns (total 11 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   client_id                35672 non-null  uint64
#  1   activity_cat_c3_nunique  35672 non-null  int64
#  2   activity_cat_c4_nunique  35672 non-null  int64
#  3   activity_cat_c5_nunique  35672 non-null  int64
#  4   activity_cat_c6_nunique  35672 non-null  int64
#  5   activity_cat_c9_nunique  35672 non-null  int64
#  6   activity_cat_c3_mode     35672 non-null  Int32
#  7   activity_cat_c4_mode     35657 non-null  Int32
#  8   activity_cat_c5_mode     35672 non-null  Int32
#  9   activity_cat_c6_mode     35672 non-null  Int32
#  10  activity_cat_c9_mode     35672 non-null  Int32
# dtypes: Int32(5), int64(5), uint64(1)
# memory usage: 2.5 MB

# %%
# Postprocess categorical features
cols_with_nulls = ['activity_cat_c4_mode']
for col in cols_with_nulls:
    # val_to_fill = activity_agg_cat[col].value_counts().idxmax()
    # # activity_agg_cat['activity_cat_c4_mode'] = activity_agg_cat['activity_cat_c4_mode'].fillna(cat_c4_mode_fill_val)
    # rows_with_nulls = activity_agg_cat[activity_agg_cat[col].isna()]
    # activity_agg_cat.loc[rows_with_nulls.index, col] = val_to_fill
    #
    # # Add new column to indicate which rows had blanks
    # new_missing_col = f'{col}_is_missing'
    # activity_agg_cat[new_missing_col] = 0
    # activity_agg_cat[new_missing_col] = activity_agg_cat[new_missing_col].astype('int8')
    # activity_agg_cat.loc[rows_with_nulls.index, new_missing_col] = 1

    val_to_fill = activity_agg_cat[col].value_counts().idxmax()
    new_missing_col = f'{col}_is_missing'
    fill_feature_nan_values(activity_agg_cat, [col], [val_to_fill], new_missing_col)

activity_agg_cat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35672 entries, 0 to 35671
# Data columns (total 12 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   client_id                        35672 non-null  uint64
#  1   activity_cat_c3_nunique          35672 non-null  int64
#  2   activity_cat_c4_nunique          35672 non-null  int64
#  3   activity_cat_c5_nunique          35672 non-null  int64
#  4   activity_cat_c6_nunique          35672 non-null  int64
#  5   activity_cat_c9_nunique          35672 non-null  int64
#  6   activity_cat_c3_mode             35672 non-null  Int32
#  7   activity_cat_c4_mode             35672 non-null  Int32
#  8   activity_cat_c5_mode             35672 non-null  Int32
#  9   activity_cat_c6_mode             35672 non-null  Int32
#  10  activity_cat_c9_mode             35672 non-null  Int32
#  11  activity_cat_c4_mode_is_missing  35672 non-null  int8
# dtypes: Int32(5), int64(5), int8(1), uint64(1)
# memory usage: 2.5 MB

# %%
# Extra features
activity_agg_extra = activities.groupby('client_id').agg(n_devices=('device_id', 'nunique')).reset_index()

# %%
# Merge all features
activity_features = (
    activities_agg_dates
    .merge(activity_agg_nums, on='client_id', how='left')
    .merge(activity_agg_flags, on='client_id', how='left')
    .merge(activity_agg_cat, on='client_id', how='left')
    .merge(activity_agg_extra, on='client_id', how='left')
)
activity_features.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35672 entries, 0 to 35671
# Data columns (total 63 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   client_id                         35672 non-null  uint64
#  1   activity_count                    35672 non-null  int64
#  2   activity_days                     35672 non-null  int64
#  3   activity_avg_per_day              35672 non-null  float64
#  4   activity_period_days              35672 non-null  int64
#  5   days_since_last_activity          35672 non-null  int64
#  6   first_activity_day                35672 non-null  int64
#  7   last_activity_day                 35672 non-null  int64
#  8   activity_float_c11_mean           35672 non-null  float32
#  9   activity_float_c11_std            35672 non-null  float32
#  10  activity_float_c11_min            35672 non-null  float32
#  11  activity_float_c11_max            35672 non-null  float32
#  12  activity_float_c11_sum            35672 non-null  float32
#  13  activity_float_c12_mean           35672 non-null  float32
#  14  activity_float_c12_std            35672 non-null  float32
#  15  activity_float_c12_min            35672 non-null  float32
#  16  activity_float_c12_max            35672 non-null  float32
#  17  activity_float_c12_sum            35672 non-null  float32
#  18  activity_float_c13_mean           35672 non-null  float32
#  19  activity_float_c13_std            35672 non-null  float32
#  20  activity_float_c13_min            35672 non-null  float32
#  21  activity_float_c13_max            35672 non-null  float32
#  22  activity_float_c13_sum            35672 non-null  float32
#  23  activity_float_c14_mean           35672 non-null  float32
#  24  activity_float_c14_std            35672 non-null  float32
#  25  activity_float_c14_min            35672 non-null  float32
#  26  activity_float_c14_max            35672 non-null  float32
#  27  activity_float_c14_sum            35672 non-null  float32
#  28  activity_float_c15_mean           35672 non-null  float32
#  29  activity_float_c15_std            35672 non-null  float32
#  30  activity_float_c15_min            35672 non-null  float32
#  31  activity_float_c15_max            35672 non-null  float32
#  32  activity_float_c15_sum            35672 non-null  float32
#  33  activity_float_c16_mean           35672 non-null  float32
#  34  activity_float_c16_std            35672 non-null  float32
#  35  activity_float_c16_min            35672 non-null  float32
#  36  activity_float_c16_max            35672 non-null  float32
#  37  activity_float_c16_sum            35672 non-null  float32
#  38  activity_float_c17_mean           35672 non-null  float32
#  39  activity_float_c17_std            35672 non-null  float32
#  40  activity_float_c17_min            35672 non-null  float32
#  41  activity_float_c17_max            35672 non-null  float32
#  42  activity_float_c17_sum            35672 non-null  float32
#  43  has_single_activity               35672 non-null  int8
#  44  activity_float_c13_is_missing     35672 non-null  int8
#  45  activity_float_c15_is_missing     35672 non-null  int8
#  46  activity_float_c16_is_missing     35672 non-null  int8
#  47  activity_float_c17_is_missing     35672 non-null  int8
#  48  activity_cat_c8_ratio             35672 non-null  Float64
#  49  activity_cat_c10_ratio            35672 non-null  Float64
#  50  activity_cat_c8_ratio_is_missing  35672 non-null  int8
#  51  activity_cat_c3_nunique           35672 non-null  int64
#  52  activity_cat_c4_nunique           35672 non-null  int64
#  53  activity_cat_c5_nunique           35672 non-null  int64
#  54  activity_cat_c6_nunique           35672 non-null  int64
#  55  activity_cat_c9_nunique           35672 non-null  int64
#  56  activity_cat_c3_mode              35672 non-null  Int32
#  57  activity_cat_c4_mode              35672 non-null  Int32
#  58  activity_cat_c5_mode              35672 non-null  Int32
#  59  activity_cat_c6_mode              35672 non-null  Int32
#  60  activity_cat_c9_mode              35672 non-null  Int32
#  61  activity_cat_c4_mode_is_missing   35672 non-null  int8
#  62  n_devices                         35672 non-null  int64
# dtypes: Float64(2), Int32(5), float32(35), float64(1), int64(12), int8(7), uint64(1)
# memory usage: 10.3 MB

# %% [markdown]
# # Communications

# %%
from utils import encode_comm_categories, preprocess_comm_data, read_communications

COMMS_PATH = 'data/initial/COMMUNICATIONS.csv'
# COMMS_PATH = 'data/samples/COMMUNICATIONS_SAMPLE.csv'

comms = read_communications(COMMS_PATH)
# comms = preprocess_comm_data(comms)
# comms = encode_comm_categories(comms)
comms.info(show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19586922 entries, 0 to 19586921
# Data columns (total 6 columns):
#  #   Column        Non-Null Count     Dtype
# ---  ------        --------------     -----
#  0   client_id     19586922 non-null  uint64
#  1   contact_date  19586922 non-null  datetime64[ns]
#  2   cat_c2        19586922 non-null  category
#  3   cat_c3        19586922 non-null  int32
#  4   cat_c4        19586922 non-null  int32
#  5   cat_c5        19586917 non-null  category
# dtypes: category(2), datetime64[ns](1), int32(2), uint64(1)
# memory usage: 504.4 MB

# %%
comms.head(10)
# Out:
#              client_id contact_date  cat_c2  cat_c3  cat_c4 cat_c5
# 0  1064751079059572946   2025-02-04   S8406       4       1      4
# 1  1064751079059572946   2025-02-04   S3565       4       1      7
# 2  1064751079059572946   2025-02-04   S8404       4       1      4
# 3  1064751079059572946   2025-04-07  S27888       4       1      4
# 4  1064751079059572946   2025-04-07   S3769       4       1      4
# 5  1064751079059572946   2025-04-07   S3564       4       1      4
# 6  1064751079059572946   2025-04-07   S3681       4       1      4
# 7  1064751079059572946   2025-02-05   S3564       4       1      4
# 8  1064751079059572946   2025-05-31  S27888       4       1      4
# 9  1064751079059572946   2025-05-31   S3770       4       1      4

# %%
comms.describe()
# Out:
#           client_id                   contact_date        cat_c3        cat_c4
# count  1.958692e+07                       19586922  1.958692e+07  1.958692e+07
# mean   9.239797e+18  2025-04-17 04:33:31.363128576  4.020126e+00  1.094510e+00
# min    8.446579e+14            2024-12-01 00:00:00  1.000000e+00  1.000000e+00
# 25%    4.627148e+18            2025-03-02 00:00:00  4.000000e+00  1.000000e+00
# 50%    9.240516e+18            2025-04-20 00:00:00  4.000000e+00  1.000000e+00
# 75%    1.382496e+19            2025-06-01 00:00:00  4.000000e+00  1.000000e+00
# max    1.844580e+19            2025-08-31 00:00:00  8.000000e+00  3.000000e+00
# std    5.337613e+18                            NaN  4.120818e-01  3.222231e-01

# %%
# Date variables

comms_agg_dates = comms.groupby('client_id').agg(
    comm_count=('contact_date', 'count'),
    comm_days=('contact_date', 'nunique'),
    first_comm_date=('contact_date', 'min'),
    last_comm_date=('contact_date', 'max'),
).reset_index()

comms_agg_dates['comm_avg_per_day'] = comms_agg_dates['comm_count'] / comms_agg_dates['comm_days']
comms_agg_dates['comm_period_days'] = (comms_agg_dates['last_comm_date'] - comms_agg_dates['first_comm_date']).dt.days

max_date = comms['contact_date'].max()
comms_agg_dates['days_since_last_comm'] = (max_date - comms_agg_dates['last_comm_date']).dt.days

# Replace dates with days from starting point
min_date = comms['contact_date'].min()
comms_agg_dates['first_comm_day'] = (comms_agg_dates['first_comm_date'] - min_date).dt.days
comms_agg_dates['last_comm_day'] = (comms_agg_dates['last_comm_date'] - min_date).dt.days
comms_agg_dates = comms_agg_dates.drop(columns=['first_comm_date', 'last_comm_date'])

# %%
# Categorical variables

aggregates = []
cat_cols = ['cat_c2', 'cat_c3', 'cat_c4', 'cat_c5']
aggregates = {f'comm_{col}_nunique': (col, 'nunique') for col in cat_cols}
aggregates |= {f'comm_{col}_mode': (col, get_series_first_mode_or_nan) for col in cat_cols}

comms_agg_cat = comms.groupby('client_id').agg(**aggregates).reset_index()
comms_agg_cat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35805 entries, 0 to 35804
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   client_id            35805 non-null  uint64
#  1   comm_cat_c2_nunique  35805 non-null  int64
#  2   comm_cat_c3_nunique  35805 non-null  int64
#  3   comm_cat_c4_nunique  35805 non-null  int64
#  4   comm_cat_c5_nunique  35805 non-null  int64
#  5   comm_cat_c2_mode     35805 non-null  category
#  6   comm_cat_c3_mode     35805 non-null  int32
#  7   comm_cat_c4_mode     35805 non-null  int32
#  8   comm_cat_c5_mode     35805 non-null  category
# dtypes: category(2), int32(2), int64(4), uint64(1)
# memory usage: 1.8 MB

# %%
# Postprocess categorical features
for col in ('comm_cat_c2_mode', 'comm_cat_c5_mode'):
    mapping = {val: idx for idx, val in enumerate(np.sort(comms_agg_cat[col].unique()))}
    comms_agg_cat[col] = comms_agg_cat[col].map(mapping).astype('int32')
comms_agg_cat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35805 entries, 0 to 35804
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   client_id            35805 non-null  uint64
#  1   comm_cat_c2_nunique  35805 non-null  int64
#  2   comm_cat_c3_nunique  35805 non-null  int64
#  3   comm_cat_c4_nunique  35805 non-null  int64
#  4   comm_cat_c5_nunique  35805 non-null  int64
#  5   comm_cat_c2_mode     35805 non-null  int32
#  6   comm_cat_c3_mode     35805 non-null  int32
#  7   comm_cat_c4_mode     35805 non-null  int32
#  8   comm_cat_c5_mode     35805 non-null  int32
# dtypes: int32(4), int64(4), uint64(1)
# memory usage: 1.9 MB

# %%
# Merge features
comms_features = comms_agg_dates.merge(comms_agg_cat, on='client_id', how='left')
comms_features.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35805 entries, 0 to 35804
# Data columns (total 16 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   client_id             35805 non-null  uint64
#  1   comm_count            35805 non-null  int64
#  2   comm_days             35805 non-null  int64
#  3   comm_avg_per_day      35805 non-null  float64
#  4   comm_period_days      35805 non-null  int64
#  5   days_since_last_comm  35805 non-null  int64
#  6   first_comm_day        35805 non-null  int64
#  7   last_comm_day         35805 non-null  int64
#  8   comm_cat_c2_nunique   35805 non-null  int64
#  9   comm_cat_c3_nunique   35805 non-null  int64
#  10  comm_cat_c4_nunique   35805 non-null  int64
#  11  comm_cat_c5_nunique   35805 non-null  int64
#  12  comm_cat_c2_mode      35805 non-null  int32
#  13  comm_cat_c3_mode      35805 non-null  int32
#  14  comm_cat_c4_mode      35805 non-null  int32
#  15  comm_cat_c5_mode      35805 non-null  int32
# dtypes: float64(1), int32(4), int64(10), uint64(1)
# memory usage: 3.8 MB

# %% [markdown]
# # Combine features from all datasets

# %%
from utils import convert_np_int_dtypes_to_nullable

# Replace dtypes with nullable to prevent their convertion to float64 after merge
tx_features = convert_np_int_dtypes_to_nullable(tx_features)
activity_features = convert_np_int_dtypes_to_nullable(activity_features)
comms_features = convert_np_int_dtypes_to_nullable(comms_features)

client_features = (
    tx_features
    .merge(activity_features, on='client_id', how='inner')
    .merge(comms_features, on='client_id', how='inner')
)
client_features.info(verbose=True, show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35048 entries, 0 to 35047
# Data columns (total 132 columns):
#  #    Column                            Non-Null Count  Dtype
# ---   ------                            --------------  -----
#  0    client_id                         35048 non-null  uint64
#  1    tx_count                          35048 non-null  Int64
#  2    tx_days                           35048 non-null  Int64
#  3    tx_avg_per_day                    35048 non-null  float64
#  4    tx_period_days                    35048 non-null  Int64
#  5    days_since_last_tx                35048 non-null  Int64
#  6    first_tx_day                      35048 non-null  Int64
#  7    last_tx_day                       35048 non-null  Int64
#  8    tx_float_c16_mean                 35048 non-null  float32
#  9    tx_float_c16_std                  35048 non-null  float32
#  10   tx_float_c16_min                  35048 non-null  float32
#  11   tx_float_c16_max                  35048 non-null  float32
#  12   tx_float_c16_sum                  35048 non-null  float32
#  13   tx_float_c17_mean                 35048 non-null  float32
#  14   tx_float_c17_std                  35048 non-null  float32
#  15   tx_float_c17_min                  35048 non-null  float32
#  16   tx_float_c17_max                  35048 non-null  float32
#  17   tx_float_c17_sum                  35048 non-null  float32
#  18   tx_float_c18_mean                 35048 non-null  float32
#  19   tx_float_c18_std                  35048 non-null  float32
#  20   tx_float_c18_min                  35048 non-null  float32
#  21   tx_float_c18_max                  35048 non-null  float32
#  22   tx_float_c18_sum                  35048 non-null  float32
#  23   tx_int_c19_mean                   35048 non-null  float64
#  24   tx_int_c19_std                    35048 non-null  float64
#  25   tx_int_c19_min                    35048 non-null  Int32
#  26   tx_int_c19_max                    35048 non-null  Int32
#  27   tx_int_c19_sum                    35048 non-null  Int32
#  28   tx_float_c20_mean                 35048 non-null  float32
#  29   tx_float_c20_std                  35048 non-null  float32
#  30   tx_float_c20_min                  35048 non-null  float32
#  31   tx_float_c20_max                  35048 non-null  float32
#  32   tx_float_c20_sum                  35048 non-null  float32
#  33   tx_float_c21_mean                 35048 non-null  float32
#  34   tx_float_c21_std                  35048 non-null  float32
#  35   tx_float_c21_min                  35048 non-null  float32
#  36   tx_float_c21_max                  35048 non-null  float32
#  37   tx_float_c21_sum                  35048 non-null  float32
#  38   has_single_tx                     35048 non-null  Int8
#  39   tx_fl_c6_ratio                    35048 non-null  float64
#  40   tx_fl_c7_ratio                    35048 non-null  float64
#  41   tx_fl_c8_ratio                    35048 non-null  float64
#  42   tx_fl_c9_ratio                    35048 non-null  float64
#  43   tx_fl_c10_ratio                   35048 non-null  float64
#  44   tx_fl_c11_ratio                   35048 non-null  float64
#  45   tx_fl_c12_ratio                   35048 non-null  float64
#  46   tx_fl_c13_ratio                   35048 non-null  float64
#  47   tx_fl_c14_ratio                   35048 non-null  float64
#  48   tx_fl_c15_ratio                   35048 non-null  float64
#  49   tx_cat_c2_nunique                 35048 non-null  Int64
#  50   tx_cat_c3_nunique                 35048 non-null  Int64
#  51   tx_cat_c4_nunique                 35048 non-null  Int64
#  52   tx_cat_c2_mode                    35048 non-null  Int32
#  53   tx_cat_c3_mode                    35048 non-null  Int32
#  54   tx_cat_c4_mode                    35048 non-null  Int32
#  55   activity_count                    35048 non-null  Int64
#  56   activity_days                     35048 non-null  Int64
#  57   activity_avg_per_day              35048 non-null  float64
#  58   activity_period_days              35048 non-null  Int64
#  59   days_since_last_activity          35048 non-null  Int64
#  60   first_activity_day                35048 non-null  Int64
#  61   last_activity_day                 35048 non-null  Int64
#  62   activity_float_c11_mean           35048 non-null  float32
#  63   activity_float_c11_std            35048 non-null  float32
#  64   activity_float_c11_min            35048 non-null  float32
#  65   activity_float_c11_max            35048 non-null  float32
#  66   activity_float_c11_sum            35048 non-null  float32
#  67   activity_float_c12_mean           35048 non-null  float32
#  68   activity_float_c12_std            35048 non-null  float32
#  69   activity_float_c12_min            35048 non-null  float32
#  70   activity_float_c12_max            35048 non-null  float32
#  71   activity_float_c12_sum            35048 non-null  float32
#  72   activity_float_c13_mean           35048 non-null  float32
#  73   activity_float_c13_std            35048 non-null  float32
#  74   activity_float_c13_min            35048 non-null  float32
#  75   activity_float_c13_max            35048 non-null  float32
#  76   activity_float_c13_sum            35048 non-null  float32
#  77   activity_float_c14_mean           35048 non-null  float32
#  78   activity_float_c14_std            35048 non-null  float32
#  79   activity_float_c14_min            35048 non-null  float32
#  80   activity_float_c14_max            35048 non-null  float32
#  81   activity_float_c14_sum            35048 non-null  float32
#  82   activity_float_c15_mean           35048 non-null  float32
#  83   activity_float_c15_std            35048 non-null  float32
#  84   activity_float_c15_min            35048 non-null  float32
#  85   activity_float_c15_max            35048 non-null  float32
#  86   activity_float_c15_sum            35048 non-null  float32
#  87   activity_float_c16_mean           35048 non-null  float32
#  88   activity_float_c16_std            35048 non-null  float32
#  89   activity_float_c16_min            35048 non-null  float32
#  90   activity_float_c16_max            35048 non-null  float32
#  91   activity_float_c16_sum            35048 non-null  float32
#  92   activity_float_c17_mean           35048 non-null  float32
#  93   activity_float_c17_std            35048 non-null  float32
#  94   activity_float_c17_min            35048 non-null  float32
#  95   activity_float_c17_max            35048 non-null  float32
#  96   activity_float_c17_sum            35048 non-null  float32
#  97   has_single_activity               35048 non-null  Int8
#  98   activity_float_c13_is_missing     35048 non-null  Int8
#  99   activity_float_c15_is_missing     35048 non-null  Int8
#  100  activity_float_c16_is_missing     35048 non-null  Int8
#  101  activity_float_c17_is_missing     35048 non-null  Int8
#  102  activity_cat_c8_ratio             35048 non-null  Float64
#  103  activity_cat_c10_ratio            35048 non-null  Float64
#  104  activity_cat_c8_ratio_is_missing  35048 non-null  Int8
#  105  activity_cat_c3_nunique           35048 non-null  Int64
#  106  activity_cat_c4_nunique           35048 non-null  Int64
#  107  activity_cat_c5_nunique           35048 non-null  Int64
#  108  activity_cat_c6_nunique           35048 non-null  Int64
#  109  activity_cat_c9_nunique           35048 non-null  Int64
#  110  activity_cat_c3_mode              35048 non-null  Int32
#  111  activity_cat_c4_mode              35048 non-null  Int32
#  112  activity_cat_c5_mode              35048 non-null  Int32
#  113  activity_cat_c6_mode              35048 non-null  Int32
#  114  activity_cat_c9_mode              35048 non-null  Int32
#  115  activity_cat_c4_mode_is_missing   35048 non-null  Int8
#  116  n_devices                         35048 non-null  Int64
#  117  comm_count                        35048 non-null  Int64
#  118  comm_days                         35048 non-null  Int64
#  119  comm_avg_per_day                  35048 non-null  float64
#  120  comm_period_days                  35048 non-null  Int64
#  121  days_since_last_comm              35048 non-null  Int64
#  122  first_comm_day                    35048 non-null  Int64
#  123  last_comm_day                     35048 non-null  Int64
#  124  comm_cat_c2_nunique               35048 non-null  Int64
#  125  comm_cat_c3_nunique               35048 non-null  Int64
#  126  comm_cat_c4_nunique               35048 non-null  Int64
#  127  comm_cat_c5_nunique               35048 non-null  Int64
#  128  comm_cat_c2_mode                  35048 non-null  Int32
#  129  comm_cat_c3_mode                  35048 non-null  Int32
#  130  comm_cat_c4_mode                  35048 non-null  Int32
#  131  comm_cat_c5_mode                  35048 non-null  Int32
# dtypes: Float64(2), Int32(15), Int64(31), Int8(8), float32(60), float64(15), uint64(1)
# memory usage: 25.3 MB

# %%
# Postprocess client features
from utils import fill_feature_nan_values

# Fill NULL-values and create a new column to indicate this
for sub_features, new_missing_col in zip([tx_features, activity_features, comms_features], ('tx_is_missing', 'activity_is_missing', 'comm_is_missing')):
    sub_features = sub_features.drop(columns=['client_id'])
    sub_features_cols = sub_features.columns
    if client_features[client_features[sub_features_cols].isna().all(axis=1)].empty:
        continue

    # for col in sub_features.columns:
    #     val_to_fill = client_features[col].median
    #     client_features = fill_feature_nan_values(client_features, col, val_to_fill)
    #
    # client_features[new_missing_col] = 0
    # client_features[new_missing_col] = client_features[new_missing_col].astype('int8')
    # client_features.loc[rows_with_nulls.index, new_missing_col] = 1

    sub_features_medians = [client_features[col].median() for col in sub_features_cols]
    client_features = fill_feature_nan_values(client_features, sub_features_cols, sub_features_medians, new_missing_col)

client_features.info(verbose=True, show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35048 entries, 0 to 35047
# Data columns (total 132 columns):
#  #    Column                            Non-Null Count  Dtype
# ---   ------                            --------------  -----
#  0    client_id                         35048 non-null  uint64
#  1    tx_count                          35048 non-null  Int64
#  2    tx_days                           35048 non-null  Int64
#  3    tx_avg_per_day                    35048 non-null  float64
#  4    tx_period_days                    35048 non-null  Int64
#  5    days_since_last_tx                35048 non-null  Int64
#  6    first_tx_day                      35048 non-null  Int64
#  7    last_tx_day                       35048 non-null  Int64
#  8    tx_float_c16_mean                 35048 non-null  float32
#  9    tx_float_c16_std                  35048 non-null  float32
#  10   tx_float_c16_min                  35048 non-null  float32
#  11   tx_float_c16_max                  35048 non-null  float32
#  12   tx_float_c16_sum                  35048 non-null  float32
#  13   tx_float_c17_mean                 35048 non-null  float32
#  14   tx_float_c17_std                  35048 non-null  float32
#  15   tx_float_c17_min                  35048 non-null  float32
#  16   tx_float_c17_max                  35048 non-null  float32
#  17   tx_float_c17_sum                  35048 non-null  float32
#  18   tx_float_c18_mean                 35048 non-null  float32
#  19   tx_float_c18_std                  35048 non-null  float32
#  20   tx_float_c18_min                  35048 non-null  float32
#  21   tx_float_c18_max                  35048 non-null  float32
#  22   tx_float_c18_sum                  35048 non-null  float32
#  23   tx_int_c19_mean                   35048 non-null  float64
#  24   tx_int_c19_std                    35048 non-null  float64
#  25   tx_int_c19_min                    35048 non-null  Int32
#  26   tx_int_c19_max                    35048 non-null  Int32
#  27   tx_int_c19_sum                    35048 non-null  Int32
#  28   tx_float_c20_mean                 35048 non-null  float32
#  29   tx_float_c20_std                  35048 non-null  float32
#  30   tx_float_c20_min                  35048 non-null  float32
#  31   tx_float_c20_max                  35048 non-null  float32
#  32   tx_float_c20_sum                  35048 non-null  float32
#  33   tx_float_c21_mean                 35048 non-null  float32
#  34   tx_float_c21_std                  35048 non-null  float32
#  35   tx_float_c21_min                  35048 non-null  float32
#  36   tx_float_c21_max                  35048 non-null  float32
#  37   tx_float_c21_sum                  35048 non-null  float32
#  38   has_single_tx                     35048 non-null  Int8
#  39   tx_fl_c6_ratio                    35048 non-null  float64
#  40   tx_fl_c7_ratio                    35048 non-null  float64
#  41   tx_fl_c8_ratio                    35048 non-null  float64
#  42   tx_fl_c9_ratio                    35048 non-null  float64
#  43   tx_fl_c10_ratio                   35048 non-null  float64
#  44   tx_fl_c11_ratio                   35048 non-null  float64
#  45   tx_fl_c12_ratio                   35048 non-null  float64
#  46   tx_fl_c13_ratio                   35048 non-null  float64
#  47   tx_fl_c14_ratio                   35048 non-null  float64
#  48   tx_fl_c15_ratio                   35048 non-null  float64
#  49   tx_cat_c2_nunique                 35048 non-null  Int64
#  50   tx_cat_c3_nunique                 35048 non-null  Int64
#  51   tx_cat_c4_nunique                 35048 non-null  Int64
#  52   tx_cat_c2_mode                    35048 non-null  Int32
#  53   tx_cat_c3_mode                    35048 non-null  Int32
#  54   tx_cat_c4_mode                    35048 non-null  Int32
#  55   activity_count                    35048 non-null  Int64
#  56   activity_days                     35048 non-null  Int64
#  57   activity_avg_per_day              35048 non-null  float64
#  58   activity_period_days              35048 non-null  Int64
#  59   days_since_last_activity          35048 non-null  Int64
#  60   first_activity_day                35048 non-null  Int64
#  61   last_activity_day                 35048 non-null  Int64
#  62   activity_float_c11_mean           35048 non-null  float32
#  63   activity_float_c11_std            35048 non-null  float32
#  64   activity_float_c11_min            35048 non-null  float32
#  65   activity_float_c11_max            35048 non-null  float32
#  66   activity_float_c11_sum            35048 non-null  float32
#  67   activity_float_c12_mean           35048 non-null  float32
#  68   activity_float_c12_std            35048 non-null  float32
#  69   activity_float_c12_min            35048 non-null  float32
#  70   activity_float_c12_max            35048 non-null  float32
#  71   activity_float_c12_sum            35048 non-null  float32
#  72   activity_float_c13_mean           35048 non-null  float32
#  73   activity_float_c13_std            35048 non-null  float32
#  74   activity_float_c13_min            35048 non-null  float32
#  75   activity_float_c13_max            35048 non-null  float32
#  76   activity_float_c13_sum            35048 non-null  float32
#  77   activity_float_c14_mean           35048 non-null  float32
#  78   activity_float_c14_std            35048 non-null  float32
#  79   activity_float_c14_min            35048 non-null  float32
#  80   activity_float_c14_max            35048 non-null  float32
#  81   activity_float_c14_sum            35048 non-null  float32
#  82   activity_float_c15_mean           35048 non-null  float32
#  83   activity_float_c15_std            35048 non-null  float32
#  84   activity_float_c15_min            35048 non-null  float32
#  85   activity_float_c15_max            35048 non-null  float32
#  86   activity_float_c15_sum            35048 non-null  float32
#  87   activity_float_c16_mean           35048 non-null  float32
#  88   activity_float_c16_std            35048 non-null  float32
#  89   activity_float_c16_min            35048 non-null  float32
#  90   activity_float_c16_max            35048 non-null  float32
#  91   activity_float_c16_sum            35048 non-null  float32
#  92   activity_float_c17_mean           35048 non-null  float32
#  93   activity_float_c17_std            35048 non-null  float32
#  94   activity_float_c17_min            35048 non-null  float32
#  95   activity_float_c17_max            35048 non-null  float32
#  96   activity_float_c17_sum            35048 non-null  float32
#  97   has_single_activity               35048 non-null  Int8
#  98   activity_float_c13_is_missing     35048 non-null  Int8
#  99   activity_float_c15_is_missing     35048 non-null  Int8
#  100  activity_float_c16_is_missing     35048 non-null  Int8
#  101  activity_float_c17_is_missing     35048 non-null  Int8
#  102  activity_cat_c8_ratio             35048 non-null  Float64
#  103  activity_cat_c10_ratio            35048 non-null  Float64
#  104  activity_cat_c8_ratio_is_missing  35048 non-null  Int8
#  105  activity_cat_c3_nunique           35048 non-null  Int64
#  106  activity_cat_c4_nunique           35048 non-null  Int64
#  107  activity_cat_c5_nunique           35048 non-null  Int64
#  108  activity_cat_c6_nunique           35048 non-null  Int64
#  109  activity_cat_c9_nunique           35048 non-null  Int64
#  110  activity_cat_c3_mode              35048 non-null  Int32
#  111  activity_cat_c4_mode              35048 non-null  Int32
#  112  activity_cat_c5_mode              35048 non-null  Int32
#  113  activity_cat_c6_mode              35048 non-null  Int32
#  114  activity_cat_c9_mode              35048 non-null  Int32
#  115  activity_cat_c4_mode_is_missing   35048 non-null  Int8
#  116  n_devices                         35048 non-null  Int64
#  117  comm_count                        35048 non-null  Int64
#  118  comm_days                         35048 non-null  Int64
#  119  comm_avg_per_day                  35048 non-null  float64
#  120  comm_period_days                  35048 non-null  Int64
#  121  days_since_last_comm              35048 non-null  Int64
#  122  first_comm_day                    35048 non-null  Int64
#  123  last_comm_day                     35048 non-null  Int64
#  124  comm_cat_c2_nunique               35048 non-null  Int64
#  125  comm_cat_c3_nunique               35048 non-null  Int64
#  126  comm_cat_c4_nunique               35048 non-null  Int64
#  127  comm_cat_c5_nunique               35048 non-null  Int64
#  128  comm_cat_c2_mode                  35048 non-null  Int32
#  129  comm_cat_c3_mode                  35048 non-null  Int32
#  130  comm_cat_c4_mode                  35048 non-null  Int32
#  131  comm_cat_c5_mode                  35048 non-null  Int32
# dtypes: Float64(2), Int32(15), Int64(31), Int8(8), float32(60), float64(15), uint64(1)
# memory usage: 25.3 MB

# %%
# Reduce float precision to float32
client_features = client_features.astype({col: 'float32' for col in client_features.select_dtypes(include=['float64']).columns})

# Downcast int64 to int32
for int64_dtype, int32_dtype in zip(['int64', 'Int64'], ['int32', 'Int32']):
    int64_cols = [col for col in client_features.columns if client_features[col].dtype.name == int64_dtype]
    for col in int64_cols:
        min_val = client_features[col].min()
        max_val = client_features[col].max()
        if (min_val >= np.iinfo(np.int32).min) and (max_val <= np.iinfo(np.int32).max):
            client_features = client_features.astype({col: int32_dtype})
        else:
            print(f'Column {col} exceeds int32 range')

# %%
client_features.info(verbose=True, show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35048 entries, 0 to 35047
# Data columns (total 132 columns):
#  #    Column                            Non-Null Count  Dtype
# ---   ------                            --------------  -----
#  0    client_id                         35048 non-null  uint64
#  1    tx_count                          35048 non-null  Int32
#  2    tx_days                           35048 non-null  Int32
#  3    tx_avg_per_day                    35048 non-null  float32
#  4    tx_period_days                    35048 non-null  Int32
#  5    days_since_last_tx                35048 non-null  Int32
#  6    first_tx_day                      35048 non-null  Int32
#  7    last_tx_day                       35048 non-null  Int32
#  8    tx_float_c16_mean                 35048 non-null  float32
#  9    tx_float_c16_std                  35048 non-null  float32
#  10   tx_float_c16_min                  35048 non-null  float32
#  11   tx_float_c16_max                  35048 non-null  float32
#  12   tx_float_c16_sum                  35048 non-null  float32
#  13   tx_float_c17_mean                 35048 non-null  float32
#  14   tx_float_c17_std                  35048 non-null  float32
#  15   tx_float_c17_min                  35048 non-null  float32
#  16   tx_float_c17_max                  35048 non-null  float32
#  17   tx_float_c17_sum                  35048 non-null  float32
#  18   tx_float_c18_mean                 35048 non-null  float32
#  19   tx_float_c18_std                  35048 non-null  float32
#  20   tx_float_c18_min                  35048 non-null  float32
#  21   tx_float_c18_max                  35048 non-null  float32
#  22   tx_float_c18_sum                  35048 non-null  float32
#  23   tx_int_c19_mean                   35048 non-null  float32
#  24   tx_int_c19_std                    35048 non-null  float32
#  25   tx_int_c19_min                    35048 non-null  Int32
#  26   tx_int_c19_max                    35048 non-null  Int32
#  27   tx_int_c19_sum                    35048 non-null  Int32
#  28   tx_float_c20_mean                 35048 non-null  float32
#  29   tx_float_c20_std                  35048 non-null  float32
#  30   tx_float_c20_min                  35048 non-null  float32
#  31   tx_float_c20_max                  35048 non-null  float32
#  32   tx_float_c20_sum                  35048 non-null  float32
#  33   tx_float_c21_mean                 35048 non-null  float32
#  34   tx_float_c21_std                  35048 non-null  float32
#  35   tx_float_c21_min                  35048 non-null  float32
#  36   tx_float_c21_max                  35048 non-null  float32
#  37   tx_float_c21_sum                  35048 non-null  float32
#  38   has_single_tx                     35048 non-null  Int8
#  39   tx_fl_c6_ratio                    35048 non-null  float32
#  40   tx_fl_c7_ratio                    35048 non-null  float32
#  41   tx_fl_c8_ratio                    35048 non-null  float32
#  42   tx_fl_c9_ratio                    35048 non-null  float32
#  43   tx_fl_c10_ratio                   35048 non-null  float32
#  44   tx_fl_c11_ratio                   35048 non-null  float32
#  45   tx_fl_c12_ratio                   35048 non-null  float32
#  46   tx_fl_c13_ratio                   35048 non-null  float32
#  47   tx_fl_c14_ratio                   35048 non-null  float32
#  48   tx_fl_c15_ratio                   35048 non-null  float32
#  49   tx_cat_c2_nunique                 35048 non-null  Int32
#  50   tx_cat_c3_nunique                 35048 non-null  Int32
#  51   tx_cat_c4_nunique                 35048 non-null  Int32
#  52   tx_cat_c2_mode                    35048 non-null  Int32
#  53   tx_cat_c3_mode                    35048 non-null  Int32
#  54   tx_cat_c4_mode                    35048 non-null  Int32
#  55   activity_count                    35048 non-null  Int32
#  56   activity_days                     35048 non-null  Int32
#  57   activity_avg_per_day              35048 non-null  float32
#  58   activity_period_days              35048 non-null  Int32
#  59   days_since_last_activity          35048 non-null  Int32
#  60   first_activity_day                35048 non-null  Int32
#  61   last_activity_day                 35048 non-null  Int32
#  62   activity_float_c11_mean           35048 non-null  float32
#  63   activity_float_c11_std            35048 non-null  float32
#  64   activity_float_c11_min            35048 non-null  float32
#  65   activity_float_c11_max            35048 non-null  float32
#  66   activity_float_c11_sum            35048 non-null  float32
#  67   activity_float_c12_mean           35048 non-null  float32
#  68   activity_float_c12_std            35048 non-null  float32
#  69   activity_float_c12_min            35048 non-null  float32
#  70   activity_float_c12_max            35048 non-null  float32
#  71   activity_float_c12_sum            35048 non-null  float32
#  72   activity_float_c13_mean           35048 non-null  float32
#  73   activity_float_c13_std            35048 non-null  float32
#  74   activity_float_c13_min            35048 non-null  float32
#  75   activity_float_c13_max            35048 non-null  float32
#  76   activity_float_c13_sum            35048 non-null  float32
#  77   activity_float_c14_mean           35048 non-null  float32
#  78   activity_float_c14_std            35048 non-null  float32
#  79   activity_float_c14_min            35048 non-null  float32
#  80   activity_float_c14_max            35048 non-null  float32
#  81   activity_float_c14_sum            35048 non-null  float32
#  82   activity_float_c15_mean           35048 non-null  float32
#  83   activity_float_c15_std            35048 non-null  float32
#  84   activity_float_c15_min            35048 non-null  float32
#  85   activity_float_c15_max            35048 non-null  float32
#  86   activity_float_c15_sum            35048 non-null  float32
#  87   activity_float_c16_mean           35048 non-null  float32
#  88   activity_float_c16_std            35048 non-null  float32
#  89   activity_float_c16_min            35048 non-null  float32
#  90   activity_float_c16_max            35048 non-null  float32
#  91   activity_float_c16_sum            35048 non-null  float32
#  92   activity_float_c17_mean           35048 non-null  float32
#  93   activity_float_c17_std            35048 non-null  float32
#  94   activity_float_c17_min            35048 non-null  float32
#  95   activity_float_c17_max            35048 non-null  float32
#  96   activity_float_c17_sum            35048 non-null  float32
#  97   has_single_activity               35048 non-null  Int8
#  98   activity_float_c13_is_missing     35048 non-null  Int8
#  99   activity_float_c15_is_missing     35048 non-null  Int8
#  100  activity_float_c16_is_missing     35048 non-null  Int8
#  101  activity_float_c17_is_missing     35048 non-null  Int8
#  102  activity_cat_c8_ratio             35048 non-null  float32
#  103  activity_cat_c10_ratio            35048 non-null  float32
#  104  activity_cat_c8_ratio_is_missing  35048 non-null  Int8
#  105  activity_cat_c3_nunique           35048 non-null  Int32
#  106  activity_cat_c4_nunique           35048 non-null  Int32
#  107  activity_cat_c5_nunique           35048 non-null  Int32
#  108  activity_cat_c6_nunique           35048 non-null  Int32
#  109  activity_cat_c9_nunique           35048 non-null  Int32
#  110  activity_cat_c3_mode              35048 non-null  Int32
#  111  activity_cat_c4_mode              35048 non-null  Int32
#  112  activity_cat_c5_mode              35048 non-null  Int32
#  113  activity_cat_c6_mode              35048 non-null  Int32
#  114  activity_cat_c9_mode              35048 non-null  Int32
#  115  activity_cat_c4_mode_is_missing   35048 non-null  Int8
#  116  n_devices                         35048 non-null  Int32
#  117  comm_count                        35048 non-null  Int32
#  118  comm_days                         35048 non-null  Int32
#  119  comm_avg_per_day                  35048 non-null  float32
#  120  comm_period_days                  35048 non-null  Int32
#  121  days_since_last_comm              35048 non-null  Int32
#  122  first_comm_day                    35048 non-null  Int32
#  123  last_comm_day                     35048 non-null  Int32
#  124  comm_cat_c2_nunique               35048 non-null  Int32
#  125  comm_cat_c3_nunique               35048 non-null  Int32
#  126  comm_cat_c4_nunique               35048 non-null  Int32
#  127  comm_cat_c5_nunique               35048 non-null  Int32
#  128  comm_cat_c2_mode                  35048 non-null  Int32
#  129  comm_cat_c3_mode                  35048 non-null  Int32
#  130  comm_cat_c4_mode                  35048 non-null  Int32
#  131  comm_cat_c5_mode                  35048 non-null  Int32
# dtypes: Int32(46), Int8(8), float32(77), uint64(1)
# memory usage: 18.8 MB

# %%
client_features.describe()
# Out:
#           client_id    tx_count     tx_days  tx_avg_per_day  tx_period_days  \
# count  3.504800e+04     35048.0     35048.0    35048.000000         35048.0
# mean   9.228491e+18  446.652248  102.330433        3.702068      164.131363
# std    5.314549e+18  474.062009   54.683926        2.885128       39.380292
# min    8.446579e+14         1.0         1.0        1.000000             0.0
# 25%    4.662208e+18       121.0        56.0        2.105263           173.0
# 50%    9.210583e+18       308.0       109.0        2.993151           180.0
# 75%    1.379687e+19       615.0       151.0        4.470209           181.0
# max    1.844580e+19      8721.0       184.0      139.000000           183.0
#
#        days_since_last_tx  first_tx_day  last_tx_day  tx_float_c16_mean  \
# count             35048.0       35048.0      35048.0       35048.000000
# mean            53.070218     55.798419   219.929782           0.029508
# std             36.383763     48.412568    36.383763           0.086140
# min                   0.0           0.0          0.0          -0.034590
# 25%                  31.0          31.0        181.0           0.000000
# 50%                  62.0          62.0        211.0           0.007280
# 75%                  92.0          90.0        242.0           0.034805
# max                 273.0         273.0        273.0           4.931539
#
#        tx_float_c16_std  ...  first_comm_day  last_comm_day  \
# count      35048.000000  ...         35048.0        35048.0
# mean           0.125950  ...        49.77411     223.122346
# std            0.334475  ...       41.925627       33.27781
# min            0.000000  ...             0.0          162.0
# 25%            0.000000  ...            16.0          181.0
# 50%            0.043387  ...            62.0          211.0
# 75%            0.141631  ...            74.0          242.0
# max           18.192768  ...           271.0          273.0
#
#        comm_cat_c2_nunique  comm_cat_c3_nunique  comm_cat_c4_nunique  \
# count              35048.0              35048.0              35048.0
# mean             62.581802             3.383274             2.997147
# std              17.357703             0.630731              0.05334
# min                    3.0                  1.0                  2.0
# 25%                   51.0                  3.0                  3.0
# 50%                   62.0                  3.0                  3.0
# 75%                   73.0                  4.0                  3.0
# max                  148.0                  7.0                  3.0
#
#        comm_cat_c5_nunique  comm_cat_c2_mode  comm_cat_c3_mode  \
# count              35048.0           35048.0           35048.0
# mean              5.130564        123.023824          4.000799
# std                1.61569         15.590284          0.056525
# min                    1.0               0.0               4.0
# 25%                    4.0             122.0               4.0
# 50%                    5.0             122.0               4.0
# 75%                    6.0             127.0               4.0
# max                   14.0             165.0               8.0
#
#        comm_cat_c4_mode  comm_cat_c5_mode
# count           35048.0           35048.0
# mean           1.057436          0.999401
# std            0.237531          0.082922
# min                 1.0               0.0
# 25%                 1.0               1.0
# 50%                 1.0               1.0
# 75%                 1.0               1.0
# max                 3.0               7.0
#
# [8 rows x 132 columns]

# %%
client_features.to_csv('data/features/features_5.csv', index=False)
