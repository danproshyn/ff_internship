# %% [markdown]
# # Feature selection

# %%
import re

import numpy as np
import pandas as pd
from IPython.display import display
from feature_engine.selection import DropConstantFeatures, DropDuplicateFeatures, DropHighPSIFeatures, MRMR, SmartCorrelatedSelection
from lightgbm import LGBMClassifier
from sklearn.feature_selection import SelectFromModel, SelectKBest, mutual_info_classif, RFE
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.inspection import permutation_importance
from sklearn.model_selection import StratifiedKFold
from sklearn_genetic import GAFeatureSelectionCV
from boruta import BorutaPy

from models.model_utils import split_dataset_v2

# %%
FEATURES_VERSION = 6
SELECTION_VERSION = 7

# %%
FEATURES_PATH = '../data/features/features_auto_v{}.csv'.format(FEATURES_VERSION)

features_df = pd.read_csv(FEATURES_PATH)

# %%
clients_cols = ['client_id', 'target', 'is_train']
clients_data = features_df[clients_cols]

X = features_df.drop(columns=clients_cols)
y = features_df['target']

# %%
# X_train = X[features_df['is_train'] == 1]
# y_train = y[features_df['is_train'] == 1]

X_train, _, _, y_train, _, _ = split_dataset_v2(FEATURES_PATH, valid_size=0.2)

# %% [markdown]
# ## Filters

# %%
"""Constant features"""

drop_constant = DropConstantFeatures(tol=1)
drop_constant.fit(X_train)
X1 = drop_constant.transform(X)
X1_train = drop_constant.transform(X_train)

# %%
"""Quasi-constant features"""

drop_quasi = DropConstantFeatures(tol=0.99)
drop_quasi.fit(X1_train)
X2 = drop_quasi.transform(X1)
X2_train = drop_quasi.transform(X1_train)

# %%
"""Duplicate features"""

drop_duplicates = DropDuplicateFeatures()
drop_duplicates.fit(X2_train)
X3 = drop_duplicates.transform(X2)
X3_train = drop_duplicates.transform(X2_train)

# %%
"""Correlation"""

corr_selector = SmartCorrelatedSelection(
    method='pearson',
    threshold=0.7,
    selection_method='missing_values',
)

corr_selector.fit(X3_train, y_train)
X_corr = corr_selector.transform(X3)
X_corr_train = corr_selector.transform(X3_train)

# %%
"""PCI"""

psi_selector = DropHighPSIFeatures(
    split_frac=0.5,
    strategy='equal_frequency',
    bins=10,
    threshold=0.1,
)

psi_selector.fit(X_corr_train)
X_psi = psi_selector.transform(X_corr)
X_psi_train = psi_selector.transform(X_corr_train)

# %%
# """Mutual information"""
#
# mi = SelectKBest(
#     score_func=mutual_info_classif,
#     k=300,
# )
# mi.fit(X_corr, y)
# selected_mi_features = X_corr.columns[mi.get_support()]
# X_mi = X_corr[selected_mi_features]

# %%
# """MRMR"""
#
# mrmr_selector = MRMR(
#     method='MIQ',
#     max_features=50,
#     regression=False,
#     random_state=42,
#     n_jobs=6,
# )
# X_mrmr = mrmr_selector.fit_transform(X_corr, y)

# %%
X_filtered = X_psi
X_filtered_train = X_psi_train
display(X_filtered.info(verbose=True, show_counts=True))
display(X_filtered.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34964 entries, 0 to 34963
# Data columns (total 424 columns):
#  #    Column                                                                                       Non-Null Count  Dtype
# ---   ------                                                                                       --------------  -----
#  0    COUNT(transactions)                                                                          34964 non-null  int64
#  1    ENTROPY(transactions.cat_c2)                                                                 34964 non-null  float64
#  2    ENTROPY(transactions.cat_c4)                                                                 34964 non-null  float64
#  3    KURTOSIS(transactions.float_c16)                                                             34964 non-null  float64
#  4    KURTOSIS(transactions.float_c17)                                                             34964 non-null  float64
#  5    KURTOSIS(transactions.float_c18)                                                             34964 non-null  float64
#  6    KURTOSIS(transactions.float_c20)                                                             34964 non-null  float64
#  7    KURTOSIS(transactions.int_c19)                                                               34964 non-null  float64
#  8    MAX(transactions.float_c16)                                                                  34964 non-null  float64
#  9    MAX(transactions.float_c17)                                                                  34964 non-null  float64
#  10   MAX(transactions.float_c18)                                                                  34964 non-null  float64
#  11   MAX(transactions.float_c20)                                                                  34964 non-null  float64
#  12   MEAN(transactions.float_c16)                                                                 34964 non-null  float64
#  13   MEAN(transactions.float_c17)                                                                 34964 non-null  float64
#  14   MEAN(transactions.float_c18)                                                                 34964 non-null  float64
#  15   MEAN(transactions.int_c19)                                                                   34964 non-null  float64
#  16   MEAN(transactions.tran_date_day_of_month_cos)                                                34964 non-null  float64
#  17   MEAN(transactions.tran_date_day_of_month_sin)                                                34964 non-null  float64
#  18   MEAN(transactions.tran_date_day_of_week_cos)                                                 34964 non-null  float64
#  19   MEAN(transactions.tran_date_day_of_week_sin)                                                 34964 non-null  float64
#  20   MIN(transactions.float_c16)                                                                  34964 non-null  float64
#  21   MIN(transactions.float_c17)                                                                  34964 non-null  float64
#  22   MIN(transactions.float_c18)                                                                  34964 non-null  float64
#  23   MIN(transactions.float_c20)                                                                  34964 non-null  float64
#  24   NUM_UNIQUE(transactions.cat_c4)                                                              34964 non-null  int64
#  25   PERCENT_TRUE(transactions.fl_c11)                                                            34964 non-null  float64
#  26   PERCENT_TRUE(transactions.fl_c12)                                                            34964 non-null  float64
#  27   PERCENT_TRUE(transactions.fl_c13)                                                            34964 non-null  float64
#  28   PERCENT_TRUE(transactions.fl_c15)                                                            34964 non-null  float64
#  29   PERCENT_TRUE(transactions.fl_c6)                                                             34964 non-null  float64
#  30   PERCENT_TRUE(transactions.fl_c8)                                                             34964 non-null  float64
#  31   PERCENT_TRUE(transactions.tran_date_is_weekend)                                              34964 non-null  float64
#  32   STD(transactions.int_c19)                                                                    34964 non-null  float64
#  33   SUM(transactions.float_c16)                                                                  34964 non-null  float64
#  34   SUM(transactions.float_c18)                                                                  34964 non-null  float64
#  35   SUM(transactions.float_c20)                                                                  34964 non-null  float64
#  36   SUM(transactions.int_c19)                                                                    34964 non-null  float64
#  37   TIME_SINCE_FIRST(transactions.tran_date, unit=days)                                          34964 non-null  float64
#  38   TIME_SINCE_LAST(transactions.tran_date, unit=days)                                           34964 non-null  float64
#  39   ENTROPY(activities.cat_c3)                                                                   34964 non-null  float64
#  40   ENTROPY(activities.cat_c5)                                                                   34964 non-null  float64
#  41   ENTROPY(activities.cat_c6)                                                                   34964 non-null  float64
#  42   ENTROPY(activities.cat_c9)                                                                   34964 non-null  float64
#  43   KURTOSIS(activities.float_c11)                                                               34964 non-null  float64
#  44   KURTOSIS(activities.float_c12)                                                               34964 non-null  float64
#  45   KURTOSIS(activities.float_c14)                                                               34964 non-null  float64
#  46   MAX(activities.float_c11)                                                                    34964 non-null  float64
#  47   MAX(activities.float_c12)                                                                    34964 non-null  float64
#  48   MAX(activities.float_c14)                                                                    34964 non-null  float64
#  49   MEAN(activities.activity_date_day_of_week_cos)                                               34964 non-null  float64
#  50   MEAN(activities.activity_date_day_of_week_sin)                                               34964 non-null  float64
#  51   MEAN(activities.float_c12)                                                                   34964 non-null  float64
#  52   MIN(activities.float_c11)                                                                    34964 non-null  float64
#  53   MIN(activities.float_c12)                                                                    34964 non-null  float64
#  54   MIN(activities.float_c14)                                                                    34964 non-null  float64
#  55   NUM_UNIQUE(activities.cat_c3)                                                                34964 non-null  int64
#  56   NUM_UNIQUE(activities.cat_c4)                                                                34964 non-null  int64
#  57   NUM_UNIQUE(activities.cat_c5)                                                                34964 non-null  int64
#  58   PERCENT_TRUE(activities.activity_date_is_weekend)                                            34964 non-null  float64
#  59   PERCENT_TRUE(activities.cat_c10)                                                             34964 non-null  float64
#  60   PERCENT_TRUE(activities.cat_c8)                                                              34964 non-null  float64
#  61   SKEW(activities.float_c11)                                                                   34964 non-null  float64
#  62   SKEW(activities.float_c14)                                                                   34964 non-null  float64
#  63   STD(activities.float_c11)                                                                    34964 non-null  float64
#  64   SUM(activities.float_c11)                                                                    34964 non-null  float64
#  65   SUM(activities.float_c14)                                                                    34964 non-null  float64
#  66   TIME_SINCE_LAST(activities.activity_date, unit=days)                                         34964 non-null  float64
#  67   ENTROPY(comms.cat_c2)                                                                        34964 non-null  float64
#  68   ENTROPY(comms.cat_c3)                                                                        34964 non-null  float64
#  69   ENTROPY(comms.cat_c5)                                                                        34964 non-null  float64
#  70   NUM_UNIQUE(comms.cat_c2)                                                                     34964 non-null  int64
#  71   NUM_UNIQUE(comms.cat_c3)                                                                     34964 non-null  int64
#  72   NUM_UNIQUE(comms.cat_c5)                                                                     34964 non-null  int64
#  73   TIME_SINCE_LAST(comms.contact_date, unit=days)                                               34964 non-null  float64
#  74   IS_WEEKEND(communication_month)                                                              34964 non-null  int64
#  75   COUNT(transactions WHERE fl_c13 = True)                                                      34964 non-null  int64
#  76   COUNT(transactions WHERE cat_c3 = 303)                                                       34964 non-null  int64
#  77   MAX(transactions.float_c16 WHERE fl_c14 = False)                                             34964 non-null  float64
#  78   MAX(transactions.float_c16 WHERE cat_c3 = 303)                                               34964 non-null  float64
#  79   MAX(transactions.float_c16 WHERE cat_c2 = 4)                                                 34964 non-null  float64
#  80   MAX(transactions.float_c17 WHERE cat_c2 = 15)                                                34964 non-null  float64
#  81   MAX(transactions.float_c17 WHERE fl_c13 = True)                                              34964 non-null  float64
#  82   MAX(transactions.float_c17 WHERE cat_c3 = 305)                                               34964 non-null  float64
#  83   MAX(transactions.float_c17 WHERE cat_c2 = 14)                                                34964 non-null  float64
#  84   MAX(transactions.float_c18 WHERE fl_c13 = True)                                              34964 non-null  float64
#  85   MAX(transactions.float_c18 WHERE cat_c3 = 305)                                               34964 non-null  float64
#  86   MAX(transactions.float_c18 WHERE cat_c3 = 303)                                               34964 non-null  float64
#  87   MAX(transactions.float_c18 WHERE cat_c3 = 209)                                               34964 non-null  float64
#  88   MAX(transactions.float_c18 WHERE fl_c14 = True)                                              34964 non-null  float64
#  89   MAX(transactions.float_c18 WHERE tran_date_is_weekend = True)                                34964 non-null  float64
#  90   MAX(transactions.float_c20 WHERE fl_c13 = True)                                              34964 non-null  float64
#  91   MAX(transactions.float_c20 WHERE cat_c3 = 305)                                               34964 non-null  float64
#  92   MAX(transactions.float_c20 WHERE cat_c3 = 303)                                               34964 non-null  float64
#  93   MAX(transactions.float_c20 WHERE cat_c2 = 4)                                                 34964 non-null  float64
#  94   MAX(transactions.float_c20 WHERE cat_c3 = 209)                                               34964 non-null  float64
#  95   MAX(transactions.float_c20 WHERE fl_c14 = True)                                              34964 non-null  float64
#  96   MAX(transactions.float_c21 WHERE cat_c2 = 15)                                                34964 non-null  float64
#  97   MAX(transactions.int_c19 WHERE cat_c2 = 15)                                                  34964 non-null  float64
#  98   MAX(transactions.int_c19 WHERE fl_c13 = True)                                                34964 non-null  float64
#  99   MAX(transactions.int_c19 WHERE cat_c3 = 305)                                                 34964 non-null  float64
#  100  MAX(transactions.int_c19 WHERE cat_c3 = 303)                                                 34964 non-null  float64
#  101  MAX(transactions.int_c19 WHERE cat_c2 = 4)                                                   34964 non-null  float64
#  102  MAX(transactions.int_c19 WHERE fl_c14 = True)                                                34964 non-null  float64
#  103  MAX(transactions.int_c19 WHERE cat_c3 = 314)                                                 34964 non-null  float64
#  104  MAX(transactions.int_c19 WHERE tran_date_is_weekend = True)                                  34964 non-null  float64
#  105  MEAN(transactions.float_c16 WHERE fl_c13 = True)                                             34964 non-null  float64
#  106  MEAN(transactions.float_c16 WHERE fl_c14 = False)                                            34964 non-null  float64
#  107  MEAN(transactions.float_c17 WHERE fl_c13 = True)                                             34964 non-null  float64
#  108  MEAN(transactions.float_c17 WHERE cat_c3 = 305)                                              34964 non-null  float64
#  109  MEAN(transactions.float_c17 WHERE fl_c12 = False)                                            34964 non-null  float64
#  110  MEAN(transactions.float_c17 WHERE tran_date_is_weekend = True)                               34964 non-null  float64
#  111  MEAN(transactions.float_c17 WHERE cat_c2 = 14)                                               34964 non-null  float64
#  112  MEAN(transactions.float_c18 WHERE cat_c2 = 15)                                               34964 non-null  float64
#  113  MEAN(transactions.float_c18 WHERE fl_c13 = True)                                             34964 non-null  float64
#  114  MEAN(transactions.float_c18 WHERE cat_c3 = 305)                                              34964 non-null  float64
#  115  MEAN(transactions.float_c18 WHERE cat_c3 = 303)                                              34964 non-null  float64
#  116  MEAN(transactions.float_c18 WHERE cat_c2 = 4)                                                34964 non-null  float64
#  117  MEAN(transactions.float_c18 WHERE fl_c14 = True)                                             34964 non-null  float64
#  118  MEAN(transactions.float_c20 WHERE fl_c13 = True)                                             34964 non-null  float64
#  119  MEAN(transactions.float_c20 WHERE int_c19 = 1)                                               34964 non-null  float64
#  120  MEAN(transactions.float_c20 WHERE fl_c12 = False)                                            34964 non-null  float64
#  121  MEAN(transactions.float_c20 WHERE cat_c2 = 4)                                                34964 non-null  float64
#  122  MEAN(transactions.float_c20 WHERE fl_c14 = True)                                             34964 non-null  float64
#  123  MEAN(transactions.float_c21 WHERE tran_date_is_weekend = True)                               34964 non-null  float64
#  124  MEAN(transactions.int_c19 WHERE cat_c2 = 15)                                                 34964 non-null  float64
#  125  MEAN(transactions.int_c19 WHERE cat_c3 = 305)                                                34964 non-null  float64
#  126  MEAN(transactions.int_c19 WHERE cat_c3 = 303)                                                34964 non-null  float64
#  127  MEAN(transactions.int_c19 WHERE cat_c3 = 314)                                                34964 non-null  float64
#  128  MEAN(transactions.int_c19 WHERE cat_c2 = 14)                                                 34964 non-null  float64
#  129  MEAN(transactions.tran_date_day_of_month_cos WHERE cat_c2 = 15)                              34964 non-null  float64
#  130  MEAN(transactions.tran_date_day_of_month_cos WHERE fl_c13 = True)                            34964 non-null  float64
#  131  MEAN(transactions.tran_date_day_of_month_cos WHERE cat_c3 = 305)                             34964 non-null  float64
#  132  MEAN(transactions.tran_date_day_of_month_cos WHERE cat_c3 = 303)                             34964 non-null  float64
#  133  MEAN(transactions.tran_date_day_of_month_cos WHERE cat_c2 = 4)                               34964 non-null  float64
#  134  MEAN(transactions.tran_date_day_of_month_cos WHERE tran_date_is_weekend = True)              34964 non-null  float64
#  135  MEAN(transactions.tran_date_day_of_month_sin WHERE cat_c2 = 15)                              34964 non-null  float64
#  136  MEAN(transactions.tran_date_day_of_month_sin WHERE fl_c13 = True)                            34964 non-null  float64
#  137  MEAN(transactions.tran_date_day_of_month_sin WHERE cat_c3 = 305)                             34964 non-null  float64
#  138  MEAN(transactions.tran_date_day_of_month_sin WHERE cat_c3 = 303)                             34964 non-null  float64
#  139  MEAN(transactions.tran_date_day_of_month_sin WHERE cat_c2 = 4)                               34964 non-null  float64
#  140  MEAN(transactions.tran_date_day_of_month_sin WHERE tran_date_is_weekend = True)              34964 non-null  float64
#  141  MEAN(transactions.tran_date_day_of_week_cos WHERE cat_c2 = 15)                               34964 non-null  float64
#  142  MEAN(transactions.tran_date_day_of_week_cos WHERE fl_c13 = True)                             34964 non-null  float64
#  143  MEAN(transactions.tran_date_day_of_week_cos WHERE cat_c3 = 305)                              34964 non-null  float64
#  144  MEAN(transactions.tran_date_day_of_week_cos WHERE cat_c3 = 303)                              34964 non-null  float64
#  145  MEAN(transactions.tran_date_day_of_week_cos WHERE cat_c2 = 4)                                34964 non-null  float64
#  146  MEAN(transactions.tran_date_day_of_week_cos WHERE tran_date_is_weekend = True)               34964 non-null  float64
#  147  MEAN(transactions.tran_date_day_of_week_sin WHERE cat_c2 = 15)                               34964 non-null  float64
#  148  MEAN(transactions.tran_date_day_of_week_sin WHERE fl_c13 = True)                             34964 non-null  float64
#  149  MEAN(transactions.tran_date_day_of_week_sin WHERE cat_c3 = 305)                              34964 non-null  float64
#  150  MEAN(transactions.tran_date_day_of_week_sin WHERE cat_c3 = 303)                              34964 non-null  float64
#  151  MEAN(transactions.tran_date_day_of_week_sin WHERE cat_c2 = 4)                                34964 non-null  float64
#  152  MEAN(transactions.tran_date_day_of_week_sin WHERE tran_date_is_weekend = True)               34964 non-null  float64
#  153  MIN(transactions.float_c16 WHERE fl_c13 = True)                                              34964 non-null  float64
#  154  MIN(transactions.float_c16 WHERE cat_c2 = 4)                                                 34964 non-null  float64
#  155  MIN(transactions.float_c16 WHERE fl_c14 = True)                                              34964 non-null  float64
#  156  MIN(transactions.float_c16 WHERE tran_date_is_weekend = True)                                34964 non-null  float64
#  157  MIN(transactions.float_c17 WHERE cat_c2 = 15)                                                34964 non-null  float64
#  158  MIN(transactions.float_c18 WHERE cat_c2 = 15)                                                34964 non-null  float64
#  159  MIN(transactions.float_c18 WHERE int_c19 = 1)                                                34964 non-null  float64
#  160  MIN(transactions.float_c18 WHERE cat_c3 = 305)                                               34964 non-null  float64
#  161  MIN(transactions.float_c18 WHERE cat_c2 = 4)                                                 34964 non-null  float64
#  162  MIN(transactions.float_c18 WHERE int_c19 = -1)                                               34964 non-null  float64
#  163  MIN(transactions.float_c18 WHERE tran_date_is_weekend = True)                                34964 non-null  float64
#  164  MIN(transactions.float_c18 WHERE tran_date_is_weekend = False)                               34964 non-null  float64
#  165  MIN(transactions.float_c20 WHERE int_c19 = 1)                                                34964 non-null  float64
#  166  MIN(transactions.float_c20 WHERE fl_c14 = False)                                             34964 non-null  float64
#  167  MIN(transactions.float_c20 WHERE cat_c3 = 305)                                               34964 non-null  float64
#  168  MIN(transactions.float_c20 WHERE cat_c3 = 303)                                               34964 non-null  float64
#  169  MIN(transactions.float_c20 WHERE cat_c2 = 4)                                                 34964 non-null  float64
#  170  MIN(transactions.float_c20 WHERE int_c19 = -1)                                               34964 non-null  float64
#  171  MIN(transactions.float_c20 WHERE tran_date_is_weekend = True)                                34964 non-null  float64
#  172  MIN(transactions.float_c20 WHERE tran_date_is_weekend = False)                               34964 non-null  float64
#  173  MIN(transactions.float_c21 WHERE fl_c14 = True)                                              34964 non-null  float64
#  174  MIN(transactions.float_c21 WHERE cat_c3 = 314)                                               34964 non-null  float64
#  175  MIN(transactions.int_c19 WHERE cat_c3 = 305)                                                 34964 non-null  float64
#  176  MIN(transactions.int_c19 WHERE fl_c12 = False)                                               34964 non-null  float64
#  177  MIN(transactions.int_c19 WHERE tran_date_is_weekend = True)                                  34964 non-null  float64
#  178  MIN(transactions.int_c19 WHERE cat_c2 = 14)                                                  34964 non-null  float64
#  179  STD(transactions.float_c16 WHERE tran_date_is_weekend = True)                                34964 non-null  float64
#  180  STD(transactions.float_c20 WHERE cat_c2 = 15)                                                34964 non-null  float64
#  181  STD(transactions.float_c20 WHERE tran_date_is_weekend = True)                                34964 non-null  float64
#  182  STD(transactions.float_c21 WHERE int_c19 = -1)                                               34964 non-null  float64
#  183  STD(transactions.int_c19 WHERE cat_c3 = 303)                                                 34964 non-null  float64
#  184  STD(transactions.int_c19 WHERE cat_c2 = 4)                                                   34964 non-null  float64
#  185  STD(transactions.int_c19 WHERE fl_c13 = False)                                               34964 non-null  float64
#  186  STD(transactions.int_c19 WHERE cat_c3 = 209)                                                 34964 non-null  float64
#  187  STD(transactions.int_c19 WHERE tran_date_is_weekend = True)                                  34964 non-null  float64
#  188  SUM(transactions.float_c16 WHERE int_c19 = 1)                                                34964 non-null  float64
#  189  SUM(transactions.float_c16 WHERE fl_c14 = False)                                             34964 non-null  float64
#  190  SUM(transactions.float_c17 WHERE cat_c2 = 15)                                                34964 non-null  float64
#  191  SUM(transactions.float_c17 WHERE fl_c13 = True)                                              34964 non-null  float64
#  192  SUM(transactions.float_c17 WHERE cat_c3 = 305)                                               34964 non-null  float64
#  193  SUM(transactions.float_c18 WHERE cat_c3 = 209)                                               34964 non-null  float64
#  194  SUM(transactions.float_c18 WHERE fl_c14 = True)                                              34964 non-null  float64
#  195  SUM(transactions.int_c19 WHERE cat_c3 = 305)                                                 34964 non-null  float64
#  196  TIME_SINCE_LAST(transactions.tran_date WHERE int_c19 = 1, unit=days)                         34964 non-null  float64
#  197  TIME_SINCE_LAST(transactions.tran_date WHERE fl_c14 = False, unit=days)                      34964 non-null  float64
#  198  TIME_SINCE_LAST(transactions.tran_date WHERE cat_c3 = 303, unit=days)                        34964 non-null  float64
#  199  TIME_SINCE_LAST(transactions.tran_date WHERE fl_c12 = False, unit=days)                      34964 non-null  float64
#  200  TIME_SINCE_LAST(transactions.tran_date WHERE int_c19 = -1, unit=days)                        34964 non-null  float64
#  201  TIME_SINCE_LAST(transactions.tran_date WHERE fl_c13 = False, unit=days)                      34964 non-null  float64
#  202  TIME_SINCE_LAST(transactions.tran_date WHERE tran_date_is_weekend = False, unit=days)        34964 non-null  float64
#  203  COUNT(activities WHERE cat_c10 = False)                                                      34964 non-null  int64
#  204  COUNT(activities WHERE cat_c4 = 2)                                                           34964 non-null  int64
#  205  COUNT(activities WHERE cat_c6 = 2)                                                           34964 non-null  int64
#  206  COUNT(activities WHERE cat_c9 = 2)                                                           34964 non-null  int64
#  207  COUNT(activities WHERE cat_c10 = True)                                                       34964 non-null  int64
#  208  COUNT(activities WHERE cat_c8 = False)                                                       34964 non-null  int64
#  209  COUNT(activities WHERE cat_c6 = 3)                                                           34964 non-null  int64
#  210  COUNT(activities WHERE cat_c9 = 1)                                                           34964 non-null  int64
#  211  MAX(activities.float_c11 WHERE cat_c6 = 2)                                                   34964 non-null  float64
#  212  MAX(activities.float_c11 WHERE cat_c9 = 2)                                                   34964 non-null  float64
#  213  MAX(activities.float_c11 WHERE cat_c6 = 3)                                                   34964 non-null  float64
#  214  MAX(activities.float_c12 WHERE cat_c10 = False)                                              34964 non-null  float64
#  215  MAX(activities.float_c12 WHERE cat_c4 = 2)                                                   34964 non-null  float64
#  216  MAX(activities.float_c12 WHERE cat_c10 = True)                                               34964 non-null  float64
#  217  MAX(activities.float_c12 WHERE activity_date_is_weekend = True)                              34964 non-null  float64
#  218  MAX(activities.float_c12 WHERE cat_c9 = 1)                                                   34964 non-null  float64
#  219  MAX(activities.float_c14 WHERE cat_c8 = True)                                                34964 non-null  float64
#  220  MEAN(activities.activity_date_day_of_month_cos WHERE activity_date_is_weekend = False)       34964 non-null  float64
#  221  MEAN(activities.activity_date_day_of_month_cos WHERE cat_c10 = False)                        34964 non-null  float64
#  222  MEAN(activities.activity_date_day_of_month_cos WHERE cat_c4 = 2)                             34964 non-null  float64
#  223  MEAN(activities.activity_date_day_of_month_cos WHERE cat_c6 = 2)                             34964 non-null  float64
#  224  MEAN(activities.activity_date_day_of_month_cos WHERE cat_c9 = 2)                             34964 non-null  float64
#  225  MEAN(activities.activity_date_day_of_month_cos WHERE cat_c8 = False)                         34964 non-null  float64
#  226  MEAN(activities.activity_date_day_of_month_cos WHERE activity_date_is_weekend = True)        34964 non-null  float64
#  227  MEAN(activities.activity_date_day_of_month_cos WHERE cat_c6 = 3)                             34964 non-null  float64
#  228  MEAN(activities.activity_date_day_of_month_cos WHERE cat_c9 = 1)                             34964 non-null  float64
#  229  MEAN(activities.activity_date_day_of_month_sin WHERE cat_c10 = False)                        34964 non-null  float64
#  230  MEAN(activities.activity_date_day_of_month_sin WHERE cat_c4 = 2)                             34964 non-null  float64
#  231  MEAN(activities.activity_date_day_of_month_sin WHERE cat_c8 = True)                          34964 non-null  float64
#  232  MEAN(activities.activity_date_day_of_month_sin WHERE cat_c6 = 2)                             34964 non-null  float64
#  233  MEAN(activities.activity_date_day_of_month_sin WHERE cat_c9 = 2)                             34964 non-null  float64
#  234  MEAN(activities.activity_date_day_of_month_sin WHERE cat_c8 = False)                         34964 non-null  float64
#  235  MEAN(activities.activity_date_day_of_month_sin WHERE activity_date_is_weekend = True)        34964 non-null  float64
#  236  MEAN(activities.activity_date_day_of_month_sin WHERE cat_c6 = 3)                             34964 non-null  float64
#  237  MEAN(activities.activity_date_day_of_month_sin WHERE cat_c9 = 1)                             34964 non-null  float64
#  238  MEAN(activities.activity_date_day_of_week_cos WHERE cat_c10 = False)                         34964 non-null  float64
#  239  MEAN(activities.activity_date_day_of_week_cos WHERE cat_c4 = 2)                              34964 non-null  float64
#  240  MEAN(activities.activity_date_day_of_week_cos WHERE cat_c6 = 2)                              34964 non-null  float64
#  241  MEAN(activities.activity_date_day_of_week_cos WHERE cat_c9 = 2)                              34964 non-null  float64
#  242  MEAN(activities.activity_date_day_of_week_cos WHERE cat_c8 = False)                          34964 non-null  float64
#  243  MEAN(activities.activity_date_day_of_week_cos WHERE activity_date_is_weekend = True)         34964 non-null  float64
#  244  MEAN(activities.activity_date_day_of_week_cos WHERE cat_c6 = 3)                              34964 non-null  float64
#  245  MEAN(activities.activity_date_day_of_week_cos WHERE cat_c9 = 1)                              34964 non-null  float64
#  246  MEAN(activities.activity_date_day_of_week_sin WHERE cat_c10 = False)                         34964 non-null  float64
#  247  MEAN(activities.activity_date_day_of_week_sin WHERE cat_c4 = 2)                              34964 non-null  float64
#  248  MEAN(activities.activity_date_day_of_week_sin WHERE cat_c6 = 2)                              34964 non-null  float64
#  249  MEAN(activities.activity_date_day_of_week_sin WHERE cat_c9 = 2)                              34964 non-null  float64
#  250  MEAN(activities.activity_date_day_of_week_sin WHERE cat_c8 = False)                          34964 non-null  float64
#  251  MEAN(activities.activity_date_day_of_week_sin WHERE activity_date_is_weekend = True)         34964 non-null  float64
#  252  MEAN(activities.activity_date_day_of_week_sin WHERE cat_c6 = 3)                              34964 non-null  float64
#  253  MEAN(activities.activity_date_day_of_week_sin WHERE cat_c9 = 1)                              34964 non-null  float64
#  254  MEAN(activities.float_c11 WHERE cat_c8 = False)                                              34964 non-null  float64
#  255  MEAN(activities.float_c14 WHERE cat_c8 = False)                                              34964 non-null  float64
#  256  MIN(activities.float_c12 WHERE cat_c10 = False)                                              34964 non-null  float64
#  257  MIN(activities.float_c12 WHERE cat_c4 = 2)                                                   34964 non-null  float64
#  258  MIN(activities.float_c12 WHERE cat_c6 = 2)                                                   34964 non-null  float64
#  259  MIN(activities.float_c12 WHERE cat_c9 = 2)                                                   34964 non-null  float64
#  260  MIN(activities.float_c12 WHERE cat_c8 = False)                                               34964 non-null  float64
#  261  MIN(activities.float_c12 WHERE cat_c6 = 3)                                                   34964 non-null  float64
#  262  MIN(activities.float_c14 WHERE cat_c10 = False)                                              34964 non-null  float64
#  263  MIN(activities.float_c14 WHERE cat_c4 = 2)                                                   34964 non-null  float64
#  264  MIN(activities.float_c14 WHERE cat_c8 = True)                                                34964 non-null  float64
#  265  MIN(activities.float_c14 WHERE cat_c6 = 2)                                                   34964 non-null  float64
#  266  MIN(activities.float_c14 WHERE cat_c9 = 2)                                                   34964 non-null  float64
#  267  MIN(activities.float_c14 WHERE cat_c6 = 3)                                                   34964 non-null  float64
#  268  STD(activities.float_c11 WHERE cat_c6 = 2)                                                   34964 non-null  float64
#  269  STD(activities.float_c11 WHERE cat_c8 = False)                                               34964 non-null  float64
#  270  STD(activities.float_c11 WHERE cat_c6 = 3)                                                   34964 non-null  float64
#  271  STD(activities.float_c11 WHERE cat_c9 = 1)                                                   34964 non-null  float64
#  272  STD(activities.float_c12 WHERE activity_date_is_weekend = False)                             34964 non-null  float64
#  273  STD(activities.float_c12 WHERE activity_date_is_weekend = True)                              34964 non-null  float64
#  274  SUM(activities.float_c12 WHERE cat_c8 = True)                                                34964 non-null  float64
#  275  SUM(activities.float_c14 WHERE cat_c4 = 2)                                                   34964 non-null  float64
#  276  SUM(activities.float_c14 WHERE cat_c8 = True)                                                34964 non-null  float64
#  277  TIME_SINCE_LAST(activities.activity_date WHERE activity_date_is_weekend = False, unit=days)  34964 non-null  float64
#  278  TIME_SINCE_LAST(activities.activity_date WHERE cat_c4 = 1, unit=days)                        34964 non-null  float64
#  279  TIME_SINCE_LAST(activities.activity_date WHERE cat_c10 = True, unit=days)                    34964 non-null  float64
#  280  TIME_SINCE_LAST(activities.activity_date WHERE activity_date_is_weekend = True, unit=days)   34964 non-null  float64
#  281  COUNT(comms WHERE cat_c3 = 7)                                                                34964 non-null  int64
#  282  COUNT(comms WHERE cat_c2 = S3769)                                                            34964 non-null  int64
#  283  COUNT(comms WHERE cat_c3 = 3)                                                                34964 non-null  int64
#  284  COUNT(comms WHERE cat_c5 = 7)                                                                34964 non-null  int64
#  285  MEAN(comms.contact_date_day_of_month_cos WHERE cat_c3 = 7)                                   34964 non-null  float64
#  286  MEAN(comms.contact_date_day_of_month_cos WHERE cat_c2 = S3769)                               34964 non-null  float64
#  287  MEAN(comms.contact_date_day_of_month_cos WHERE contact_date_is_weekend = False)              34964 non-null  float64
#  288  MEAN(comms.contact_date_day_of_month_cos WHERE cat_c3 = 3)                                   34964 non-null  float64
#  289  MEAN(comms.contact_date_day_of_month_cos WHERE cat_c5 = 7)                                   34964 non-null  float64
#  290  MEAN(comms.contact_date_day_of_month_sin WHERE cat_c3 = 7)                                   34964 non-null  float64
#  291  MEAN(comms.contact_date_day_of_month_sin WHERE cat_c2 = S3769)                               34964 non-null  float64
#  292  MEAN(comms.contact_date_day_of_month_sin WHERE cat_c3 = 3)                                   34964 non-null  float64
#  293  MEAN(comms.contact_date_day_of_month_sin WHERE cat_c5 = 7)                                   34964 non-null  float64
#  294  MEAN(comms.contact_date_day_of_month_sin WHERE cat_c4 = 2)                                   34964 non-null  float64
#  295  MEAN(comms.contact_date_day_of_week_cos WHERE cat_c3 = 7)                                    34964 non-null  float64
#  296  MEAN(comms.contact_date_day_of_week_cos WHERE cat_c2 = S3769)                                34964 non-null  float64
#  297  MEAN(comms.contact_date_day_of_week_cos WHERE contact_date_is_weekend = False)               34964 non-null  float64
#  298  MEAN(comms.contact_date_day_of_week_cos WHERE cat_c3 = 3)                                    34964 non-null  float64
#  299  MEAN(comms.contact_date_day_of_week_cos WHERE cat_c2 = S3677)                                34964 non-null  float64
#  300  MEAN(comms.contact_date_day_of_week_cos WHERE cat_c5 = 7)                                    34964 non-null  float64
#  301  MEAN(comms.contact_date_day_of_week_cos WHERE contact_date_is_weekend = True)                34964 non-null  float64
#  302  MEAN(comms.contact_date_day_of_week_cos WHERE cat_c4 = 2)                                    34964 non-null  float64
#  303  MEAN(comms.contact_date_day_of_week_sin WHERE cat_c3 = 7)                                    34964 non-null  float64
#  304  MEAN(comms.contact_date_day_of_week_sin WHERE cat_c2 = S3769)                                34964 non-null  float64
#  305  MEAN(comms.contact_date_day_of_week_sin WHERE contact_date_is_weekend = False)               34964 non-null  float64
#  306  MEAN(comms.contact_date_day_of_week_sin WHERE cat_c3 = 3)                                    34964 non-null  float64
#  307  MEAN(comms.contact_date_day_of_week_sin WHERE cat_c2 = S3677)                                34964 non-null  float64
#  308  MEAN(comms.contact_date_day_of_week_sin WHERE cat_c5 = 7)                                    34964 non-null  float64
#  309  MEAN(comms.contact_date_day_of_week_sin WHERE cat_c4 = 2)                                    34964 non-null  float64
#  310  TIME_SINCE_LAST(comms.contact_date WHERE cat_c3 = 7, unit=days)                              34964 non-null  float64
#  311  TIME_SINCE_LAST(comms.contact_date WHERE cat_c2 = S3769, unit=days)                          34964 non-null  float64
#  312  TIME_SINCE_LAST(comms.contact_date WHERE cat_c3 = 3, unit=days)                              34964 non-null  float64
#  313  TIME_SINCE_LAST(comms.contact_date WHERE cat_c2 = S3677, unit=days)                          34964 non-null  float64
#  314  TIME_SINCE_LAST(comms.contact_date WHERE cat_c5 = 7, unit=days)                              34964 non-null  float64
#  315  TIME_SINCE_LAST(comms.contact_date WHERE contact_date_is_weekend = True, unit=days)          34964 non-null  float64
#  316  TIME_SINCE_LAST(comms.contact_date WHERE cat_c4 = 2, unit=days)                              34964 non-null  float64
#  317  MEAN(transactions.float_c16)__30_days                                                        34964 non-null  float64
#  318  MEAN(transactions.float_c17)__30_days                                                        34964 non-null  float64
#  319  MEAN(transactions.float_c18)__30_days                                                        34964 non-null  float64
#  320  MEAN(transactions.tran_date_day_of_month_cos)__30_days                                       34964 non-null  float64
#  321  MEAN(transactions.tran_date_day_of_month_sin)__30_days                                       34964 non-null  float64
#  322  MEAN(transactions.tran_date_day_of_week_cos)__30_days                                        34964 non-null  float64
#  323  MEAN(transactions.tran_date_day_of_week_sin)__30_days                                        34964 non-null  float64
#  324  PERCENT_TRUE(transactions.fl_c6)__30_days                                                    34964 non-null  float64
#  325  PERCENT_TRUE(transactions.fl_c7)__30_days                                                    34964 non-null  float64
#  326  PERCENT_TRUE(transactions.tran_date_is_weekend)__30_days                                     34964 non-null  float64
#  327  SUM(transactions.float_c17)__30_days                                                         34964 non-null  float64
#  328  COUNT(transactions WHERE cat_c2 = 15)__30_days                                               34964 non-null  int64
#  329  SUM(transactions.float_c16 WHERE fl_c13 = True)__30_days                                     34964 non-null  float64
#  330  SUM(transactions.float_c16 WHERE int_c19 = 1)__30_days                                       34964 non-null  float64
#  331  SUM(transactions.float_c17 WHERE int_c19 = 1)__30_days                                       34964 non-null  float64
#  332  SUM(transactions.float_c17 WHERE cat_c3 = 305)__30_days                                      34964 non-null  float64
#  333  SUM(transactions.float_c17 WHERE cat_c2 = 14)__30_days                                       34964 non-null  float64
#  334  SUM(transactions.float_c18 WHERE fl_c13 = True)__30_days                                     34964 non-null  float64
#  335  SUM(transactions.float_c18 WHERE cat_c3 = 305)__30_days                                      34964 non-null  float64
#  336  SUM(transactions.float_c18 WHERE cat_c3 = 303)__30_days                                      34964 non-null  float64
#  337  SUM(transactions.float_c20 WHERE cat_c2 = 15)__30_days                                       34964 non-null  float64
#  338  SUM(transactions.float_c20 WHERE fl_c13 = True)__30_days                                     34964 non-null  float64
#  339  SUM(transactions.float_c20 WHERE cat_c3 = 305)__30_days                                      34964 non-null  float64
#  340  SUM(transactions.float_c20 WHERE cat_c3 = 303)__30_days                                      34964 non-null  float64
#  341  SUM(transactions.float_c20 WHERE cat_c2 = 4)__30_days                                        34964 non-null  float64
#  342  PERCENT_TRUE(transactions.fl_c7)__90_days                                                    34964 non-null  float64
#  343  PERCENT_TRUE(transactions.tran_date_is_weekend)__90_days                                     34964 non-null  float64
#  344  SUM(transactions.float_c17 WHERE fl_c12 = False)__90_days                                    34964 non-null  float64
#  345  SUM(transactions.float_c17 WHERE cat_c2 = 14)__90_days                                       34964 non-null  float64
#  346  MEAN(activities.activity_date_day_of_week_cos)__30_days                                      34964 non-null  float64
#  347  MEAN(activities.activity_date_day_of_week_sin)__30_days                                      34964 non-null  float64
#  348  PERCENT_TRUE(activities.activity_date_is_weekend)__30_days                                   34964 non-null  float64
#  349  COUNT(activities WHERE cat_c4 = 2)__30_days                                                  34964 non-null  int64
#  350  SUM(activities.float_c11 WHERE cat_c10 = False)__30_days                                     34964 non-null  float64
#  351  SUM(activities.float_c11 WHERE cat_c9 = 2)__30_days                                          34964 non-null  float64
#  352  SUM(activities.float_c11 WHERE cat_c8 = False)__30_days                                      34964 non-null  float64
#  353  SUM(activities.float_c12 WHERE activity_date_is_weekend = True)__30_days                     34964 non-null  float64
#  354  SUM(activities.float_c14 WHERE cat_c10 = False)__30_days                                     34964 non-null  float64
#  355  SUM(activities.float_c14 WHERE cat_c8 = False)__30_days                                      34964 non-null  float64
#  356  MEAN(activities.activity_date_day_of_month_cos)__90_days                                     34964 non-null  float64
#  357  MEAN(activities.activity_date_day_of_month_sin)__90_days                                     34964 non-null  float64
#  358  MEAN(activities.activity_date_day_of_week_sin)__90_days                                      34964 non-null  float64
#  359  COUNT(comms WHERE cat_c3 = 7)__30_days                                                       34964 non-null  int64
#  360  COUNT(comms WHERE cat_c3 = 3)__30_days                                                       34964 non-null  int64
#  361  device_id_nunique                                                                            34964 non-null  float64
#  362  INTERACTION_activity_per_trans                                                               34964 non-null  float64
#  363  INTERACTION_contact_per_trans                                                                34964 non-null  float64
#  364  INTERACTION_contact_per_activity                                                             34964 non-null  float64
#  365  BALANCE_net_flow                                                                             34964 non-null  float64
#  366  BALANCE_savings_potential                                                                    34964 non-null  float64
#  367  tran_date_gap_days__median                                                                   34964 non-null  float64
#  368  tran_date_gap_days__mean                                                                     34964 non-null  float64
#  369  tran_date_gap_days__maximum                                                                  34964 non-null  float64
#  370  tran_date_gap_days__skewness                                                                 34964 non-null  float64
#  371  tran_date_gap_days__linear_trend__attr_"slope"                                               34964 non-null  float64
#  372  tran_date_gap_days__approximate_entropy__m_2__r_0.25                                         34964 non-null  float64
#  373  tran_date_gap_days__ratio_beyond_r_sigma__r_2                                                34964 non-null  float64
#  374  tran_date_gap_days__autocorrelation__lag_1                                                   34964 non-null  float64
#  375  tran_date_gap_days__longest_strike_above_mean                                                34964 non-null  float64
#  376  tran_date_gap_days__longest_strike_below_mean                                                34964 non-null  float64
#  377  float_c18_diff__median                                                                       34964 non-null  float64
#  378  float_c18_diff__skewness                                                                     34964 non-null  float64
#  379  float_c18_diff__quantile__q_0.25                                                             34964 non-null  float64
#  380  float_c18_diff__quantile__q_0.75                                                             34964 non-null  float64
#  381  float_c18_diff__approximate_entropy__m_2__r_0.25                                             34964 non-null  float64
#  382  float_c18_diff__ratio_beyond_r_sigma__r_2                                                    34964 non-null  float64
#  383  float_c18_diff__autocorrelation__lag_1                                                       34964 non-null  float64
#  384  float_c18_diff__longest_strike_above_mean                                                    34964 non-null  float64
#  385  float_c18_diff__longest_strike_below_mean                                                    34964 non-null  float64
#  386  activity_date_gap_days__median                                                               34964 non-null  float64
#  387  activity_date_gap_days__mean                                                                 34964 non-null  float64
#  388  activity_date_gap_days__maximum                                                              34964 non-null  float64
#  389  activity_date_gap_days__skewness                                                             34964 non-null  float64
#  390  activity_date_gap_days__linear_trend__attr_"slope"                                           34964 non-null  float64
#  391  activity_date_gap_days__approximate_entropy__m_2__r_0.25                                     34964 non-null  float64
#  392  activity_date_gap_days__ratio_beyond_r_sigma__r_2                                            34964 non-null  float64
#  393  activity_date_gap_days__autocorrelation__lag_1                                               34964 non-null  float64
#  394  activity_date_gap_days__longest_strike_above_mean                                            34964 non-null  float64
#  395  activity_date_gap_days__longest_strike_below_mean                                            34964 non-null  float64
#  396  contact_date_gap_days__maximum                                                               34964 non-null  float64
#  397  contact_date_gap_days__skewness                                                              34964 non-null  float64
#  398  contact_date_gap_days__quantile__q_0.25                                                      34964 non-null  float64
#  399  contact_date_gap_days__linear_trend__attr_"slope"                                            34964 non-null  float64
#  400  contact_date_gap_days__ratio_beyond_r_sigma__r_2                                             34964 non-null  float64
#  401  contact_date_gap_days__autocorrelation__lag_1                                                34964 non-null  float64
#  402  contact_date_gap_days__longest_strike_above_mean                                             34964 non-null  float64
#  403  STD(transactions.float_c16 WHERE cat_c3 = 305)_na                                            34964 non-null  int64
#  404  FIRST(activities.activity_date)_days                                                         34964 non-null  int64
#  405  MONTH(communication_month)_sin                                                               34964 non-null  float64
#  406  MODE(transactions.cat_c2)_14                                                                 34964 non-null  int64
#  407  MODE(transactions.cat_c2)_Rare                                                               34964 non-null  int64
#  408  MODE(transactions.cat_c2)_4                                                                  34964 non-null  int64
#  409  MODE(transactions.cat_c2)_15                                                                 34964 non-null  int64
#  410  MODE(transactions.cat_c2)_1                                                                  34964 non-null  int64
#  411  MODE(transactions.cat_c3)_305                                                                34964 non-null  int64
#  412  MODE(transactions.cat_c3)_314                                                                34964 non-null  int64
#  413  MODE(transactions.cat_c3)_Rare                                                               34964 non-null  int64
#  414  MODE(transactions.cat_c3)_303                                                                34964 non-null  int64
#  415  MODE(transactions.cat_c3)_312                                                                34964 non-null  int64
#  416  MODE(activities.cat_c6)_4                                                                    34964 non-null  int64
#  417  MODE(activities.cat_c6)_Rare                                                                 34964 non-null  int64
#  418  MODE(activities.cat_c6)_8                                                                    34964 non-null  int64
#  419  MODE(comms.cat_c2)_S3769                                                                     34964 non-null  int64
#  420  MODE(comms.cat_c2)_Rare                                                                      34964 non-null  int64
#  421  MODE(comms.cat_c2)_S27888                                                                    34964 non-null  int64
#  422  MODE(comms.cat_c2)_S3563                                                                     34964 non-null  int64
#  423  MODE(comms.cat_c4)_1                                                                         34964 non-null  int64
# dtypes: float64(377), int64(47)
# memory usage: 113.1 MB
# None
#        COUNT(transactions)  ENTROPY(transactions.cat_c2)  \
# count                34964                         34964
# mean                   447                             1
# std                    474                             0
# min                      2                             0
# 25%                    122                             1
# 50%                    309                             1
# 75%                    616                             1
# max                   8721                             2
#
#        ENTROPY(transactions.cat_c4)  KURTOSIS(transactions.float_c16)  \
# count                         34964                             34964
# mean                              0                                78
# std                               0                               146
# min                               0                                -2
# 25%                               0                                 0
# 50%                               0                                27
# 75%                               0                                93
# max                               2                              3572
#
#        KURTOSIS(transactions.float_c17)  KURTOSIS(transactions.float_c18)  \
# count                             34964                             34964
# mean                                132                                42
# std                                 225                                57
# min                                  -2                                -2
# 25%                                   0                                11
# 50%                                  34                                25
# 75%                                 176                                51
# max                                2741                              1350
#
#        KURTOSIS(transactions.float_c20)  KURTOSIS(transactions.int_c19)  \
# count                             34964                           34964
# mean                                 16                               0
# std                                 112                               2
# min                                  -2                              -2
# 25%                                   0                              -1
# 50%                                   0                              -1
# 75%                                   0                               0
# max                                3767                             259
#
#        MAX(transactions.float_c16)  MAX(transactions.float_c17)  ...  \
# count                        34964                        34964  ...
# mean                             1                            4  ...
# std                              4                           19  ...
# min                              0                            0  ...
# 25%                              0                            0  ...
# 50%                              0                            1  ...
# 75%                              1                            4  ...
# max                            413                         2294  ...
#
#        MODE(transactions.cat_c3)_303  MODE(transactions.cat_c3)_312  \
# count                          34964                          34964
# mean                               0                              0
# std                                0                              0
# min                                0                              0
# 25%                                0                              0
# 50%                                0                              0
# 75%                                0                              0
# max                                1                              1
#
#        MODE(activities.cat_c6)_4  MODE(activities.cat_c6)_Rare  \
# count                      34964                         34964
# mean                           0                             0
# std                            0                             0
# min                            0                             0
# 25%                            0                             0
# 50%                            0                             0
# 75%                            0                             0
# max                            1                             1
#
#        MODE(activities.cat_c6)_8  MODE(comms.cat_c2)_S3769  \
# count                      34964                     34964
# mean                           0                         0
# std                            0                         0
# min                            0                         0
# 25%                            0                         0
# 50%                            0                         0
# 75%                            0                         0
# max                            1                         1
#
#        MODE(comms.cat_c2)_Rare  MODE(comms.cat_c2)_S27888  \
# count                    34964                      34964
# mean                         0                          0
# std                          0                          0
# min                          0                          0
# 25%                          0                          0
# 50%                          0                          0
# 75%                          0                          0
# max                          1                          1
#
#        MODE(comms.cat_c2)_S3563  MODE(comms.cat_c4)_1
# count                     34964                 34964
# mean                          0                     0
# std                           0                     0
# min                           0                     0
# 25%                           0                     1
# 50%                           0                     1
# 75%                           0                     1
# max                           1                     1
#
# [8 rows x 424 columns]

# %%
FILTER_OUT_PATH = '../data/features_selected/features_v{}_filtered_v{}.csv'.format(FEATURES_VERSION, SELECTION_VERSION)

pd.concat([X_filtered, clients_data], axis=1).to_csv(FILTER_OUT_PATH, index=False)

# %% [markdown]
# ## Boruta selection

# %%
X_prev = X_filtered
X_prev_train = X_filtered_train

rf = RandomForestClassifier(
    class_weight='balanced',
    max_depth=5,
    n_jobs=6,
    random_state=42,
)
feat_selector = BorutaPy(
    rf,
    n_estimators='auto',
    perc=100,
    max_iter=100,
    verbose=2,
    random_state=42,
)

feat_selector.fit(X_prev_train.values, y_train.values)

accepted_features = X_prev_train.columns[feat_selector.support_].to_list()
tentative_features = X_prev_train.columns[feat_selector.support_weak_].to_list()

X_boruta = X_prev[accepted_features + tentative_features]
X_boruta_train = X_prev_train[accepted_features + tentative_features]
# Out:
# Iteration: 	1 / 100
# Confirmed: 	0
# Tentative: 	424
# Rejected: 	0
# Iteration: 	2 / 100
# Confirmed: 	0
# Tentative: 	424
# Rejected: 	0
# Iteration: 	3 / 100
# Confirmed: 	0
# Tentative: 	424
# Rejected: 	0
# Iteration: 	4 / 100
# Confirmed: 	0
# Tentative: 	424
# Rejected: 	0
# Iteration: 	5 / 100
# Confirmed: 	0
# Tentative: 	424
# Rejected: 	0
# Iteration: 	6 / 100
# Confirmed: 	0
# Tentative: 	424
# Rejected: 	0
# Iteration: 	7 / 100
# Confirmed: 	0
# Tentative: 	424
# Rejected: 	0
# Iteration: 	8 / 100
# Confirmed: 	147
# Tentative: 	110
# Rejected: 	167
# Iteration: 	9 / 100
# Confirmed: 	147
# Tentative: 	110
# Rejected: 	167
# Iteration: 	10 / 100
# Confirmed: 	147
# Tentative: 	110
# Rejected: 	167
# Iteration: 	11 / 100
# Confirmed: 	147
# Tentative: 	110
# Rejected: 	167
# Iteration: 	12 / 100
# Confirmed: 	150
# Tentative: 	107
# Rejected: 	167
# Iteration: 	13 / 100
# Confirmed: 	150
# Tentative: 	92
# Rejected: 	182
# Iteration: 	14 / 100
# Confirmed: 	150
# Tentative: 	92
# Rejected: 	182
# Iteration: 	15 / 100
# Confirmed: 	150
# Tentative: 	92
# Rejected: 	182
# Iteration: 	16 / 100
# Confirmed: 	154
# Tentative: 	72
# Rejected: 	198
# Iteration: 	17 / 100
# Confirmed: 	154
# Tentative: 	72
# Rejected: 	198
# Iteration: 	18 / 100
# Confirmed: 	154
# Tentative: 	72
# Rejected: 	198
# Iteration: 	19 / 100
# Confirmed: 	155
# Tentative: 	71
# Rejected: 	198
# Iteration: 	20 / 100
# Confirmed: 	155
# Tentative: 	62
# Rejected: 	207
# Iteration: 	21 / 100
# Confirmed: 	155
# Tentative: 	62
# Rejected: 	207
# Iteration: 	22 / 100
# Confirmed: 	155
# Tentative: 	62
# Rejected: 	207
# Iteration: 	23 / 100
# Confirmed: 	155
# Tentative: 	55
# Rejected: 	214
# Iteration: 	24 / 100
# Confirmed: 	155
# Tentative: 	55
# Rejected: 	214
# Iteration: 	25 / 100
# Confirmed: 	155
# Tentative: 	55
# Rejected: 	214
# Iteration: 	26 / 100
# Confirmed: 	155
# Tentative: 	55
# Rejected: 	214
# Iteration: 	27 / 100
# Confirmed: 	155
# Tentative: 	55
# Rejected: 	214
# Iteration: 	28 / 100
# Confirmed: 	155
# Tentative: 	55
# Rejected: 	214
# Iteration: 	29 / 100
# Confirmed: 	155
# Tentative: 	55
# Rejected: 	214
# Iteration: 	30 / 100
# Confirmed: 	155
# Tentative: 	55
# Rejected: 	214
# Iteration: 	31 / 100
# Confirmed: 	155
# Tentative: 	53
# Rejected: 	216
# Iteration: 	32 / 100
# Confirmed: 	155
# Tentative: 	53
# Rejected: 	216
# Iteration: 	33 / 100
# Confirmed: 	155
# Tentative: 	53
# Rejected: 	216
# Iteration: 	34 / 100
# Confirmed: 	156
# Tentative: 	52
# Rejected: 	216
# Iteration: 	35 / 100
# Confirmed: 	156
# Tentative: 	47
# Rejected: 	221
# Iteration: 	36 / 100
# Confirmed: 	156
# Tentative: 	47
# Rejected: 	221
# Iteration: 	37 / 100
# Confirmed: 	156
# Tentative: 	47
# Rejected: 	221
# Iteration: 	38 / 100
# Confirmed: 	156
# Tentative: 	47
# Rejected: 	221
# Iteration: 	39 / 100
# Confirmed: 	156
# Tentative: 	47
# Rejected: 	221
# Iteration: 	40 / 100
# Confirmed: 	157
# Tentative: 	46
# Rejected: 	221
# Iteration: 	41 / 100
# Confirmed: 	157
# Tentative: 	43
# Rejected: 	224
# Iteration: 	42 / 100
# Confirmed: 	157
# Tentative: 	43
# Rejected: 	224
# Iteration: 	43 / 100
# Confirmed: 	157
# Tentative: 	43
# Rejected: 	224
# Iteration: 	44 / 100
# Confirmed: 	157
# Tentative: 	43
# Rejected: 	224
# Iteration: 	45 / 100
# Confirmed: 	157
# Tentative: 	43
# Rejected: 	224
# Iteration: 	46 / 100
# Confirmed: 	157
# Tentative: 	43
# Rejected: 	224
# Iteration: 	47 / 100
# Confirmed: 	157
# Tentative: 	43
# Rejected: 	224
# Iteration: 	48 / 100
# Confirmed: 	157
# Tentative: 	41
# Rejected: 	226
# Iteration: 	49 / 100
# Confirmed: 	157
# Tentative: 	41
# Rejected: 	226
# Iteration: 	50 / 100
# Confirmed: 	157
# Tentative: 	41
# Rejected: 	226
# Iteration: 	51 / 100
# Confirmed: 	157
# Tentative: 	41
# Rejected: 	226
# Iteration: 	52 / 100
# Confirmed: 	157
# Tentative: 	41
# Rejected: 	226
# Iteration: 	53 / 100
# Confirmed: 	157
# Tentative: 	41
# Rejected: 	226
# Iteration: 	54 / 100
# Confirmed: 	157
# Tentative: 	37
# Rejected: 	230
# Iteration: 	55 / 100
# Confirmed: 	157
# Tentative: 	37
# Rejected: 	230
# Iteration: 	56 / 100
# Confirmed: 	157
# Tentative: 	37
# Rejected: 	230
# Iteration: 	57 / 100
# Confirmed: 	157
# Tentative: 	37
# Rejected: 	230
# Iteration: 	58 / 100
# Confirmed: 	157
# Tentative: 	37
# Rejected: 	230
# Iteration: 	59 / 100
# Confirmed: 	157
# Tentative: 	37
# Rejected: 	230
# Iteration: 	60 / 100
# Confirmed: 	157
# Tentative: 	35
# Rejected: 	232
# Iteration: 	61 / 100
# Confirmed: 	157
# Tentative: 	35
# Rejected: 	232
# Iteration: 	62 / 100
# Confirmed: 	157
# Tentative: 	35
# Rejected: 	232
# Iteration: 	63 / 100
# Confirmed: 	157
# Tentative: 	35
# Rejected: 	232
# Iteration: 	64 / 100
# Confirmed: 	157
# Tentative: 	35
# Rejected: 	232
# Iteration: 	65 / 100
# Confirmed: 	157
# Tentative: 	33
# Rejected: 	234
# Iteration: 	66 / 100
# Confirmed: 	157
# Tentative: 	33
# Rejected: 	234
# Iteration: 	67 / 100
# Confirmed: 	157
# Tentative: 	33
# Rejected: 	234
# Iteration: 	68 / 100
# Confirmed: 	157
# Tentative: 	33
# Rejected: 	234
# Iteration: 	69 / 100
# Confirmed: 	157
# Tentative: 	33
# Rejected: 	234
# Iteration: 	70 / 100
# Confirmed: 	158
# Tentative: 	29
# Rejected: 	237
# Iteration: 	71 / 100
# Confirmed: 	158
# Tentative: 	29
# Rejected: 	237
# Iteration: 	72 / 100
# Confirmed: 	158
# Tentative: 	29
# Rejected: 	237
# Iteration: 	73 / 100
# Confirmed: 	158
# Tentative: 	29
# Rejected: 	237
# Iteration: 	74 / 100
# Confirmed: 	158
# Tentative: 	29
# Rejected: 	237
# Iteration: 	75 / 100
# Confirmed: 	158
# Tentative: 	29
# Rejected: 	237
# Iteration: 	76 / 100
# Confirmed: 	158
# Tentative: 	29
# Rejected: 	237
# Iteration: 	77 / 100
# Confirmed: 	158
# Tentative: 	29
# Rejected: 	237
# Iteration: 	78 / 100
# Confirmed: 	158
# Tentative: 	29
# Rejected: 	237
# Iteration: 	79 / 100
# Confirmed: 	158
# Tentative: 	28
# Rejected: 	238
# Iteration: 	80 / 100
# Confirmed: 	158
# Tentative: 	27
# Rejected: 	239
# Iteration: 	81 / 100
# Confirmed: 	158
# Tentative: 	27
# Rejected: 	239
# Iteration: 	82 / 100
# Confirmed: 	158
# Tentative: 	27
# Rejected: 	239
# Iteration: 	83 / 100
# Confirmed: 	158
# Tentative: 	25
# Rejected: 	241
# Iteration: 	84 / 100
# Confirmed: 	158
# Tentative: 	25
# Rejected: 	241
# Iteration: 	85 / 100
# Confirmed: 	158
# Tentative: 	24
# Rejected: 	242
# Iteration: 	86 / 100
# Confirmed: 	158
# Tentative: 	24
# Rejected: 	242
# Iteration: 	87 / 100
# Confirmed: 	158
# Tentative: 	24
# Rejected: 	242
# Iteration: 	88 / 100
# Confirmed: 	158
# Tentative: 	24
# Rejected: 	242
# Iteration: 	89 / 100
# Confirmed: 	158
# Tentative: 	24
# Rejected: 	242
# Iteration: 	90 / 100
# Confirmed: 	158
# Tentative: 	24
# Rejected: 	242
# Iteration: 	91 / 100
# Confirmed: 	158
# Tentative: 	24
# Rejected: 	242
# Iteration: 	92 / 100
# Confirmed: 	158
# Tentative: 	24
# Rejected: 	242
# Iteration: 	93 / 100
# Confirmed: 	158
# Tentative: 	23
# Rejected: 	243
# Iteration: 	94 / 100
# Confirmed: 	158
# Tentative: 	23
# Rejected: 	243
# Iteration: 	95 / 100
# Confirmed: 	158
# Tentative: 	23
# Rejected: 	243
# Iteration: 	96 / 100
# Confirmed: 	158
# Tentative: 	23
# Rejected: 	243
# Iteration: 	97 / 100
# Confirmed: 	158
# Tentative: 	23
# Rejected: 	243
# Iteration: 	98 / 100
# Confirmed: 	158
# Tentative: 	22
# Rejected: 	244
# Iteration: 	99 / 100
# Confirmed: 	158
# Tentative: 	22
# Rejected: 	244
#
#
# BorutaPy finished running.
#
# Iteration: 	100 / 100
# Confirmed: 	158
# Tentative: 	11
# Rejected: 	255

# %%
BORUTA_OUT_PATH = '../data/features_selected/features_v{}_boruta_v1.csv'.format(FEATURES_VERSION)
pd.concat([X_boruta, clients_data], axis=1).to_csv(BORUTA_OUT_PATH, index=False)

# %% [markdown]
# ## Selection with regularization

# %%
# """L1 regularization"""
#
# log_l1 = LogisticRegression(
#     penalty='l1',
#     solver='saga',
#     max_iter=1500,
#     class_weight='balanced',
#     n_jobs=6,
#     random_state=42,
#     verbose=1,
# )
# sfm = SelectFromModel(log_l1, threshold='median')
#
# sfm.fit(X_filtered, y)
#
# selected_l1_features = X_filtered.columns[sfm.get_support()]
# X_l1 = X_filtered[selected_l1_features]

# %%
"""ElasticNet regularization"""

X_prev = X_boruta
X_prev_train = X_boruta_train

log_en = LogisticRegression(
    penalty='elasticnet',
    solver='saga',
    l1_ratio=0.3,
    C=1,
    max_iter=3000,
    class_weight='balanced',
    n_jobs=6,
    random_state=42,
    verbose=1,
)

log_en.fit(X_prev_train, y_train)

coef = pd.Series(np.abs(log_en.coef_[0]), index=X_prev.columns)
selected_en_features = coef[coef > 1e-6].sort_values(ascending=False).index.tolist()
X_en = X_prev[selected_en_features]
X_en_train = X_prev_train[selected_en_features]
# Out:
# [Parallel(n_jobs=6)]: Using backend ThreadingBackend with 6 concurrent workers.
# max_iter reached after 167 seconds
# C:\Users\dan\PycharmProjects\ds\ff_internship\.venv\Lib\site-packages\sklearn\linear_model\_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(

# %%
ELASTICNET_OUT_PATH = '../data/features_selected/features_v{}_elasticnet_v1.csv'.format(FEATURES_VERSION)
pd.concat([X_en, clients_data], axis=1).to_csv(ELASTICNET_OUT_PATH, index=False)

# %% [markdown]
# ## Select best features from model params

# %%
# """Select top features from LightGBM model"""
#
# lgb = LGBMClassifier(
#     n_estimators=500,
#     learning_rate=0.05,
#     predict_disable_shape_check=True,
#     random_state=42,
#     n_jobs=6,
# )
#
# lgb_data = X_filtered.rename(columns=lambda x: re.sub(r'[,\n\[\]\{\}:"]', '_', x))
# lgb.fit(lgb_data, y)
#
# importances = lgb.feature_importances_
# indices = np.argsort(importances)[::-1]
#
# top100 = X_filtered.columns[indices[:200]]
# X_lgb_imp = X_filtered[top100]

# %% [markdown]
# ## Permutation importance

# %%
# """Permutation Importance"""
#
# perm = permutation_importance(
#     lgb, X_lgb_imp, y,
#     n_repeats=10,
#     scoring='roc_auc',
#     n_jobs=6,
#     random_state=42,
# )
#
# perm_sorted_idx = perm.importances_mean.argsort()[::-1]
# selected_perm = [top100[i] for i in perm_sorted_idx if perm.importances_mean[i] < 0]
#
# X_pi = X_lgb_imp[selected_perm]

# %% [markdown]
# ## Stability selection

# %%
X_prev = X_boruta
X_prev_train = X_boruta_train

skf = StratifiedKFold(n_splits=10, shuffle=True, random_state=42)
freq = pd.Series(0, index=X_filtered.columns)
lgb_data = X_prev_train.rename(columns=lambda x: re.sub(r'[,\n\[\]\{\}:"]', '_', x))

for train_idx, val_idx in skf.split(lgb_data, y_train):
    lgb = LGBMClassifier(
        n_estimators=300,
        learning_rate=0.05,
        predict_disable_shape_check=True,
        random_state=42,
        n_jobs=6,
    )
    lgb.fit(lgb_data.iloc[train_idx], y_train.iloc[train_idx])

    imp = pd.Series(lgb.feature_importances_, index=X_prev.columns)
    top = imp.sort_values(ascending=False).head(60).index
    freq[top] += 1

selected_stable_features = freq[freq >= 6].index.tolist()[:50]
X_stable = X_prev[selected_stable_features]
X_stable_train = X_prev_train[selected_stable_features]
# Out:
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 4931, number of negative: 15027
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.008443 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 37446
# [LightGBM] [Info] Number of data points in the train set: 19958, number of used features: 169
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.247069 -> initscore=-1.114307
# [LightGBM] [Info] Start training from score -1.114307
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 4931, number of negative: 15027
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.004975 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 37449
# [LightGBM] [Info] Number of data points in the train set: 19958, number of used features: 169
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.247069 -> initscore=-1.114307
# [LightGBM] [Info] Start training from score -1.114307
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 4931, number of negative: 15027
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.005015 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 37439
# [LightGBM] [Info] Number of data points in the train set: 19958, number of used features: 169
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.247069 -> initscore=-1.114307
# [LightGBM] [Info] Start training from score -1.114307
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 4931, number of negative: 15027
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.003383 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 37452
# [LightGBM] [Info] Number of data points in the train set: 19958, number of used features: 169
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.247069 -> initscore=-1.114307
# [LightGBM] [Info] Start training from score -1.114307
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 4931, number of negative: 15027
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.004971 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 37436
# [LightGBM] [Info] Number of data points in the train set: 19958, number of used features: 169
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.247069 -> initscore=-1.114307
# [LightGBM] [Info] Start training from score -1.114307
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 4931, number of negative: 15027
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.006804 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 37417
# [LightGBM] [Info] Number of data points in the train set: 19958, number of used features: 169
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.247069 -> initscore=-1.114307
# [LightGBM] [Info] Start training from score -1.114307
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 4931, number of negative: 15028
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.008223 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 37445
# [LightGBM] [Info] Number of data points in the train set: 19959, number of used features: 169
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.247056 -> initscore=-1.114373
# [LightGBM] [Info] Start training from score -1.114373
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 4931, number of negative: 15028
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.007087 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 37438
# [LightGBM] [Info] Number of data points in the train set: 19959, number of used features: 169
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.247056 -> initscore=-1.114373
# [LightGBM] [Info] Start training from score -1.114373
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 4931, number of negative: 15028
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.005658 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 37440
# [LightGBM] [Info] Number of data points in the train set: 19959, number of used features: 169
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.247056 -> initscore=-1.114373
# [LightGBM] [Info] Start training from score -1.114373
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 4932, number of negative: 15027
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.005362 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 37436
# [LightGBM] [Info] Number of data points in the train set: 19959, number of used features: 169
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.247107 -> initscore=-1.114104
# [LightGBM] [Info] Start training from score -1.114104

# %%
selected_stable_features = freq[freq >= 6].index.tolist()
X_stable = X_prev[selected_stable_features]
X_stable_train = X_prev_train[selected_stable_features]

# %%
STABLE_OUT_PATH = '../data/features_selected/features_v{}_stable_v2.csv'.format(FEATURES_VERSION)
pd.concat([X_stable, clients_data], axis=1).to_csv(STABLE_OUT_PATH, index=False)

# %% [markdown]
# ## RFE

# %%
X_prev = X_boruta
X_prev_train = X_boruta_train

lgb = LGBMClassifier(
    n_estimators=500,
    learning_rate=0.05,
    predict_disable_shape_check=True,
    random_state=42,
    n_jobs=6,
)
rfe = RFE(
    estimator=lgb,
    n_features_to_select=50,
    step=5,
    verbose=1,
)
rfe.fit(X_prev_train, y_train)

selected_rfe_features = X_prev.columns[rfe.get_support()]
X_rfe = X_prev[selected_rfe_features]
X_rfe_train = X_prev_train[selected_rfe_features]
# Out:
# Fitting estimator with 169 features.
# [LightGBM] [Info] Number of positive: 5479, number of negative: 16697
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.008837 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 37550
# [LightGBM] [Info] Number of data points in the train set: 22176, number of used features: 169
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.247069 -> initscore=-1.114306
# [LightGBM] [Info] Start training from score -1.114306
# Fitting estimator with 164 features.
# [LightGBM] [Info] Number of positive: 5479, number of negative: 16697
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.006675 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 37220
# [LightGBM] [Info] Number of data points in the train set: 22176, number of used features: 164
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.247069 -> initscore=-1.114306
# [LightGBM] [Info] Start training from score -1.114306
# Fitting estimator with 159 features.
# [LightGBM] [Info] Number of positive: 5479, number of negative: 16697
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.006493 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 36835
# [LightGBM] [Info] Number of data points in the train set: 22176, number of used features: 159
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.247069 -> initscore=-1.114306
# [LightGBM] [Info] Start training from score -1.114306
# Fitting estimator with 154 features.
# [LightGBM] [Info] Number of positive: 5479, number of negative: 16697
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.007355 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 35782
# [LightGBM] [Info] Number of data points in the train set: 22176, number of used features: 154
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.247069 -> initscore=-1.114306
# [LightGBM] [Info] Start training from score -1.114306
# Fitting estimator with 149 features.
# [LightGBM] [Info] Number of positive: 5479, number of negative: 16697
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.007365 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 35041
# [LightGBM] [Info] Number of data points in the train set: 22176, number of used features: 149
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.247069 -> initscore=-1.114306
# [LightGBM] [Info] Start training from score -1.114306
# Fitting estimator with 144 features.
# [LightGBM] [Info] Number of positive: 5479, number of negative: 16697
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.004766 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 34409
# [LightGBM] [Info] Number of data points in the train set: 22176, number of used features: 144
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.247069 -> initscore=-1.114306
# [LightGBM] [Info] Start training from score -1.114306
# Fitting estimator with 139 features.
# [LightGBM] [Info] Number of positive: 5479, number of negative: 16697
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.008638 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 33368
# [LightGBM] [Info] Number of data points in the train set: 22176, number of used features: 139
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.247069 -> initscore=-1.114306
# [LightGBM] [Info] Start training from score -1.114306
# Fitting estimator with 134 features.
# [LightGBM] [Info] Number of positive: 5479, number of negative: 16697
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.004292 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 32286
# [LightGBM] [Info] Number of data points in the train set: 22176, number of used features: 134
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.247069 -> initscore=-1.114306
# [LightGBM] [Info] Start training from score -1.114306
# Fitting estimator with 129 features.
# [LightGBM] [Info] Number of positive: 5479, number of negative: 16697
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.007557 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 31011
# [LightGBM] [Info] Number of data points in the train set: 22176, number of used features: 129
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.247069 -> initscore=-1.114306
# [LightGBM] [Info] Start training from score -1.114306
# Fitting estimator with 124 features.
# [LightGBM] [Info] Number of positive: 5479, number of negative: 16697
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.006260 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 29903
# [LightGBM] [Info] Number of data points in the train set: 22176, number of used features: 124
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.247069 -> initscore=-1.114306
# [LightGBM] [Info] Start training from score -1.114306
# Fitting estimator with 119 features.
# [LightGBM] [Info] Number of positive: 5479, number of negative: 16697
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.006507 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 28882
# [LightGBM] [Info] Number of data points in the train set: 22176, number of used features: 119
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.247069 -> initscore=-1.114306
# [LightGBM] [Info] Start training from score -1.114306
# Fitting estimator with 114 features.
# [LightGBM] [Info] Number of positive: 5479, number of negative: 16697
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.003842 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 28010
# [LightGBM] [Info] Number of data points in the train set: 22176, number of used features: 114
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.247069 -> initscore=-1.114306
# [LightGBM] [Info] Start training from score -1.114306
# Fitting estimator with 109 features.
# [LightGBM] [Info] Number of positive: 5479, number of negative: 16697
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.003683 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 26868
# [LightGBM] [Info] Number of data points in the train set: 22176, number of used features: 109
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.247069 -> initscore=-1.114306
# [LightGBM] [Info] Start training from score -1.114306
# Fitting estimator with 104 features.
# [LightGBM] [Info] Number of positive: 5479, number of negative: 16697
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.005000 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 25597
# [LightGBM] [Info] Number of data points in the train set: 22176, number of used features: 104
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.247069 -> initscore=-1.114306
# [LightGBM] [Info] Start training from score -1.114306
# Fitting estimator with 99 features.
# [LightGBM] [Info] Number of positive: 5479, number of negative: 16697
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.005358 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 24322
# [LightGBM] [Info] Number of data points in the train set: 22176, number of used features: 99
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.247069 -> initscore=-1.114306
# [LightGBM] [Info] Start training from score -1.114306
# Fitting estimator with 94 features.
# [LightGBM] [Info] Number of positive: 5479, number of negative: 16697
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.003228 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 23048
# [LightGBM] [Info] Number of data points in the train set: 22176, number of used features: 94
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.247069 -> initscore=-1.114306
# [LightGBM] [Info] Start training from score -1.114306
# Fitting estimator with 89 features.
# [LightGBM] [Info] Number of positive: 5479, number of negative: 16697
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.003469 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 21776
# [LightGBM] [Info] Number of data points in the train set: 22176, number of used features: 89
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.247069 -> initscore=-1.114306
# [LightGBM] [Info] Start training from score -1.114306
# Fitting estimator with 84 features.
# [LightGBM] [Info] Number of positive: 5479, number of negative: 16697
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.004755 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 20660
# [LightGBM] [Info] Number of data points in the train set: 22176, number of used features: 84
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.247069 -> initscore=-1.114306
# [LightGBM] [Info] Start training from score -1.114306
# Fitting estimator with 79 features.
# [LightGBM] [Info] Number of positive: 5479, number of negative: 16697
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.004099 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 19456
# [LightGBM] [Info] Number of data points in the train set: 22176, number of used features: 79
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.247069 -> initscore=-1.114306
# [LightGBM] [Info] Start training from score -1.114306
# Fitting estimator with 74 features.
# [LightGBM] [Info] Number of positive: 5479, number of negative: 16697
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002849 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 18341
# [LightGBM] [Info] Number of data points in the train set: 22176, number of used features: 74
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.247069 -> initscore=-1.114306
# [LightGBM] [Info] Start training from score -1.114306
# Fitting estimator with 69 features.
# [LightGBM] [Info] Number of positive: 5479, number of negative: 16697
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002612 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 17084
# [LightGBM] [Info] Number of data points in the train set: 22176, number of used features: 69
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.247069 -> initscore=-1.114306
# [LightGBM] [Info] Start training from score -1.114306
# Fitting estimator with 64 features.
# [LightGBM] [Info] Number of positive: 5479, number of negative: 16697
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.003558 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 15813
# [LightGBM] [Info] Number of data points in the train set: 22176, number of used features: 64
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.247069 -> initscore=-1.114306
# [LightGBM] [Info] Start training from score -1.114306
# Fitting estimator with 59 features.
# [LightGBM] [Info] Number of positive: 5479, number of negative: 16697
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002831 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 14539
# [LightGBM] [Info] Number of data points in the train set: 22176, number of used features: 59
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.247069 -> initscore=-1.114306
# [LightGBM] [Info] Start training from score -1.114306
# Fitting estimator with 54 features.
# [LightGBM] [Info] Number of positive: 5479, number of negative: 16697
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.003444 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 13264
# [LightGBM] [Info] Number of data points in the train set: 22176, number of used features: 54
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.247069 -> initscore=-1.114306
# [LightGBM] [Info] Start training from score -1.114306
# [LightGBM] [Info] Number of positive: 5479, number of negative: 16697
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002739 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12401
# [LightGBM] [Info] Number of data points in the train set: 22176, number of used features: 50
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.247069 -> initscore=-1.114306
# [LightGBM] [Info] Start training from score -1.114306
# RFE(estimator=LGBMClassifier(learning_rate=0.05, n_estimators=500, n_jobs=6,
#                              predict_disable_shape_check=True,
#                              random_state=42),
#     n_features_to_select=50, step=5, verbose=1)

# %%
RFE_OUT_PATH = '../data/features_selected/features_v{}_rfe_v1.csv'.format(FEATURES_VERSION)
pd.concat([X_rfe, clients_data], axis=1).to_csv(RFE_OUT_PATH, index=False)

# %% [markdown]
# ## Genetic algorithm

# %%
X_prev = X_boruta
X_prev_train = X_boruta_train

ga_selector = GAFeatureSelectionCV(
    estimator=LGBMClassifier(
        n_estimators=300,
        learning_rate=0.05,
        max_depth=-1,
        num_leaves=31,
        subsample=0.8,
        colsample_bytree=0.8,
        n_jobs=6,
        random_state=42,
    ),
    cv=3,
    population_size=40,
    generations=25,
    crossover_probability=0.35,
    mutation_probability=0.20,
    tournament_size=5,
    elitism=True,
    max_features=60,
    scoring='roc_auc',
    criteria='max',

    n_jobs=6,
    verbose=True,
    keep_top_k=5,
    use_cache=True,
    refit=False,
)

lgb_data = X_prev_train.rename(columns=lambda x: re.sub(r'[,\n\[\]\{\}:"]', '_', x))
ga_selector.fit(lgb_data, y_train)
selected_ga_features = X_prev.columns[ga_selector.best_features_.tolist()]
X_ga = X_prev[selected_ga_features]
X_ga_train = X_prev_train[selected_ga_features]
# Out:
# C:\Users\dan\PycharmProjects\ds\ff_internship\.venv\Lib\site-packages\deap\creator.py:185: RuntimeWarning: A class named 'FitnessMax' has already been created and it will be overwritten. Consider deleting previous creation of that class or rename it.
#   warnings.warn("A class named '{0}' has already been created and it "
# C:\Users\dan\PycharmProjects\ds\ff_internship\.venv\Lib\site-packages\deap\creator.py:185: RuntimeWarning: A class named 'Individual' has already been created and it will be overwritten. Consider deleting previous creation of that class or rename it.
#   warnings.warn("A class named '{0}' has already been created and it "
# gen	nevals	fitness 	fitness_std	fitness_max	fitness_min
# 0  	40    	-44999.6	49749.8    	0.791395   	-100000
# 1  	52    	-2499.24	15612.6    	0.793863   	-100000
# 2  	45    	0.788844	0.00405573 	0.794357   	0.774117
# 3  	41    	0.792356	0.00177868 	0.795972   	0.788162
# 4  	46    	0.79406 	0.00165947 	0.795972   	0.791395
# 5  	39    	0.795648	0.000642932	0.797046   	0.793643
# 6  	38    	0.796161	0.000727964	0.797661   	0.795467
# 7  	43    	0.797177	0.00062382 	0.799491   	0.795691
# 8  	43    	0.797909	0.000853557	0.799491   	0.797046
# 9  	43    	0.798612	0.000819492	0.799491   	0.797221
# 10 	43    	0.799425	0.000236423	0.799491   	0.798362
# 11 	46    	0.799491	3.33067e-16	0.799491   	0.799491
# 12 	43    	0.799491	3.33067e-16	0.799491   	0.799491
# 13 	41    	0.799491	3.33067e-16	0.799491   	0.799491
# 14 	47    	0.799491	3.33067e-16	0.799491   	0.799491
# 15 	40    	0.799491	3.33067e-16	0.799491   	0.799491
# 16 	44    	0.799491	3.33067e-16	0.799491   	0.799491
# 17 	42    	0.799491	3.33067e-16	0.799491   	0.799491
# 18 	46    	0.799491	3.33067e-16	0.799491   	0.799491
# 19 	42    	0.799491	3.33067e-16	0.799491   	0.799491
# 20 	45    	0.799491	3.33067e-16	0.799491   	0.799491
# 21 	52    	0.799491	3.33067e-16	0.799491   	0.799491
# 22 	44    	0.799491	3.33067e-16	0.799491   	0.799491
# 23 	45    	0.799491	3.33067e-16	0.799491   	0.799491
# 24 	47    	0.799491	3.33067e-16	0.799491   	0.799491
# 25 	44    	0.799491	3.33067e-16	0.799491   	0.799491
# GAFeatureSelectionCV(crossover_probability=0.35,
#                      estimator=LGBMClassifier(colsample_bytree=0.8,
#                                               learning_rate=0.05,
#                                               n_estimators=300, n_jobs=6,
#                                               random_state=42, subsample=0.8),
#                      generations=25, keep_top_k=5, max_features=60,
#                      mutation_probability=0.2, n_jobs=6, population_size=40,
#                      refit=False, scoring='roc_auc', tournament_size=5)

# %%
GA_OUT_PATH = '../data/features_selected/features_v{}_ga_v1.csv'.format(FEATURES_VERSION)
pd.concat([X_ga, clients_data], axis=1).to_csv(GA_OUT_PATH, index=False)
