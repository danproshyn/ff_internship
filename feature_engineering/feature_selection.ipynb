# %% [markdown]
# # Feature selection

# %%
import re

import numpy as np
import pandas as pd
from IPython.display import display
from feature_engine.selection import DropConstantFeatures, DropDuplicateFeatures, MRMR, SmartCorrelatedSelection
from lightgbm import LGBMClassifier
from sklearn.feature_selection import SelectFromModel, SelectKBest, mutual_info_classif, RFE
from sklearn.linear_model import LogisticRegression
from sklearn.inspection import permutation_importance

# %%
FEATURES_VERSION = 6
SELECTION_VERSION = 4

# %%
FEATURES_PATH = '../data/features/features_auto_v{}.csv'.format(FEATURES_VERSION)

features_df = pd.read_csv(FEATURES_PATH)

# %%
clients_cols = ['client_id', 'target', 'is_train']
clients_data = features_df[clients_cols]

# %%
X = features_df.drop(columns=clients_cols)
y = features_df['target']

# %% [markdown]
# ## Filters

# %%
"""Low-Variance"""

drop_constant = DropConstantFeatures(tol=1)
drop_quasi = DropConstantFeatures(tol=0.99)
drop_duplicates = DropDuplicateFeatures()

X1 = drop_constant.fit_transform(X)
X2 = drop_quasi.fit_transform(X1)
X3 = drop_duplicates.fit_transform(X2)

# %%
"""Correlation"""

corr_selector = SmartCorrelatedSelection(
    method='pearson',
    threshold=0.7,
    selection_method='missing_values',
)
# X_corr = corr_selector.fit_transform(X3)
X_corr = corr_selector.fit_transform(X3, y)

# %%
# """Mutual information"""
#
# mi = SelectKBest(
#     score_func=mutual_info_classif,
#     k=1200,
# )
# mi.fit(X_corr, y)
# selected_mi_features = X_corr.columns[mi.get_support()]
# X_mi = X_corr[selected_mi_features]

# %%
# """MRMR"""
#
# mrmr_selector = MRMR(
#     method='MIQ',
#     max_features=5,
#     regression=False,
#     random_state=42,
#     n_jobs=6,
# )
# X_mrmr = mrmr_selector.fit_transform(X_corr, y)

# %%
X_filtered = X_corr
display(X_filtered.info(verbose=True, show_counts=True))
display(X_filtered.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34964 entries, 0 to 34963
# Data columns (total 431 columns):
#  #    Column                                                                                       Non-Null Count  Dtype
# ---   ------                                                                                       --------------  -----
#  0    COUNT(transactions)                                                                          34964 non-null  int64
#  1    ENTROPY(transactions.cat_c2)                                                                 34964 non-null  float64
#  2    ENTROPY(transactions.cat_c4)                                                                 34964 non-null  float64
#  3    KURTOSIS(transactions.float_c16)                                                             34964 non-null  float64
#  4    KURTOSIS(transactions.float_c17)                                                             34964 non-null  float64
#  5    KURTOSIS(transactions.float_c18)                                                             34964 non-null  float64
#  6    KURTOSIS(transactions.float_c20)                                                             34964 non-null  float64
#  7    KURTOSIS(transactions.int_c19)                                                               34964 non-null  float64
#  8    MAX(transactions.float_c16)                                                                  34964 non-null  float64
#  9    MAX(transactions.float_c17)                                                                  34964 non-null  float64
#  10   MAX(transactions.float_c18)                                                                  34964 non-null  float64
#  11   MAX(transactions.float_c20)                                                                  34964 non-null  float64
#  12   MEAN(transactions.float_c16)                                                                 34964 non-null  float64
#  13   MEAN(transactions.float_c17)                                                                 34964 non-null  float64
#  14   MEAN(transactions.float_c18)                                                                 34964 non-null  float64
#  15   MEAN(transactions.int_c19)                                                                   34964 non-null  float64
#  16   MEAN(transactions.tran_date_day_of_month_cos)                                                34964 non-null  float64
#  17   MEAN(transactions.tran_date_day_of_month_sin)                                                34964 non-null  float64
#  18   MEAN(transactions.tran_date_day_of_week_cos)                                                 34964 non-null  float64
#  19   MEAN(transactions.tran_date_day_of_week_sin)                                                 34964 non-null  float64
#  20   MIN(transactions.float_c16)                                                                  34964 non-null  float64
#  21   MIN(transactions.float_c17)                                                                  34964 non-null  float64
#  22   MIN(transactions.float_c18)                                                                  34964 non-null  float64
#  23   MIN(transactions.float_c20)                                                                  34964 non-null  float64
#  24   NUM_UNIQUE(transactions.cat_c3)                                                              34964 non-null  int64
#  25   NUM_UNIQUE(transactions.cat_c4)                                                              34964 non-null  int64
#  26   PERCENT_TRUE(transactions.fl_c11)                                                            34964 non-null  float64
#  27   PERCENT_TRUE(transactions.fl_c12)                                                            34964 non-null  float64
#  28   PERCENT_TRUE(transactions.fl_c13)                                                            34964 non-null  float64
#  29   PERCENT_TRUE(transactions.fl_c15)                                                            34964 non-null  float64
#  30   PERCENT_TRUE(transactions.fl_c6)                                                             34964 non-null  float64
#  31   PERCENT_TRUE(transactions.fl_c8)                                                             34964 non-null  float64
#  32   PERCENT_TRUE(transactions.tran_date_is_weekend)                                              34964 non-null  float64
#  33   STD(transactions.int_c19)                                                                    34964 non-null  float64
#  34   SUM(transactions.float_c16)                                                                  34964 non-null  float64
#  35   SUM(transactions.float_c17)                                                                  34964 non-null  float64
#  36   SUM(transactions.float_c18)                                                                  34964 non-null  float64
#  37   SUM(transactions.float_c20)                                                                  34964 non-null  float64
#  38   SUM(transactions.int_c19)                                                                    34964 non-null  float64
#  39   TIME_SINCE_FIRST(transactions.tran_date, unit=days)                                          34964 non-null  float64
#  40   TIME_SINCE_LAST(transactions.tran_date, unit=days)                                           34964 non-null  float64
#  41   ENTROPY(activities.cat_c3)                                                                   34964 non-null  float64
#  42   ENTROPY(activities.cat_c5)                                                                   34964 non-null  float64
#  43   ENTROPY(activities.cat_c6)                                                                   34964 non-null  float64
#  44   ENTROPY(activities.cat_c9)                                                                   34964 non-null  float64
#  45   KURTOSIS(activities.float_c11)                                                               34964 non-null  float64
#  46   KURTOSIS(activities.float_c12)                                                               34964 non-null  float64
#  47   KURTOSIS(activities.float_c14)                                                               34964 non-null  float64
#  48   MAX(activities.float_c11)                                                                    34964 non-null  float64
#  49   MAX(activities.float_c12)                                                                    34964 non-null  float64
#  50   MAX(activities.float_c14)                                                                    34964 non-null  float64
#  51   MEAN(activities.activity_date_day_of_week_cos)                                               34964 non-null  float64
#  52   MEAN(activities.activity_date_day_of_week_sin)                                               34964 non-null  float64
#  53   MEAN(activities.float_c12)                                                                   34964 non-null  float64
#  54   MIN(activities.float_c11)                                                                    34964 non-null  float64
#  55   MIN(activities.float_c12)                                                                    34964 non-null  float64
#  56   MIN(activities.float_c14)                                                                    34964 non-null  float64
#  57   NUM_UNIQUE(activities.cat_c3)                                                                34964 non-null  int64
#  58   NUM_UNIQUE(activities.cat_c4)                                                                34964 non-null  int64
#  59   NUM_UNIQUE(activities.cat_c5)                                                                34964 non-null  int64
#  60   PERCENT_TRUE(activities.activity_date_is_weekend)                                            34964 non-null  float64
#  61   PERCENT_TRUE(activities.cat_c10)                                                             34964 non-null  float64
#  62   PERCENT_TRUE(activities.cat_c8)                                                              34964 non-null  float64
#  63   SKEW(activities.float_c11)                                                                   34964 non-null  float64
#  64   SKEW(activities.float_c14)                                                                   34964 non-null  float64
#  65   STD(activities.float_c11)                                                                    34964 non-null  float64
#  66   SUM(activities.float_c11)                                                                    34964 non-null  float64
#  67   SUM(activities.float_c14)                                                                    34964 non-null  float64
#  68   TIME_SINCE_LAST(activities.activity_date, unit=days)                                         34964 non-null  float64
#  69   ENTROPY(comms.cat_c2)                                                                        34964 non-null  float64
#  70   ENTROPY(comms.cat_c3)                                                                        34964 non-null  float64
#  71   ENTROPY(comms.cat_c5)                                                                        34964 non-null  float64
#  72   NUM_UNIQUE(comms.cat_c3)                                                                     34964 non-null  int64
#  73   NUM_UNIQUE(comms.cat_c5)                                                                     34964 non-null  int64
#  74   TIME_SINCE_LAST(comms.contact_date, unit=days)                                               34964 non-null  float64
#  75   IS_WEEKEND(communication_month)                                                              34964 non-null  int64
#  76   COUNT(transactions WHERE cat_c3 = 303)                                                       34964 non-null  int64
#  77   COUNT(transactions WHERE cat_c2 = 4)                                                         34964 non-null  int64
#  78   MAX(transactions.float_c16 WHERE fl_c14 = False)                                             34964 non-null  float64
#  79   MAX(transactions.float_c16 WHERE cat_c3 = 303)                                               34964 non-null  float64
#  80   MAX(transactions.float_c16 WHERE cat_c2 = 4)                                                 34964 non-null  float64
#  81   MAX(transactions.float_c16 WHERE tran_date_is_weekend = True)                                34964 non-null  float64
#  82   MAX(transactions.float_c17 WHERE cat_c2 = 15)                                                34964 non-null  float64
#  83   MAX(transactions.float_c17 WHERE fl_c13 = True)                                              34964 non-null  float64
#  84   MAX(transactions.float_c17 WHERE cat_c3 = 305)                                               34964 non-null  float64
#  85   MAX(transactions.float_c17 WHERE cat_c2 = 14)                                                34964 non-null  float64
#  86   MAX(transactions.float_c18 WHERE fl_c13 = True)                                              34964 non-null  float64
#  87   MAX(transactions.float_c18 WHERE cat_c3 = 303)                                               34964 non-null  float64
#  88   MAX(transactions.float_c18 WHERE cat_c3 = 209)                                               34964 non-null  float64
#  89   MAX(transactions.float_c18 WHERE fl_c14 = True)                                              34964 non-null  float64
#  90   MAX(transactions.float_c18 WHERE tran_date_is_weekend = True)                                34964 non-null  float64
#  91   MAX(transactions.float_c20 WHERE fl_c13 = True)                                              34964 non-null  float64
#  92   MAX(transactions.float_c20 WHERE cat_c3 = 305)                                               34964 non-null  float64
#  93   MAX(transactions.float_c20 WHERE cat_c3 = 303)                                               34964 non-null  float64
#  94   MAX(transactions.float_c20 WHERE cat_c2 = 4)                                                 34964 non-null  float64
#  95   MAX(transactions.float_c20 WHERE cat_c3 = 209)                                               34964 non-null  float64
#  96   MAX(transactions.float_c20 WHERE fl_c14 = True)                                              34964 non-null  float64
#  97   MAX(transactions.float_c21 WHERE cat_c2 = 15)                                                34964 non-null  float64
#  98   MAX(transactions.float_c21 WHERE cat_c3 = 305)                                               34964 non-null  float64
#  99   MAX(transactions.int_c19 WHERE cat_c2 = 15)                                                  34964 non-null  float64
#  100  MAX(transactions.int_c19 WHERE fl_c13 = True)                                                34964 non-null  float64
#  101  MAX(transactions.int_c19 WHERE cat_c3 = 305)                                                 34964 non-null  float64
#  102  MAX(transactions.int_c19 WHERE cat_c3 = 303)                                                 34964 non-null  float64
#  103  MAX(transactions.int_c19 WHERE cat_c2 = 4)                                                   34964 non-null  float64
#  104  MAX(transactions.int_c19 WHERE fl_c14 = True)                                                34964 non-null  float64
#  105  MAX(transactions.int_c19 WHERE cat_c3 = 314)                                                 34964 non-null  float64
#  106  MAX(transactions.int_c19 WHERE tran_date_is_weekend = True)                                  34964 non-null  float64
#  107  MEAN(transactions.float_c16 WHERE fl_c13 = True)                                             34964 non-null  float64
#  108  MEAN(transactions.float_c16 WHERE fl_c14 = False)                                            34964 non-null  float64
#  109  MEAN(transactions.float_c16 WHERE cat_c2 = 4)                                                34964 non-null  float64
#  110  MEAN(transactions.float_c17 WHERE cat_c2 = 15)                                               34964 non-null  float64
#  111  MEAN(transactions.float_c17 WHERE fl_c13 = True)                                             34964 non-null  float64
#  112  MEAN(transactions.float_c17 WHERE cat_c3 = 305)                                              34964 non-null  float64
#  113  MEAN(transactions.float_c17 WHERE fl_c12 = False)                                            34964 non-null  float64
#  114  MEAN(transactions.float_c17 WHERE tran_date_is_weekend = True)                               34964 non-null  float64
#  115  MEAN(transactions.float_c17 WHERE cat_c2 = 14)                                               34964 non-null  float64
#  116  MEAN(transactions.float_c18 WHERE fl_c13 = True)                                             34964 non-null  float64
#  117  MEAN(transactions.float_c18 WHERE cat_c3 = 305)                                              34964 non-null  float64
#  118  MEAN(transactions.float_c18 WHERE cat_c3 = 303)                                              34964 non-null  float64
#  119  MEAN(transactions.float_c18 WHERE cat_c2 = 4)                                                34964 non-null  float64
#  120  MEAN(transactions.float_c18 WHERE fl_c14 = True)                                             34964 non-null  float64
#  121  MEAN(transactions.float_c20 WHERE fl_c13 = True)                                             34964 non-null  float64
#  122  MEAN(transactions.float_c20 WHERE int_c19 = 1)                                               34964 non-null  float64
#  123  MEAN(transactions.float_c20 WHERE cat_c3 = 303)                                              34964 non-null  float64
#  124  MEAN(transactions.float_c20 WHERE cat_c2 = 4)                                                34964 non-null  float64
#  125  MEAN(transactions.float_c20 WHERE int_c19 = -1)                                              34964 non-null  float64
#  126  MEAN(transactions.float_c20 WHERE fl_c14 = True)                                             34964 non-null  float64
#  127  MEAN(transactions.float_c21 WHERE cat_c2 = 15)                                               34964 non-null  float64
#  128  MEAN(transactions.int_c19 WHERE cat_c2 = 15)                                                 34964 non-null  float64
#  129  MEAN(transactions.int_c19 WHERE cat_c3 = 305)                                                34964 non-null  float64
#  130  MEAN(transactions.int_c19 WHERE cat_c3 = 303)                                                34964 non-null  float64
#  131  MEAN(transactions.int_c19 WHERE cat_c3 = 314)                                                34964 non-null  float64
#  132  MEAN(transactions.int_c19 WHERE cat_c2 = 14)                                                 34964 non-null  float64
#  133  MEAN(transactions.tran_date_day_of_month_cos WHERE cat_c2 = 15)                              34964 non-null  float64
#  134  MEAN(transactions.tran_date_day_of_month_cos WHERE fl_c13 = True)                            34964 non-null  float64
#  135  MEAN(transactions.tran_date_day_of_month_cos WHERE cat_c3 = 305)                             34964 non-null  float64
#  136  MEAN(transactions.tran_date_day_of_month_cos WHERE cat_c3 = 303)                             34964 non-null  float64
#  137  MEAN(transactions.tran_date_day_of_month_cos WHERE cat_c2 = 4)                               34964 non-null  float64
#  138  MEAN(transactions.tran_date_day_of_month_cos WHERE tran_date_is_weekend = True)              34964 non-null  float64
#  139  MEAN(transactions.tran_date_day_of_month_sin WHERE cat_c2 = 15)                              34964 non-null  float64
#  140  MEAN(transactions.tran_date_day_of_month_sin WHERE fl_c13 = True)                            34964 non-null  float64
#  141  MEAN(transactions.tran_date_day_of_month_sin WHERE cat_c3 = 305)                             34964 non-null  float64
#  142  MEAN(transactions.tran_date_day_of_month_sin WHERE cat_c3 = 303)                             34964 non-null  float64
#  143  MEAN(transactions.tran_date_day_of_month_sin WHERE cat_c2 = 4)                               34964 non-null  float64
#  144  MEAN(transactions.tran_date_day_of_month_sin WHERE tran_date_is_weekend = True)              34964 non-null  float64
#  145  MEAN(transactions.tran_date_day_of_week_cos WHERE cat_c2 = 15)                               34964 non-null  float64
#  146  MEAN(transactions.tran_date_day_of_week_cos WHERE fl_c13 = True)                             34964 non-null  float64
#  147  MEAN(transactions.tran_date_day_of_week_cos WHERE cat_c3 = 305)                              34964 non-null  float64
#  148  MEAN(transactions.tran_date_day_of_week_cos WHERE cat_c3 = 303)                              34964 non-null  float64
#  149  MEAN(transactions.tran_date_day_of_week_cos WHERE cat_c2 = 4)                                34964 non-null  float64
#  150  MEAN(transactions.tran_date_day_of_week_cos WHERE tran_date_is_weekend = True)               34964 non-null  float64
#  151  MEAN(transactions.tran_date_day_of_week_sin WHERE cat_c2 = 15)                               34964 non-null  float64
#  152  MEAN(transactions.tran_date_day_of_week_sin WHERE fl_c13 = True)                             34964 non-null  float64
#  153  MEAN(transactions.tran_date_day_of_week_sin WHERE cat_c3 = 305)                              34964 non-null  float64
#  154  MEAN(transactions.tran_date_day_of_week_sin WHERE cat_c3 = 303)                              34964 non-null  float64
#  155  MEAN(transactions.tran_date_day_of_week_sin WHERE cat_c2 = 4)                                34964 non-null  float64
#  156  MEAN(transactions.tran_date_day_of_week_sin WHERE tran_date_is_weekend = True)               34964 non-null  float64
#  157  MIN(transactions.float_c16 WHERE fl_c13 = True)                                              34964 non-null  float64
#  158  MIN(transactions.float_c16 WHERE cat_c2 = 4)                                                 34964 non-null  float64
#  159  MIN(transactions.float_c16 WHERE fl_c14 = True)                                              34964 non-null  float64
#  160  MIN(transactions.float_c16 WHERE tran_date_is_weekend = True)                                34964 non-null  float64
#  161  MIN(transactions.float_c17 WHERE cat_c3 = 314)                                               34964 non-null  float64
#  162  MIN(transactions.float_c18 WHERE cat_c2 = 15)                                                34964 non-null  float64
#  163  MIN(transactions.float_c18 WHERE cat_c3 = 305)                                               34964 non-null  float64
#  164  MIN(transactions.float_c18 WHERE cat_c2 = 4)                                                 34964 non-null  float64
#  165  MIN(transactions.float_c18 WHERE int_c19 = -1)                                               34964 non-null  float64
#  166  MIN(transactions.float_c18 WHERE fl_c14 = True)                                              34964 non-null  float64
#  167  MIN(transactions.float_c18 WHERE tran_date_is_weekend = True)                                34964 non-null  float64
#  168  MIN(transactions.float_c18 WHERE cat_c2 = 14)                                                34964 non-null  float64
#  169  MIN(transactions.float_c20 WHERE int_c19 = 1)                                                34964 non-null  float64
#  170  MIN(transactions.float_c20 WHERE fl_c14 = False)                                             34964 non-null  float64
#  171  MIN(transactions.float_c20 WHERE cat_c3 = 305)                                               34964 non-null  float64
#  172  MIN(transactions.float_c20 WHERE cat_c2 = 4)                                                 34964 non-null  float64
#  173  MIN(transactions.float_c20 WHERE cat_c3 = 209)                                               34964 non-null  float64
#  174  MIN(transactions.float_c20 WHERE tran_date_is_weekend = True)                                34964 non-null  float64
#  175  MIN(transactions.float_c20 WHERE tran_date_is_weekend = False)                               34964 non-null  float64
#  176  MIN(transactions.float_c21 WHERE cat_c3 = 314)                                               34964 non-null  float64
#  177  MIN(transactions.int_c19 WHERE cat_c3 = 305)                                                 34964 non-null  float64
#  178  MIN(transactions.int_c19 WHERE fl_c12 = False)                                               34964 non-null  float64
#  179  MIN(transactions.int_c19 WHERE tran_date_is_weekend = True)                                  34964 non-null  float64
#  180  MIN(transactions.int_c19 WHERE cat_c2 = 14)                                                  34964 non-null  float64
#  181  STD(transactions.float_c17 WHERE int_c19 = -1)                                               34964 non-null  float64
#  182  STD(transactions.float_c20 WHERE cat_c2 = 15)                                                34964 non-null  float64
#  183  STD(transactions.float_c20 WHERE tran_date_is_weekend = True)                                34964 non-null  float64
#  184  STD(transactions.float_c21 WHERE int_c19 = -1)                                               34964 non-null  float64
#  185  STD(transactions.int_c19 WHERE cat_c3 = 303)                                                 34964 non-null  float64
#  186  STD(transactions.int_c19 WHERE cat_c2 = 4)                                                   34964 non-null  float64
#  187  STD(transactions.int_c19 WHERE fl_c13 = False)                                               34964 non-null  float64
#  188  STD(transactions.int_c19 WHERE cat_c3 = 209)                                                 34964 non-null  float64
#  189  STD(transactions.int_c19 WHERE tran_date_is_weekend = True)                                  34964 non-null  float64
#  190  SUM(transactions.float_c16 WHERE int_c19 = 1)                                                34964 non-null  float64
#  191  SUM(transactions.float_c16 WHERE fl_c14 = False)                                             34964 non-null  float64
#  192  SUM(transactions.float_c17 WHERE cat_c2 = 15)                                                34964 non-null  float64
#  193  SUM(transactions.float_c17 WHERE fl_c13 = True)                                              34964 non-null  float64
#  194  SUM(transactions.float_c17 WHERE cat_c3 = 305)                                               34964 non-null  float64
#  195  SUM(transactions.float_c18 WHERE cat_c3 = 303)                                               34964 non-null  float64
#  196  SUM(transactions.float_c18 WHERE cat_c3 = 209)                                               34964 non-null  float64
#  197  SUM(transactions.float_c18 WHERE fl_c14 = True)                                              34964 non-null  float64
#  198  SUM(transactions.float_c21 WHERE fl_c13 = True)                                              34964 non-null  float64
#  199  SUM(transactions.int_c19 WHERE cat_c3 = 305)                                                 34964 non-null  float64
#  200  TIME_SINCE_LAST(transactions.tran_date WHERE int_c19 = 1, unit=days)                         34964 non-null  float64
#  201  TIME_SINCE_LAST(transactions.tran_date WHERE fl_c14 = False, unit=days)                      34964 non-null  float64
#  202  TIME_SINCE_LAST(transactions.tran_date WHERE cat_c3 = 303, unit=days)                        34964 non-null  float64
#  203  TIME_SINCE_LAST(transactions.tran_date WHERE fl_c12 = False, unit=days)                      34964 non-null  float64
#  204  TIME_SINCE_LAST(transactions.tran_date WHERE int_c19 = -1, unit=days)                        34964 non-null  float64
#  205  TIME_SINCE_LAST(transactions.tran_date WHERE fl_c13 = False, unit=days)                      34964 non-null  float64
#  206  TIME_SINCE_LAST(transactions.tran_date WHERE tran_date_is_weekend = False, unit=days)        34964 non-null  float64
#  207  COUNT(activities WHERE cat_c10 = False)                                                      34964 non-null  int64
#  208  COUNT(activities WHERE cat_c4 = 2)                                                           34964 non-null  int64
#  209  COUNT(activities WHERE cat_c6 = 2)                                                           34964 non-null  int64
#  210  COUNT(activities WHERE cat_c9 = 2)                                                           34964 non-null  int64
#  211  COUNT(activities WHERE cat_c10 = True)                                                       34964 non-null  int64
#  212  COUNT(activities WHERE cat_c8 = False)                                                       34964 non-null  int64
#  213  COUNT(activities WHERE cat_c6 = 3)                                                           34964 non-null  int64
#  214  COUNT(activities WHERE cat_c9 = 1)                                                           34964 non-null  int64
#  215  MAX(activities.float_c11 WHERE cat_c6 = 2)                                                   34964 non-null  float64
#  216  MAX(activities.float_c11 WHERE cat_c9 = 2)                                                   34964 non-null  float64
#  217  MAX(activities.float_c11 WHERE cat_c6 = 3)                                                   34964 non-null  float64
#  218  MAX(activities.float_c12 WHERE cat_c10 = False)                                              34964 non-null  float64
#  219  MAX(activities.float_c12 WHERE cat_c4 = 2)                                                   34964 non-null  float64
#  220  MAX(activities.float_c12 WHERE cat_c10 = True)                                               34964 non-null  float64
#  221  MAX(activities.float_c12 WHERE activity_date_is_weekend = True)                              34964 non-null  float64
#  222  MAX(activities.float_c12 WHERE cat_c9 = 1)                                                   34964 non-null  float64
#  223  MAX(activities.float_c14 WHERE cat_c8 = True)                                                34964 non-null  float64
#  224  MEAN(activities.activity_date_day_of_month_cos WHERE activity_date_is_weekend = False)       34964 non-null  float64
#  225  MEAN(activities.activity_date_day_of_month_cos WHERE cat_c10 = False)                        34964 non-null  float64
#  226  MEAN(activities.activity_date_day_of_month_cos WHERE cat_c4 = 2)                             34964 non-null  float64
#  227  MEAN(activities.activity_date_day_of_month_cos WHERE cat_c6 = 2)                             34964 non-null  float64
#  228  MEAN(activities.activity_date_day_of_month_cos WHERE cat_c9 = 2)                             34964 non-null  float64
#  229  MEAN(activities.activity_date_day_of_month_cos WHERE cat_c8 = False)                         34964 non-null  float64
#  230  MEAN(activities.activity_date_day_of_month_cos WHERE activity_date_is_weekend = True)        34964 non-null  float64
#  231  MEAN(activities.activity_date_day_of_month_cos WHERE cat_c6 = 3)                             34964 non-null  float64
#  232  MEAN(activities.activity_date_day_of_month_cos WHERE cat_c9 = 1)                             34964 non-null  float64
#  233  MEAN(activities.activity_date_day_of_month_sin WHERE cat_c10 = False)                        34964 non-null  float64
#  234  MEAN(activities.activity_date_day_of_month_sin WHERE cat_c4 = 2)                             34964 non-null  float64
#  235  MEAN(activities.activity_date_day_of_month_sin WHERE cat_c8 = True)                          34964 non-null  float64
#  236  MEAN(activities.activity_date_day_of_month_sin WHERE cat_c6 = 2)                             34964 non-null  float64
#  237  MEAN(activities.activity_date_day_of_month_sin WHERE cat_c9 = 2)                             34964 non-null  float64
#  238  MEAN(activities.activity_date_day_of_month_sin WHERE cat_c8 = False)                         34964 non-null  float64
#  239  MEAN(activities.activity_date_day_of_month_sin WHERE activity_date_is_weekend = True)        34964 non-null  float64
#  240  MEAN(activities.activity_date_day_of_month_sin WHERE cat_c6 = 3)                             34964 non-null  float64
#  241  MEAN(activities.activity_date_day_of_month_sin WHERE cat_c9 = 1)                             34964 non-null  float64
#  242  MEAN(activities.activity_date_day_of_week_cos WHERE cat_c10 = False)                         34964 non-null  float64
#  243  MEAN(activities.activity_date_day_of_week_cos WHERE cat_c4 = 2)                              34964 non-null  float64
#  244  MEAN(activities.activity_date_day_of_week_cos WHERE cat_c6 = 2)                              34964 non-null  float64
#  245  MEAN(activities.activity_date_day_of_week_cos WHERE cat_c9 = 2)                              34964 non-null  float64
#  246  MEAN(activities.activity_date_day_of_week_cos WHERE cat_c8 = False)                          34964 non-null  float64
#  247  MEAN(activities.activity_date_day_of_week_cos WHERE activity_date_is_weekend = True)         34964 non-null  float64
#  248  MEAN(activities.activity_date_day_of_week_cos WHERE cat_c6 = 3)                              34964 non-null  float64
#  249  MEAN(activities.activity_date_day_of_week_cos WHERE cat_c9 = 1)                              34964 non-null  float64
#  250  MEAN(activities.activity_date_day_of_week_sin WHERE cat_c10 = False)                         34964 non-null  float64
#  251  MEAN(activities.activity_date_day_of_week_sin WHERE cat_c4 = 2)                              34964 non-null  float64
#  252  MEAN(activities.activity_date_day_of_week_sin WHERE cat_c6 = 2)                              34964 non-null  float64
#  253  MEAN(activities.activity_date_day_of_week_sin WHERE cat_c9 = 2)                              34964 non-null  float64
#  254  MEAN(activities.activity_date_day_of_week_sin WHERE cat_c8 = False)                          34964 non-null  float64
#  255  MEAN(activities.activity_date_day_of_week_sin WHERE activity_date_is_weekend = True)         34964 non-null  float64
#  256  MEAN(activities.activity_date_day_of_week_sin WHERE cat_c6 = 3)                              34964 non-null  float64
#  257  MEAN(activities.activity_date_day_of_week_sin WHERE cat_c9 = 1)                              34964 non-null  float64
#  258  MEAN(activities.float_c11 WHERE cat_c8 = False)                                              34964 non-null  float64
#  259  MEAN(activities.float_c14 WHERE cat_c8 = False)                                              34964 non-null  float64
#  260  MIN(activities.float_c12 WHERE cat_c10 = False)                                              34964 non-null  float64
#  261  MIN(activities.float_c12 WHERE cat_c4 = 2)                                                   34964 non-null  float64
#  262  MIN(activities.float_c12 WHERE cat_c6 = 2)                                                   34964 non-null  float64
#  263  MIN(activities.float_c12 WHERE cat_c9 = 2)                                                   34964 non-null  float64
#  264  MIN(activities.float_c12 WHERE cat_c8 = False)                                               34964 non-null  float64
#  265  MIN(activities.float_c12 WHERE cat_c6 = 3)                                                   34964 non-null  float64
#  266  MIN(activities.float_c14 WHERE cat_c10 = False)                                              34964 non-null  float64
#  267  MIN(activities.float_c14 WHERE cat_c4 = 2)                                                   34964 non-null  float64
#  268  MIN(activities.float_c14 WHERE cat_c8 = True)                                                34964 non-null  float64
#  269  MIN(activities.float_c14 WHERE cat_c6 = 2)                                                   34964 non-null  float64
#  270  MIN(activities.float_c14 WHERE cat_c9 = 2)                                                   34964 non-null  float64
#  271  MIN(activities.float_c14 WHERE cat_c8 = False)                                               34964 non-null  float64
#  272  MIN(activities.float_c14 WHERE cat_c6 = 3)                                                   34964 non-null  float64
#  273  STD(activities.float_c11 WHERE cat_c6 = 2)                                                   34964 non-null  float64
#  274  STD(activities.float_c11 WHERE cat_c8 = False)                                               34964 non-null  float64
#  275  STD(activities.float_c11 WHERE cat_c6 = 3)                                                   34964 non-null  float64
#  276  STD(activities.float_c11 WHERE cat_c9 = 1)                                                   34964 non-null  float64
#  277  STD(activities.float_c12 WHERE activity_date_is_weekend = False)                             34964 non-null  float64
#  278  STD(activities.float_c12 WHERE activity_date_is_weekend = True)                              34964 non-null  float64
#  279  SUM(activities.float_c12 WHERE cat_c8 = True)                                                34964 non-null  float64
#  280  SUM(activities.float_c14 WHERE cat_c4 = 2)                                                   34964 non-null  float64
#  281  SUM(activities.float_c14 WHERE cat_c8 = True)                                                34964 non-null  float64
#  282  TIME_SINCE_LAST(activities.activity_date WHERE activity_date_is_weekend = False, unit=days)  34964 non-null  float64
#  283  TIME_SINCE_LAST(activities.activity_date WHERE cat_c4 = 1, unit=days)                        34964 non-null  float64
#  284  TIME_SINCE_LAST(activities.activity_date WHERE cat_c10 = True, unit=days)                    34964 non-null  float64
#  285  TIME_SINCE_LAST(activities.activity_date WHERE activity_date_is_weekend = True, unit=days)   34964 non-null  float64
#  286  COUNT(comms WHERE cat_c3 = 7)                                                                34964 non-null  int64
#  287  COUNT(comms WHERE cat_c2 = S3769)                                                            34964 non-null  int64
#  288  COUNT(comms WHERE cat_c3 = 3)                                                                34964 non-null  int64
#  289  COUNT(comms WHERE cat_c5 = 7)                                                                34964 non-null  int64
#  290  COUNT(comms WHERE cat_c4 = 2)                                                                34964 non-null  int64
#  291  MEAN(comms.contact_date_day_of_month_cos WHERE cat_c3 = 7)                                   34964 non-null  float64
#  292  MEAN(comms.contact_date_day_of_month_cos WHERE cat_c2 = S3769)                               34964 non-null  float64
#  293  MEAN(comms.contact_date_day_of_month_cos WHERE contact_date_is_weekend = False)              34964 non-null  float64
#  294  MEAN(comms.contact_date_day_of_month_cos WHERE cat_c3 = 3)                                   34964 non-null  float64
#  295  MEAN(comms.contact_date_day_of_month_cos WHERE cat_c5 = 7)                                   34964 non-null  float64
#  296  MEAN(comms.contact_date_day_of_month_sin WHERE cat_c3 = 7)                                   34964 non-null  float64
#  297  MEAN(comms.contact_date_day_of_month_sin WHERE cat_c2 = S3769)                               34964 non-null  float64
#  298  MEAN(comms.contact_date_day_of_month_sin WHERE cat_c3 = 3)                                   34964 non-null  float64
#  299  MEAN(comms.contact_date_day_of_month_sin WHERE cat_c5 = 7)                                   34964 non-null  float64
#  300  MEAN(comms.contact_date_day_of_month_sin WHERE cat_c4 = 2)                                   34964 non-null  float64
#  301  MEAN(comms.contact_date_day_of_week_cos WHERE cat_c3 = 7)                                    34964 non-null  float64
#  302  MEAN(comms.contact_date_day_of_week_cos WHERE cat_c2 = S3769)                                34964 non-null  float64
#  303  MEAN(comms.contact_date_day_of_week_cos WHERE contact_date_is_weekend = False)               34964 non-null  float64
#  304  MEAN(comms.contact_date_day_of_week_cos WHERE cat_c3 = 3)                                    34964 non-null  float64
#  305  MEAN(comms.contact_date_day_of_week_cos WHERE cat_c2 = S3677)                                34964 non-null  float64
#  306  MEAN(comms.contact_date_day_of_week_cos WHERE cat_c5 = 7)                                    34964 non-null  float64
#  307  MEAN(comms.contact_date_day_of_week_cos WHERE contact_date_is_weekend = True)                34964 non-null  float64
#  308  MEAN(comms.contact_date_day_of_week_cos WHERE cat_c4 = 2)                                    34964 non-null  float64
#  309  MEAN(comms.contact_date_day_of_week_sin WHERE cat_c3 = 7)                                    34964 non-null  float64
#  310  MEAN(comms.contact_date_day_of_week_sin WHERE cat_c2 = S3769)                                34964 non-null  float64
#  311  MEAN(comms.contact_date_day_of_week_sin WHERE contact_date_is_weekend = False)               34964 non-null  float64
#  312  MEAN(comms.contact_date_day_of_week_sin WHERE cat_c3 = 3)                                    34964 non-null  float64
#  313  MEAN(comms.contact_date_day_of_week_sin WHERE cat_c2 = S3677)                                34964 non-null  float64
#  314  MEAN(comms.contact_date_day_of_week_sin WHERE cat_c5 = 7)                                    34964 non-null  float64
#  315  MEAN(comms.contact_date_day_of_week_sin WHERE cat_c4 = 2)                                    34964 non-null  float64
#  316  TIME_SINCE_LAST(comms.contact_date WHERE cat_c3 = 7, unit=days)                              34964 non-null  float64
#  317  TIME_SINCE_LAST(comms.contact_date WHERE cat_c2 = S3769, unit=days)                          34964 non-null  float64
#  318  TIME_SINCE_LAST(comms.contact_date WHERE cat_c3 = 3, unit=days)                              34964 non-null  float64
#  319  TIME_SINCE_LAST(comms.contact_date WHERE cat_c2 = S3677, unit=days)                          34964 non-null  float64
#  320  TIME_SINCE_LAST(comms.contact_date WHERE cat_c5 = 7, unit=days)                              34964 non-null  float64
#  321  TIME_SINCE_LAST(comms.contact_date WHERE contact_date_is_weekend = True, unit=days)          34964 non-null  float64
#  322  TIME_SINCE_LAST(comms.contact_date WHERE cat_c4 = 2, unit=days)                              34964 non-null  float64
#  323  MEAN(transactions.float_c16)__30_days                                                        34964 non-null  float64
#  324  MEAN(transactions.float_c17)__30_days                                                        34964 non-null  float64
#  325  MEAN(transactions.float_c18)__30_days                                                        34964 non-null  float64
#  326  MEAN(transactions.tran_date_day_of_month_cos)__30_days                                       34964 non-null  float64
#  327  MEAN(transactions.tran_date_day_of_month_sin)__30_days                                       34964 non-null  float64
#  328  MEAN(transactions.tran_date_day_of_week_cos)__30_days                                        34964 non-null  float64
#  329  MEAN(transactions.tran_date_day_of_week_sin)__30_days                                        34964 non-null  float64
#  330  PERCENT_TRUE(transactions.fl_c6)__30_days                                                    34964 non-null  float64
#  331  PERCENT_TRUE(transactions.tran_date_is_weekend)__30_days                                     34964 non-null  float64
#  332  SUM(transactions.float_c17)__30_days                                                         34964 non-null  float64
#  333  COUNT(transactions WHERE cat_c2 = 15)__30_days                                               34964 non-null  int64
#  334  SUM(transactions.float_c16 WHERE fl_c13 = True)__30_days                                     34964 non-null  float64
#  335  SUM(transactions.float_c16 WHERE int_c19 = 1)__30_days                                       34964 non-null  float64
#  336  SUM(transactions.float_c17 WHERE int_c19 = 1)__30_days                                       34964 non-null  float64
#  337  SUM(transactions.float_c17 WHERE cat_c3 = 305)__30_days                                      34964 non-null  float64
#  338  SUM(transactions.float_c17 WHERE cat_c2 = 14)__30_days                                       34964 non-null  float64
#  339  SUM(transactions.float_c18 WHERE cat_c3 = 305)__30_days                                      34964 non-null  float64
#  340  SUM(transactions.float_c18 WHERE cat_c3 = 303)__30_days                                      34964 non-null  float64
#  341  SUM(transactions.float_c20 WHERE cat_c2 = 15)__30_days                                       34964 non-null  float64
#  342  SUM(transactions.float_c20 WHERE fl_c13 = True)__30_days                                     34964 non-null  float64
#  343  SUM(transactions.float_c20 WHERE cat_c3 = 305)__30_days                                      34964 non-null  float64
#  344  SUM(transactions.float_c20 WHERE cat_c3 = 303)__30_days                                      34964 non-null  float64
#  345  SUM(transactions.float_c20 WHERE cat_c2 = 4)__30_days                                        34964 non-null  float64
#  346  PERCENT_TRUE(transactions.fl_c7)__90_days                                                    34964 non-null  float64
#  347  PERCENT_TRUE(transactions.tran_date_is_weekend)__90_days                                     34964 non-null  float64
#  348  SUM(transactions.float_c17 WHERE cat_c3 = 303)__90_days                                      34964 non-null  float64
#  349  SUM(transactions.float_c17 WHERE cat_c2 = 14)__90_days                                       34964 non-null  float64
#  350  SUM(transactions.float_c20 WHERE fl_c14 = True)__90_days                                     34964 non-null  float64
#  351  MEAN(activities.activity_date_day_of_week_cos)__30_days                                      34964 non-null  float64
#  352  MEAN(activities.activity_date_day_of_week_sin)__30_days                                      34964 non-null  float64
#  353  PERCENT_TRUE(activities.activity_date_is_weekend)__30_days                                   34964 non-null  float64
#  354  COUNT(activities WHERE cat_c4 = 2)__30_days                                                  34964 non-null  int64
#  355  SUM(activities.float_c11 WHERE cat_c10 = False)__30_days                                     34964 non-null  float64
#  356  SUM(activities.float_c11 WHERE cat_c9 = 2)__30_days                                          34964 non-null  float64
#  357  SUM(activities.float_c11 WHERE cat_c8 = False)__30_days                                      34964 non-null  float64
#  358  SUM(activities.float_c12 WHERE activity_date_is_weekend = True)__30_days                     34964 non-null  float64
#  359  SUM(activities.float_c14 WHERE cat_c10 = False)__30_days                                     34964 non-null  float64
#  360  SUM(activities.float_c14 WHERE cat_c8 = False)__30_days                                      34964 non-null  float64
#  361  MEAN(activities.activity_date_day_of_month_cos)__90_days                                     34964 non-null  float64
#  362  MEAN(activities.activity_date_day_of_month_sin)__90_days                                     34964 non-null  float64
#  363  MEAN(activities.activity_date_day_of_week_cos)__90_days                                      34964 non-null  float64
#  364  COUNT(comms WHERE cat_c3 = 7)__30_days                                                       34964 non-null  int64
#  365  COUNT(comms WHERE cat_c3 = 3)__30_days                                                       34964 non-null  int64
#  366  device_id_nunique                                                                            34964 non-null  float64
#  367  INTERACTION_activity_per_trans                                                               34964 non-null  float64
#  368  INTERACTION_contact_per_trans                                                                34964 non-null  float64
#  369  INTERACTION_contact_per_activity                                                             34964 non-null  float64
#  370  BALANCE_net_flow                                                                             34964 non-null  float64
#  371  BALANCE_savings_potential                                                                    34964 non-null  float64
#  372  tran_date_gap_days__median                                                                   34964 non-null  float64
#  373  tran_date_gap_days__mean                                                                     34964 non-null  float64
#  374  tran_date_gap_days__maximum                                                                  34964 non-null  float64
#  375  tran_date_gap_days__skewness                                                                 34964 non-null  float64
#  376  tran_date_gap_days__linear_trend__attr_"slope"                                               34964 non-null  float64
#  377  tran_date_gap_days__approximate_entropy__m_2__r_0.25                                         34964 non-null  float64
#  378  tran_date_gap_days__ratio_beyond_r_sigma__r_2                                                34964 non-null  float64
#  379  tran_date_gap_days__autocorrelation__lag_1                                                   34964 non-null  float64
#  380  tran_date_gap_days__longest_strike_above_mean                                                34964 non-null  float64
#  381  tran_date_gap_days__longest_strike_below_mean                                                34964 non-null  float64
#  382  float_c18_diff__median                                                                       34964 non-null  float64
#  383  float_c18_diff__skewness                                                                     34964 non-null  float64
#  384  float_c18_diff__quantile__q_0.25                                                             34964 non-null  float64
#  385  float_c18_diff__quantile__q_0.75                                                             34964 non-null  float64
#  386  float_c18_diff__approximate_entropy__m_2__r_0.25                                             34964 non-null  float64
#  387  float_c18_diff__ratio_beyond_r_sigma__r_2                                                    34964 non-null  float64
#  388  float_c18_diff__autocorrelation__lag_1                                                       34964 non-null  float64
#  389  float_c18_diff__longest_strike_above_mean                                                    34964 non-null  float64
#  390  float_c18_diff__longest_strike_below_mean                                                    34964 non-null  float64
#  391  activity_date_gap_days__median                                                               34964 non-null  float64
#  392  activity_date_gap_days__mean                                                                 34964 non-null  float64
#  393  activity_date_gap_days__maximum                                                              34964 non-null  float64
#  394  activity_date_gap_days__skewness                                                             34964 non-null  float64
#  395  activity_date_gap_days__linear_trend__attr_"slope"                                           34964 non-null  float64
#  396  activity_date_gap_days__approximate_entropy__m_2__r_0.25                                     34964 non-null  float64
#  397  activity_date_gap_days__ratio_beyond_r_sigma__r_2                                            34964 non-null  float64
#  398  activity_date_gap_days__autocorrelation__lag_1                                               34964 non-null  float64
#  399  activity_date_gap_days__longest_strike_above_mean                                            34964 non-null  float64
#  400  activity_date_gap_days__longest_strike_below_mean                                            34964 non-null  float64
#  401  contact_date_gap_days__maximum                                                               34964 non-null  float64
#  402  contact_date_gap_days__skewness                                                              34964 non-null  float64
#  403  contact_date_gap_days__quantile__q_0.25                                                      34964 non-null  float64
#  404  contact_date_gap_days__linear_trend__attr_"slope"                                            34964 non-null  float64
#  405  contact_date_gap_days__ratio_beyond_r_sigma__r_2                                             34964 non-null  float64
#  406  contact_date_gap_days__autocorrelation__lag_1                                                34964 non-null  float64
#  407  contact_date_gap_days__longest_strike_above_mean                                             34964 non-null  float64
#  408  STD(transactions.float_c16 WHERE cat_c3 = 305)_na                                            34964 non-null  int64
#  409  FIRST(activities.activity_date)_days                                                         34964 non-null  int64
#  410  MONTH(communication_month)_sin                                                               34964 non-null  float64
#  411  WEEKDAY(communication_month)_sin                                                             34964 non-null  float64
#  412  WEEKDAY(communication_month)_cos                                                             34964 non-null  float64
#  413  MODE(transactions.cat_c2)_14                                                                 34964 non-null  int64
#  414  MODE(transactions.cat_c2)_Rare                                                               34964 non-null  int64
#  415  MODE(transactions.cat_c2)_4                                                                  34964 non-null  int64
#  416  MODE(transactions.cat_c2)_15                                                                 34964 non-null  int64
#  417  MODE(transactions.cat_c2)_1                                                                  34964 non-null  int64
#  418  MODE(transactions.cat_c3)_305                                                                34964 non-null  int64
#  419  MODE(transactions.cat_c3)_314                                                                34964 non-null  int64
#  420  MODE(transactions.cat_c3)_Rare                                                               34964 non-null  int64
#  421  MODE(transactions.cat_c3)_303                                                                34964 non-null  int64
#  422  MODE(transactions.cat_c3)_312                                                                34964 non-null  int64
#  423  MODE(activities.cat_c6)_4                                                                    34964 non-null  int64
#  424  MODE(activities.cat_c6)_Rare                                                                 34964 non-null  int64
#  425  MODE(activities.cat_c6)_8                                                                    34964 non-null  int64
#  426  MODE(comms.cat_c2)_S3769                                                                     34964 non-null  int64
#  427  MODE(comms.cat_c2)_Rare                                                                      34964 non-null  int64
#  428  MODE(comms.cat_c2)_S27888                                                                    34964 non-null  int64
#  429  MODE(comms.cat_c2)_S3563                                                                     34964 non-null  int64
#  430  MODE(comms.cat_c4)_1                                                                         34964 non-null  int64
# dtypes: float64(383), int64(48)
# memory usage: 115.0 MB
# None
#        COUNT(transactions)  ENTROPY(transactions.cat_c2)  \
# count         34964.000000                  34964.000000
# mean            447.722171                      1.574397
# std             474.127701                      0.402746
# min               2.000000                      0.000000
# 25%             122.000000                      1.329142
# 50%             309.000000                      1.620685
# 75%             616.000000                      1.855134
# max            8721.000000                      2.720781
#
#        ENTROPY(transactions.cat_c4)  KURTOSIS(transactions.float_c16)  \
# count                  34964.000000                      34964.000000
# mean                       0.105946                         78.719137
# std                        0.190807                        146.909330
# min                        0.000000                         -2.000000
# 25%                        0.000000                          0.000000
# 50%                        0.015948                         27.623509
# 75%                        0.126522                         93.020321
# max                        2.159006                       3572.595778
#
#        KURTOSIS(transactions.float_c17)  KURTOSIS(transactions.float_c18)  \
# count                      34964.000000                      34964.000000
# mean                         132.415299                         42.100321
# std                          225.166766                         57.951094
# min                           -2.000000                         -2.000000
# 25%                            0.000000                         11.095781
# 50%                           34.185537                         25.522798
# 75%                          176.602358                         51.168443
# max                         2741.303377                       1350.808942
#
#        KURTOSIS(transactions.float_c20)  KURTOSIS(transactions.int_c19)  \
# count                      34964.000000                    34964.000000
# mean                          16.052793                       -0.719137
# std                          112.541100                        2.653992
# min                           -2.000000                       -2.000000
# 25%                            0.000000                       -1.807487
# 50%                            0.000000                       -1.327778
# 75%                            0.000000                       -0.379546
# max                         3767.000265                      259.670459
#
#        MAX(transactions.float_c16)  MAX(transactions.float_c17)  ...  \
# count                 34964.000000                 34964.000000  ...
# mean                      1.619920                     4.577120  ...
# std                       4.867832                    19.215062  ...
# min                       0.000000                     0.000000  ...
# 25%                       0.000000                     0.000000  ...
# 50%                       0.470000                     1.000000  ...
# 75%                       1.660000                     4.010000  ...
# max                     413.130005                  2294.719971  ...
#
#        MODE(transactions.cat_c3)_303  MODE(transactions.cat_c3)_312  \
# count                   34964.000000                   34964.000000
# mean                        0.047763                       0.020135
# std                         0.213268                       0.140464
# min                         0.000000                       0.000000
# 25%                         0.000000                       0.000000
# 50%                         0.000000                       0.000000
# 75%                         0.000000                       0.000000
# max                         1.000000                       1.000000
#
#        MODE(activities.cat_c6)_4  MODE(activities.cat_c6)_Rare  \
# count               34964.000000                  34964.000000
# mean                    0.052540                      0.016131
# std                     0.223116                      0.125981
# min                     0.000000                      0.000000
# 25%                     0.000000                      0.000000
# 50%                     0.000000                      0.000000
# 75%                     0.000000                      0.000000
# max                     1.000000                      1.000000
#
#        MODE(activities.cat_c6)_8  MODE(comms.cat_c2)_S3769  \
# count               34964.000000              34964.000000
# mean                    0.028515                  0.030202
# std                     0.166441                  0.171147
# min                     0.000000                  0.000000
# 25%                     0.000000                  0.000000
# 50%                     0.000000                  0.000000
# 75%                     0.000000                  0.000000
# max                     1.000000                  1.000000
#
#        MODE(comms.cat_c2)_Rare  MODE(comms.cat_c2)_S27888  \
# count             34964.000000               34964.000000
# mean                  0.039183                   0.013957
# std                   0.194033                   0.117315
# min                   0.000000                   0.000000
# 25%                   0.000000                   0.000000
# 50%                   0.000000                   0.000000
# 75%                   0.000000                   0.000000
# max                   1.000000                   1.000000
#
#        MODE(comms.cat_c2)_S3563  MODE(comms.cat_c4)_1
# count              34964.000000          34964.000000
# mean                   0.010439              0.945744
# std                    0.101640              0.226525
# min                    0.000000              0.000000
# 25%                    0.000000              1.000000
# 50%                    0.000000              1.000000
# 75%                    0.000000              1.000000
# max                    1.000000              1.000000
#
# [8 rows x 431 columns]

# %%
FILTER_OUT_PATH = '../data/features_selected/features_v{}_filtered_v{}.csv'.format(FEATURES_VERSION, SELECTION_VERSION)

pd.concat([X_filtered, clients_data], axis=1).to_csv(FILTER_OUT_PATH, index=False)

# %% [markdown]
# ## Embedded

# %%
# """L1 regularization"""
#
# log_l1 = LogisticRegression(
#     penalty='l1',
#     solver='saga',
#     max_iter=500,
#     class_weight='balanced',
#     n_jobs=6,
#     random_state=42,
#     verbose=1,
# )
# sfm = SelectFromModel(log_l1, threshold='median')
#
# sfm.fit(X_filtered, y)
#
# selected_l1_features = X_filtered.columns[sfm.get_support()]
# X_l1 = X_filtered[selected_l1_features]
# Out:
# C:\Users\dan\PycharmProjects\ds\ff_internship\.venv\Lib\site-packages\sklearn\linear_model\_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(

# %%
"""Select top features from LightGBM model"""

lgb = LGBMClassifier(
    n_estimators=500,
    learning_rate=0.05,
    predict_disable_shape_check=True,
    random_state=42,
    n_jobs=6,
)

lgb_data = X_filtered.rename(columns=lambda x: re.sub(r'[,\n\[\]\{\}:"]', '_', x))
lgb.fit(lgb_data, y)

importances = lgb.feature_importances_
indices = np.argsort(importances)[::-1]

top100 = X_filtered.columns[indices[:200]]
X_lgb_imp = X_filtered[top100]
# Out:
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 8554, number of negative: 26410
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.040767 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 86878
# [LightGBM] [Info] Number of data points in the train set: 34964, number of used features: 431
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.244652 -> initscore=-1.127344
# [LightGBM] [Info] Start training from score -1.127344

# %%
top100 = X_filtered.columns[indices[:200]]
X_lgb_imp = X_filtered[top100]

# %%
# """Permutation Importance"""
#
# perm = permutation_importance(
#     lgb, X_lgb_imp, y,
#     n_repeats=10,
#     scoring='roc_auc',
#     n_jobs=6,
#     random_state=42,
# )
#
# perm_sorted_idx = perm.importances_mean.argsort()[::-1]
# selected_perm = [top100[i] for i in perm_sorted_idx if perm.importances_mean[i] < 0]
#
# X_pi = X_lgb_imp[selected_perm]

# %%
X_embedded = X_lgb_imp
display(X_embedded.info(verbose=True, show_counts=True))
display(X_embedded.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34964 entries, 0 to 34963
# Data columns (total 200 columns):
#  #    Column                                                                                  Non-Null Count  Dtype
# ---   ------                                                                                  --------------  -----
#  0    INTERACTION_contact_per_trans                                                           34964 non-null  float64
#  1    ENTROPY(comms.cat_c3)                                                                   34964 non-null  float64
#  2    MEAN(comms.contact_date_day_of_month_cos WHERE cat_c3 = 3)                              34964 non-null  float64
#  3    COUNT(comms WHERE cat_c4 = 2)                                                           34964 non-null  int64
#  4    ENTROPY(comms.cat_c5)                                                                   34964 non-null  float64
#  5    MEAN(comms.contact_date_day_of_month_sin WHERE cat_c4 = 2)                              34964 non-null  float64
#  6    MEAN(comms.contact_date_day_of_month_sin WHERE cat_c3 = 3)                              34964 non-null  float64
#  7    ENTROPY(comms.cat_c2)                                                                   34964 non-null  float64
#  8    PERCENT_TRUE(transactions.fl_c15)                                                       34964 non-null  float64
#  9    COUNT(comms WHERE cat_c3 = 3)                                                           34964 non-null  int64
#  10   BALANCE_savings_potential                                                               34964 non-null  float64
#  11   MEAN(transactions.float_c18)                                                            34964 non-null  float64
#  12   BALANCE_net_flow                                                                        34964 non-null  float64
#  13   MEAN(comms.contact_date_day_of_week_sin WHERE cat_c3 = 3)                               34964 non-null  float64
#  14   MEAN(activities.float_c12)                                                              34964 non-null  float64
#  15   SUM(transactions.int_c19 WHERE cat_c3 = 305)                                            34964 non-null  float64
#  16   ENTROPY(transactions.cat_c2)                                                            34964 non-null  float64
#  17   COUNT(transactions WHERE cat_c2 = 15)__30_days                                          34964 non-null  int64
#  18   COUNT(activities WHERE cat_c10 = True)                                                  34964 non-null  int64
#  19   MEAN(transactions.float_c18 WHERE fl_c13 = True)                                        34964 non-null  float64
#  20   contact_date_gap_days__autocorrelation__lag_1                                           34964 non-null  float64
#  21   activity_date_gap_days__mean                                                            34964 non-null  float64
#  22   MEAN(transactions.int_c19 WHERE cat_c3 = 305)                                           34964 non-null  float64
#  23   MEAN(comms.contact_date_day_of_week_sin WHERE cat_c2 = S3769)                           34964 non-null  float64
#  24   PERCENT_TRUE(transactions.fl_c12)                                                       34964 non-null  float64
#  25   float_c18_diff__autocorrelation__lag_1                                                  34964 non-null  float64
#  26   SKEW(activities.float_c11)                                                              34964 non-null  float64
#  27   MEAN(activities.activity_date_day_of_week_sin)__30_days                                 34964 non-null  float64
#  28   MIN(transactions.float_c18 WHERE cat_c2 = 15)                                           34964 non-null  float64
#  29   KURTOSIS(activities.float_c14)                                                          34964 non-null  float64
#  30   MEAN(transactions.tran_date_day_of_month_sin WHERE tran_date_is_weekend = True)         34964 non-null  float64
#  31   MEAN(comms.contact_date_day_of_month_cos WHERE cat_c3 = 7)                              34964 non-null  float64
#  32   float_c18_diff__skewness                                                                34964 non-null  float64
#  33   MEAN(activities.activity_date_day_of_week_sin)                                          34964 non-null  float64
#  34   MEAN(comms.contact_date_day_of_week_cos WHERE cat_c4 = 2)                               34964 non-null  float64
#  35   contact_date_gap_days__linear_trend__attr_"slope"                                       34964 non-null  float64
#  36   MEAN(transactions.tran_date_day_of_month_sin WHERE cat_c3 = 305)                        34964 non-null  float64
#  37   MEAN(activities.activity_date_day_of_month_sin WHERE cat_c10 = False)                   34964 non-null  float64
#  38   COUNT(comms WHERE cat_c5 = 7)                                                           34964 non-null  int64
#  39   MEAN(transactions.tran_date_day_of_week_cos WHERE cat_c3 = 305)                         34964 non-null  float64
#  40   activity_date_gap_days__autocorrelation__lag_1                                          34964 non-null  float64
#  41   MEAN(transactions.int_c19 WHERE cat_c3 = 303)                                           34964 non-null  float64
#  42   KURTOSIS(activities.float_c12)                                                          34964 non-null  float64
#  43   STD(activities.float_c11)                                                               34964 non-null  float64
#  44   MIN(transactions.float_c18 WHERE cat_c2 = 14)                                           34964 non-null  float64
#  45   INTERACTION_contact_per_activity                                                        34964 non-null  float64
#  46   TIME_SINCE_LAST(comms.contact_date WHERE cat_c4 = 2, unit=days)                         34964 non-null  float64
#  47   MEAN(comms.contact_date_day_of_week_sin WHERE cat_c4 = 2)                               34964 non-null  float64
#  48   MEAN(transactions.tran_date_day_of_month_cos)__30_days                                  34964 non-null  float64
#  49   contact_date_gap_days__skewness                                                         34964 non-null  float64
#  50   MEAN(transactions.int_c19 WHERE cat_c3 = 314)                                           34964 non-null  float64
#  51   MEAN(transactions.tran_date_day_of_week_cos WHERE cat_c2 = 15)                          34964 non-null  float64
#  52   MEAN(activities.activity_date_day_of_month_sin)__90_days                                34964 non-null  float64
#  53   MEAN(activities.activity_date_day_of_month_cos WHERE activity_date_is_weekend = False)  34964 non-null  float64
#  54   MEAN(transactions.tran_date_day_of_month_sin)__30_days                                  34964 non-null  float64
#  55   MEAN(comms.contact_date_day_of_week_cos WHERE cat_c3 = 3)                               34964 non-null  float64
#  56   activity_date_gap_days__skewness                                                        34964 non-null  float64
#  57   MEAN(activities.activity_date_day_of_week_cos)__90_days                                 34964 non-null  float64
#  58   MEAN(comms.contact_date_day_of_month_sin WHERE cat_c2 = S3769)                          34964 non-null  float64
#  59   MIN(activities.float_c11)                                                               34964 non-null  float64
#  60   MEAN(activities.activity_date_day_of_month_cos WHERE activity_date_is_weekend = True)   34964 non-null  float64
#  61   tran_date_gap_days__ratio_beyond_r_sigma__r_2                                           34964 non-null  float64
#  62   tran_date_gap_days__skewness                                                            34964 non-null  float64
#  63   MEAN(comms.contact_date_day_of_week_cos WHERE cat_c2 = S3677)                           34964 non-null  float64
#  64   MEAN(comms.contact_date_day_of_month_sin WHERE cat_c3 = 7)                              34964 non-null  float64
#  65   MEAN(transactions.float_c18)__30_days                                                   34964 non-null  float64
#  66   MEAN(transactions.tran_date_day_of_week_cos WHERE cat_c2 = 4)                           34964 non-null  float64
#  67   MEAN(transactions.float_c21 WHERE cat_c2 = 15)                                          34964 non-null  float64
#  68   MEAN(comms.contact_date_day_of_week_cos WHERE contact_date_is_weekend = False)          34964 non-null  float64
#  69   contact_date_gap_days__ratio_beyond_r_sigma__r_2                                        34964 non-null  float64
#  70   ENTROPY(activities.cat_c5)                                                              34964 non-null  float64
#  71   PERCENT_TRUE(activities.activity_date_is_weekend)__30_days                              34964 non-null  float64
#  72   float_c18_diff__ratio_beyond_r_sigma__r_2                                               34964 non-null  float64
#  73   MEAN(transactions.tran_date_day_of_week_cos WHERE cat_c3 = 303)                         34964 non-null  float64
#  74   activity_date_gap_days__approximate_entropy__m_2__r_0.25                                34964 non-null  float64
#  75   MEAN(transactions.tran_date_day_of_week_cos)__30_days                                   34964 non-null  float64
#  76   MEAN(activities.activity_date_day_of_month_sin WHERE cat_c4 = 2)                        34964 non-null  float64
#  77   PERCENT_TRUE(transactions.tran_date_is_weekend)                                         34964 non-null  float64
#  78   KURTOSIS(activities.float_c11)                                                          34964 non-null  float64
#  79   MEAN(transactions.tran_date_day_of_month_cos)                                           34964 non-null  float64
#  80   MEAN(comms.contact_date_day_of_week_sin WHERE cat_c2 = S3677)                           34964 non-null  float64
#  81   MEAN(transactions.float_c18 WHERE cat_c2 = 4)                                           34964 non-null  float64
#  82   MEAN(comms.contact_date_day_of_week_cos WHERE contact_date_is_weekend = True)           34964 non-null  float64
#  83   MEAN(activities.activity_date_day_of_month_cos WHERE cat_c4 = 2)                        34964 non-null  float64
#  84   MEAN(transactions.tran_date_day_of_month_cos WHERE cat_c2 = 4)                          34964 non-null  float64
#  85   MEAN(transactions.tran_date_day_of_month_cos WHERE tran_date_is_weekend = True)         34964 non-null  float64
#  86   INTERACTION_activity_per_trans                                                          34964 non-null  float64
#  87   tran_date_gap_days__approximate_entropy__m_2__r_0.25                                    34964 non-null  float64
#  88   float_c18_diff__quantile__q_0.75                                                        34964 non-null  float64
#  89   PERCENT_TRUE(activities.activity_date_is_weekend)                                       34964 non-null  float64
#  90   STD(activities.float_c12 WHERE activity_date_is_weekend = False)                        34964 non-null  float64
#  91   MEAN(transactions.tran_date_day_of_week_sin)__30_days                                   34964 non-null  float64
#  92   PERCENT_TRUE(transactions.fl_c6)                                                        34964 non-null  float64
#  93   PERCENT_TRUE(transactions.fl_c13)                                                       34964 non-null  float64
#  94   activity_date_gap_days__ratio_beyond_r_sigma__r_2                                       34964 non-null  float64
#  95   tran_date_gap_days__autocorrelation__lag_1                                              34964 non-null  float64
#  96   MAX(activities.float_c11)                                                               34964 non-null  float64
#  97   MIN(activities.float_c14)                                                               34964 non-null  float64
#  98   MEAN(activities.activity_date_day_of_month_cos WHERE cat_c10 = False)                   34964 non-null  float64
#  99   MEAN(transactions.tran_date_day_of_month_sin WHERE cat_c2 = 15)                         34964 non-null  float64
#  100  STD(transactions.int_c19 WHERE tran_date_is_weekend = True)                             34964 non-null  float64
#  101  STD(activities.float_c12 WHERE activity_date_is_weekend = True)                         34964 non-null  float64
#  102  MEAN(transactions.tran_date_day_of_month_sin)                                           34964 non-null  float64
#  103  MEAN(transactions.tran_date_day_of_month_cos WHERE cat_c3 = 305)                        34964 non-null  float64
#  104  MEAN(comms.contact_date_day_of_week_cos WHERE cat_c2 = S3769)                           34964 non-null  float64
#  105  SKEW(activities.float_c14)                                                              34964 non-null  float64
#  106  MEAN(transactions.tran_date_day_of_month_cos WHERE cat_c3 = 303)                        34964 non-null  float64
#  107  MEAN(transactions.tran_date_day_of_week_sin WHERE cat_c3 = 303)                         34964 non-null  float64
#  108  SUM(activities.float_c12 WHERE activity_date_is_weekend = True)__30_days                34964 non-null  float64
#  109  MEAN(comms.contact_date_day_of_month_sin WHERE cat_c5 = 7)                              34964 non-null  float64
#  110  MEAN(transactions.float_c16 WHERE fl_c13 = True)                                        34964 non-null  float64
#  111  MEAN(comms.contact_date_day_of_week_cos WHERE cat_c3 = 7)                               34964 non-null  float64
#  112  MEAN(transactions.tran_date_day_of_week_sin WHERE cat_c2 = 15)                          34964 non-null  float64
#  113  MEAN(comms.contact_date_day_of_month_cos WHERE cat_c2 = S3769)                          34964 non-null  float64
#  114  KURTOSIS(transactions.float_c18)                                                        34964 non-null  float64
#  115  MEAN(activities.activity_date_day_of_month_cos)__90_days                                34964 non-null  float64
#  116  activity_date_gap_days__maximum                                                         34964 non-null  float64
#  117  MEAN(activities.activity_date_day_of_week_cos)                                          34964 non-null  float64
#  118  MEAN(transactions.tran_date_day_of_week_cos)                                            34964 non-null  float64
#  119  MAX(transactions.float_c16 WHERE fl_c14 = False)                                        34964 non-null  float64
#  120  COUNT(activities WHERE cat_c9 = 2)                                                      34964 non-null  int64
#  121  MIN(transactions.float_c18 WHERE tran_date_is_weekend = True)                           34964 non-null  float64
#  122  MEAN(activities.activity_date_day_of_week_sin WHERE cat_c10 = False)                    34964 non-null  float64
#  123  MEAN(activities.activity_date_day_of_week_cos WHERE activity_date_is_weekend = True)    34964 non-null  float64
#  124  SUM(activities.float_c14 WHERE cat_c4 = 2)                                              34964 non-null  float64
#  125  MEAN(activities.activity_date_day_of_week_cos WHERE cat_c4 = 2)                         34964 non-null  float64
#  126  MEAN(activities.activity_date_day_of_month_sin WHERE cat_c8 = True)                     34964 non-null  float64
#  127  MEAN(transactions.tran_date_day_of_month_cos WHERE cat_c2 = 15)                         34964 non-null  float64
#  128  MAX(transactions.float_c18 WHERE fl_c14 = True)                                         34964 non-null  float64
#  129  MEAN(transactions.float_c18 WHERE cat_c3 = 303)                                         34964 non-null  float64
#  130  MEAN(transactions.tran_date_day_of_week_sin WHERE cat_c3 = 305)                         34964 non-null  float64
#  131  SUM(activities.float_c14)                                                               34964 non-null  float64
#  132  MEAN(comms.contact_date_day_of_month_cos WHERE cat_c5 = 7)                              34964 non-null  float64
#  133  MEAN(transactions.tran_date_day_of_month_sin WHERE cat_c3 = 303)                        34964 non-null  float64
#  134  MEAN(comms.contact_date_day_of_week_sin WHERE contact_date_is_weekend = False)          34964 non-null  float64
#  135  MEAN(comms.contact_date_day_of_week_sin WHERE cat_c5 = 7)                               34964 non-null  float64
#  136  SUM(activities.float_c11)                                                               34964 non-null  float64
#  137  tran_date_gap_days__mean                                                                34964 non-null  float64
#  138  SUM(transactions.float_c16)                                                             34964 non-null  float64
#  139  MEAN(transactions.tran_date_day_of_week_sin)                                            34964 non-null  float64
#  140  MEAN(transactions.tran_date_day_of_month_sin WHERE cat_c2 = 4)                          34964 non-null  float64
#  141  MEAN(transactions.tran_date_day_of_week_sin WHERE cat_c2 = 4)                           34964 non-null  float64
#  142  MAX(transactions.float_c16)                                                             34964 non-null  float64
#  143  MIN(transactions.float_c18)                                                             34964 non-null  float64
#  144  MEAN(transactions.float_c18 WHERE cat_c3 = 305)                                         34964 non-null  float64
#  145  TIME_SINCE_LAST(comms.contact_date WHERE cat_c5 = 7, unit=days)                         34964 non-null  float64
#  146  MEAN(transactions.tran_date_day_of_month_sin WHERE fl_c13 = True)                       34964 non-null  float64
#  147  MEAN(transactions.tran_date_day_of_week_sin WHERE fl_c13 = True)                        34964 non-null  float64
#  148  MEAN(comms.contact_date_day_of_month_cos WHERE contact_date_is_weekend = False)         34964 non-null  float64
#  149  STD(transactions.int_c19 WHERE fl_c13 = False)                                          34964 non-null  float64
#  150  MAX(transactions.float_c18 WHERE fl_c13 = True)                                         34964 non-null  float64
#  151  MAX(transactions.float_c18 WHERE cat_c3 = 303)                                          34964 non-null  float64
#  152  MEAN(activities.activity_date_day_of_week_cos WHERE cat_c10 = False)                    34964 non-null  float64
#  153  MEAN(activities.activity_date_day_of_week_sin WHERE cat_c4 = 2)                         34964 non-null  float64
#  154  PERCENT_TRUE(transactions.fl_c7)__90_days                                               34964 non-null  float64
#  155  activity_date_gap_days__linear_trend__attr_"slope"                                      34964 non-null  float64
#  156  MEAN(comms.contact_date_day_of_week_sin WHERE cat_c3 = 7)                               34964 non-null  float64
#  157  MEAN(comms.contact_date_day_of_week_cos WHERE cat_c5 = 7)                               34964 non-null  float64
#  158  tran_date_gap_days__maximum                                                             34964 non-null  float64
#  159  MAX(transactions.float_c18)                                                             34964 non-null  float64
#  160  SUM(transactions.float_c18 WHERE cat_c3 = 303)__30_days                                 34964 non-null  float64
#  161  float_c18_diff__quantile__q_0.25                                                        34964 non-null  float64
#  162  COUNT(activities WHERE cat_c10 = False)                                                 34964 non-null  int64
#  163  MEAN(transactions.tran_date_day_of_week_cos WHERE fl_c13 = True)                        34964 non-null  float64
#  164  MEAN(activities.activity_date_day_of_month_sin WHERE activity_date_is_weekend = True)   34964 non-null  float64
#  165  MEAN(activities.activity_date_day_of_week_cos)__30_days                                 34964 non-null  float64
#  166  PERCENT_TRUE(transactions.tran_date_is_weekend)__30_days                                34964 non-null  float64
#  167  MEAN(transactions.float_c16)__30_days                                                   34964 non-null  float64
#  168  MEAN(transactions.tran_date_day_of_month_cos WHERE fl_c13 = True)                       34964 non-null  float64
#  169  MIN(activities.float_c14 WHERE cat_c10 = False)                                         34964 non-null  float64
#  170  KURTOSIS(transactions.float_c17)                                                        34964 non-null  float64
#  171  tran_date_gap_days__longest_strike_below_mean                                           34964 non-null  float64
#  172  PERCENT_TRUE(transactions.tran_date_is_weekend)__90_days                                34964 non-null  float64
#  173  SUM(transactions.float_c18 WHERE cat_c3 = 305)__30_days                                 34964 non-null  float64
#  174  MEAN(transactions.int_c19)                                                              34964 non-null  float64
#  175  COUNT(comms WHERE cat_c3 = 7)                                                           34964 non-null  int64
#  176  MIN(activities.float_c14 WHERE cat_c4 = 2)                                              34964 non-null  float64
#  177  COUNT(transactions WHERE cat_c2 = 4)                                                    34964 non-null  int64
#  178  PERCENT_TRUE(transactions.fl_c6)__30_days                                               34964 non-null  float64
#  179  SUM(activities.float_c14 WHERE cat_c8 = True)                                           34964 non-null  float64
#  180  MAX(transactions.float_c21 WHERE cat_c2 = 15)                                           34964 non-null  float64
#  181  STD(transactions.float_c21 WHERE int_c19 = -1)                                          34964 non-null  float64
#  182  COUNT(comms WHERE cat_c2 = S3769)                                                       34964 non-null  int64
#  183  MEAN(transactions.tran_date_day_of_week_cos WHERE tran_date_is_weekend = True)          34964 non-null  float64
#  184  MEAN(transactions.tran_date_day_of_week_sin WHERE tran_date_is_weekend = True)          34964 non-null  float64
#  185  TIME_SINCE_LAST(comms.contact_date WHERE cat_c3 = 3, unit=days)                         34964 non-null  float64
#  186  MEAN(activities.activity_date_day_of_month_sin WHERE cat_c9 = 2)                        34964 non-null  float64
#  187  MIN(activities.float_c12 WHERE cat_c4 = 2)                                              34964 non-null  float64
#  188  COUNT(transactions)                                                                     34964 non-null  int64
#  189  MIN(activities.float_c12 WHERE cat_c10 = False)                                         34964 non-null  float64
#  190  tran_date_gap_days__linear_trend__attr_"slope"                                          34964 non-null  float64
#  191  activity_date_gap_days__longest_strike_below_mean                                       34964 non-null  float64
#  192  KURTOSIS(transactions.int_c19)                                                          34964 non-null  float64
#  193  PERCENT_TRUE(activities.cat_c10)                                                        34964 non-null  float64
#  194  SUM(transactions.float_c16 WHERE fl_c13 = True)__30_days                                34964 non-null  float64
#  195  float_c18_diff__approximate_entropy__m_2__r_0.25                                        34964 non-null  float64
#  196  SUM(transactions.float_c18 WHERE cat_c3 = 303)                                          34964 non-null  float64
#  197  MEAN(transactions.float_c18 WHERE fl_c14 = True)                                        34964 non-null  float64
#  198  MAX(transactions.float_c18 WHERE tran_date_is_weekend = True)                           34964 non-null  float64
#  199  MIN(activities.float_c14 WHERE cat_c8 = True)                                           34964 non-null  float64
# dtypes: float64(189), int64(11)
# memory usage: 53.4 MB
# None
#        INTERACTION_contact_per_trans  ENTROPY(comms.cat_c3)  \
# count                          34964                  34964
# mean                               1                      0
# std                                1                      0
# min                                0                      0
# 25%                                1                      0
# 50%                                1                      0
# 75%                                1                      0
# max                               65                      1
#
#        MEAN(comms.contact_date_day_of_month_cos WHERE cat_c3 = 3)  \
# count                                              34964
# mean                                                   0
# std                                                    0
# min                                                    0
# 25%                                                    0
# 50%                                                    0
# 75%                                                    0
# max                                                    1
#
#        COUNT(comms WHERE cat_c4 = 2)  ENTROPY(comms.cat_c5)  \
# count                          34964                  34964
# mean                              42                      0
# std                               14                      0
# min                                0                      0
# 25%                               33                      0
# 50%                               42                      0
# 75%                               51                      0
# max                              362                      1
#
#        MEAN(comms.contact_date_day_of_month_sin WHERE cat_c4 = 2)  \
# count                                              34964
# mean                                                   0
# std                                                    0
# min                                                    0
# 25%                                                    0
# 50%                                                    0
# 75%                                                    0
# max                                                    0
#
#        MEAN(comms.contact_date_day_of_month_sin WHERE cat_c3 = 3)  \
# count                                              34964
# mean                                                   0
# std                                                    0
# min                                                    0
# 25%                                                    0
# 50%                                                    0
# 75%                                                    0
# max                                                    0
#
#        ENTROPY(comms.cat_c2)  PERCENT_TRUE(transactions.fl_c15)  \
# count                  34964                              34964
# mean                       2                                  0
# std                        0                                  0
# min                        0                                  0
# 25%                        2                                  0
# 50%                        2                                  0
# 75%                        2                                  0
# max                        4                                  0
#
#        COUNT(comms WHERE cat_c3 = 3)  ...  \
# count                          34964  ...
# mean                              13  ...
# std                                5  ...
# min                                0  ...
# 25%                               10  ...
# 50%                               13  ...
# 75%                               17  ...
# max                              115  ...
#
#        tran_date_gap_days__linear_trend__attr_"slope"  \
# count                                           34964
# mean                                                0
# std                                                 1
# min                                               -14
# 25%                                                 0
# 50%                                                 0
# 75%                                                 0
# max                                                83
#
#        activity_date_gap_days__longest_strike_below_mean  \
# count                                              34964
# mean                                                  18
# std                                                   11
# min                                                    0
# 25%                                                   12
# 50%                                                   17
# 75%                                                   23
# max                                                  275
#
#        KURTOSIS(transactions.int_c19)  PERCENT_TRUE(activities.cat_c10)  \
# count                           34964                             34964
# mean                                0                                 0
# std                                 2                                 0
# min                                -2                                 0
# 25%                                -1                                 0
# 50%                                -1                                 0
# 75%                                 0                                 0
# max                               259                                 1
#
#        SUM(transactions.float_c16 WHERE fl_c13 = True)__30_days  \
# count                                              34964
# mean                                                   1
# std                                                    4
# min                                                    0
# 25%                                                    0
# 50%                                                    0
# 75%                                                    1
# max                                                  189
#
#        float_c18_diff__approximate_entropy__m_2__r_0.25  \
# count                                             34964
# mean                                                  0
# std                                                   0
# min                                                   0
# 25%                                                   0
# 50%                                                   0
# 75%                                                   0
# max                                                   1
#
#        SUM(transactions.float_c18 WHERE cat_c3 = 303)  \
# count                                           34964
# mean                                              793
# std                                              3464
# min                                                 0
# 25%                                                54
# 50%                                               225
# 75%                                               664
# max                                            219808
#
#        MEAN(transactions.float_c18 WHERE fl_c14 = True)  \
# count                                             34964
# mean                                                 17
# std                                                  45
# min                                                   0
# 25%                                                   5
# 50%                                                  10
# 75%                                                  19
# max                                                2856
#
#        MAX(transactions.float_c18 WHERE tran_date_is_weekend = True)  \
# count                                              34964
# mean                                                 819
# std                                                  989
# min                                                    0
# 25%                                                  250
# 50%                                                  500
# 75%                                                 1000
# max                                                35410
#
#        MIN(activities.float_c14 WHERE cat_c8 = True)
# count                                          34964
# mean                                               0
# std                                                0
# min                                                0
# 25%                                                0
# 50%                                                0
# 75%                                                0
# max                                               16
#
# [8 rows x 200 columns]

# %%
EMBEDDED_OUT_PATH = '../data/features_selected/features_v{}_embedded_v{}.csv'.format(FEATURES_VERSION, SELECTION_VERSION)

pd.concat([X_embedded, clients_data], axis=1).to_csv(EMBEDDED_OUT_PATH, index=False)

# %% [markdown]
# ## Wrapped

# %%
rfe = RFE(
    estimator=lgb,
    n_features_to_select=50,
    step=0.1,
    verbose=1,
)
rfe.fit(X_embedded, y)

selected_rfe_features = X_embedded.columns[rfe.get_support()]
X_rfe = X_embedded[selected_rfe_features]
# Out:
# Fitting estimator with 200 features.
# [LightGBM] [Info] Number of positive: 8554, number of negative: 26410
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.014311 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 48701
# [LightGBM] [Info] Number of data points in the train set: 34964, number of used features: 200
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.244652 -> initscore=-1.127344
# [LightGBM] [Info] Start training from score -1.127344
# Fitting estimator with 195 features.
# [LightGBM] [Info] Number of positive: 8554, number of negative: 26410
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.014020 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 47726
# [LightGBM] [Info] Number of data points in the train set: 34964, number of used features: 195
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.244652 -> initscore=-1.127344
# [LightGBM] [Info] Start training from score -1.127344
# Fitting estimator with 190 features.
# [LightGBM] [Info] Number of positive: 8554, number of negative: 26410
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.011083 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 46451
# [LightGBM] [Info] Number of data points in the train set: 34964, number of used features: 190
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.244652 -> initscore=-1.127344
# [LightGBM] [Info] Start training from score -1.127344
# Fitting estimator with 185 features.
# [LightGBM] [Info] Number of positive: 8554, number of negative: 26410
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.062859 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 45177
# [LightGBM] [Info] Number of data points in the train set: 34964, number of used features: 185
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.244652 -> initscore=-1.127344
# [LightGBM] [Info] Start training from score -1.127344
# Fitting estimator with 180 features.
# [LightGBM] [Info] Number of positive: 8554, number of negative: 26410
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.009222 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 44119
# [LightGBM] [Info] Number of data points in the train set: 34964, number of used features: 180
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.244652 -> initscore=-1.127344
# [LightGBM] [Info] Start training from score -1.127344
# Fitting estimator with 175 features.
# [LightGBM] [Info] Number of positive: 8554, number of negative: 26410
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.009125 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 42968
# [LightGBM] [Info] Number of data points in the train set: 34964, number of used features: 175
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.244652 -> initscore=-1.127344
# [LightGBM] [Info] Start training from score -1.127344
# Fitting estimator with 170 features.
# [LightGBM] [Info] Number of positive: 8554, number of negative: 26410
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.007901 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 41953
# [LightGBM] [Info] Number of data points in the train set: 34964, number of used features: 170
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.244652 -> initscore=-1.127344
# [LightGBM] [Info] Start training from score -1.127344
# Fitting estimator with 165 features.
# [LightGBM] [Info] Number of positive: 8554, number of negative: 26410
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.014869 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 40680
# [LightGBM] [Info] Number of data points in the train set: 34964, number of used features: 165
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.244652 -> initscore=-1.127344
# [LightGBM] [Info] Start training from score -1.127344
# Fitting estimator with 160 features.
# [LightGBM] [Info] Number of positive: 8554, number of negative: 26410
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.052098 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 39406
# [LightGBM] [Info] Number of data points in the train set: 34964, number of used features: 160
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.244652 -> initscore=-1.127344
# [LightGBM] [Info] Start training from score -1.127344
# Fitting estimator with 155 features.
# [LightGBM] [Info] Number of positive: 8554, number of negative: 26410
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.051648 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 38131
# [LightGBM] [Info] Number of data points in the train set: 34964, number of used features: 155
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.244652 -> initscore=-1.127344
# [LightGBM] [Info] Start training from score -1.127344
# Fitting estimator with 150 features.
# [LightGBM] [Info] Number of positive: 8554, number of negative: 26410
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.049855 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 37003
# [LightGBM] [Info] Number of data points in the train set: 34964, number of used features: 150
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.244652 -> initscore=-1.127344
# [LightGBM] [Info] Start training from score -1.127344
# Fitting estimator with 145 features.
# [LightGBM] [Info] Number of positive: 8554, number of negative: 26410
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.048356 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 35842
# [LightGBM] [Info] Number of data points in the train set: 34964, number of used features: 145
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.244652 -> initscore=-1.127344
# [LightGBM] [Info] Start training from score -1.127344
# Fitting estimator with 140 features.
# [LightGBM] [Info] Number of positive: 8554, number of negative: 26410
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.026498 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 34644
# [LightGBM] [Info] Number of data points in the train set: 34964, number of used features: 140
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.244652 -> initscore=-1.127344
# [LightGBM] [Info] Start training from score -1.127344
# Fitting estimator with 135 features.
# [LightGBM] [Info] Number of positive: 8554, number of negative: 26410
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.008132 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 33369
# [LightGBM] [Info] Number of data points in the train set: 34964, number of used features: 135
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.244652 -> initscore=-1.127344
# [LightGBM] [Info] Start training from score -1.127344
# Fitting estimator with 130 features.
# [LightGBM] [Info] Number of positive: 8554, number of negative: 26410
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.006198 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 32163
# [LightGBM] [Info] Number of data points in the train set: 34964, number of used features: 130
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.244652 -> initscore=-1.127344
# [LightGBM] [Info] Start training from score -1.127344
# Fitting estimator with 125 features.
# [LightGBM] [Info] Number of positive: 8554, number of negative: 26410
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.005970 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 30952
# [LightGBM] [Info] Number of data points in the train set: 34964, number of used features: 125
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.244652 -> initscore=-1.127344
# [LightGBM] [Info] Start training from score -1.127344
# Fitting estimator with 120 features.
# [LightGBM] [Info] Number of positive: 8554, number of negative: 26410
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.036029 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 29837
# [LightGBM] [Info] Number of data points in the train set: 34964, number of used features: 120
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.244652 -> initscore=-1.127344
# [LightGBM] [Info] Start training from score -1.127344
# Fitting estimator with 115 features.
# [LightGBM] [Info] Number of positive: 8554, number of negative: 26410
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.006608 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 28565
# [LightGBM] [Info] Number of data points in the train set: 34964, number of used features: 115
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.244652 -> initscore=-1.127344
# [LightGBM] [Info] Start training from score -1.127344
# Fitting estimator with 110 features.
# [LightGBM] [Info] Number of positive: 8554, number of negative: 26410
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.006970 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 27290
# [LightGBM] [Info] Number of data points in the train set: 34964, number of used features: 110
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.244652 -> initscore=-1.127344
# [LightGBM] [Info] Start training from score -1.127344
# Fitting estimator with 105 features.
# [LightGBM] [Info] Number of positive: 8554, number of negative: 26410
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.033806 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 26017
# [LightGBM] [Info] Number of data points in the train set: 34964, number of used features: 105
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.244652 -> initscore=-1.127344
# [LightGBM] [Info] Start training from score -1.127344
# Fitting estimator with 100 features.
# [LightGBM] [Info] Number of positive: 8554, number of negative: 26410
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.031559 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 24956
# [LightGBM] [Info] Number of data points in the train set: 34964, number of used features: 100
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.244652 -> initscore=-1.127344
# [LightGBM] [Info] Start training from score -1.127344
# Fitting estimator with 95 features.
# [LightGBM] [Info] Number of positive: 8554, number of negative: 26410
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.032959 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 23682
# [LightGBM] [Info] Number of data points in the train set: 34964, number of used features: 95
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.244652 -> initscore=-1.127344
# [LightGBM] [Info] Start training from score -1.127344
# Fitting estimator with 90 features.
# [LightGBM] [Info] Number of positive: 8554, number of negative: 26410
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.027716 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 22407
# [LightGBM] [Info] Number of data points in the train set: 34964, number of used features: 90
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.244652 -> initscore=-1.127344
# [LightGBM] [Info] Start training from score -1.127344
# Fitting estimator with 85 features.
# [LightGBM] [Info] Number of positive: 8554, number of negative: 26410
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.026366 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 21132
# [LightGBM] [Info] Number of data points in the train set: 34964, number of used features: 85
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.244652 -> initscore=-1.127344
# [LightGBM] [Info] Start training from score -1.127344
# Fitting estimator with 80 features.
# [LightGBM] [Info] Number of positive: 8554, number of negative: 26410
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.025655 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 19881
# [LightGBM] [Info] Number of data points in the train set: 34964, number of used features: 80
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.244652 -> initscore=-1.127344
# [LightGBM] [Info] Start training from score -1.127344
# Fitting estimator with 75 features.
# [LightGBM] [Info] Number of positive: 8554, number of negative: 26410
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.023892 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 18606
# [LightGBM] [Info] Number of data points in the train set: 34964, number of used features: 75
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.244652 -> initscore=-1.127344
# [LightGBM] [Info] Start training from score -1.127344
# Fitting estimator with 70 features.
# [LightGBM] [Info] Number of positive: 8554, number of negative: 26410
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.024986 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 17331
# [LightGBM] [Info] Number of data points in the train set: 34964, number of used features: 70
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.244652 -> initscore=-1.127344
# [LightGBM] [Info] Start training from score -1.127344
# Fitting estimator with 65 features.
# [LightGBM] [Info] Number of positive: 8554, number of negative: 26410
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.020357 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 16056
# [LightGBM] [Info] Number of data points in the train set: 34964, number of used features: 65
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.244652 -> initscore=-1.127344
# [LightGBM] [Info] Start training from score -1.127344
# Fitting estimator with 60 features.
# [LightGBM] [Info] Number of positive: 8554, number of negative: 26410
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.017776 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 14782
# [LightGBM] [Info] Number of data points in the train set: 34964, number of used features: 60
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.244652 -> initscore=-1.127344
# [LightGBM] [Info] Start training from score -1.127344
# Fitting estimator with 55 features.
# [LightGBM] [Info] Number of positive: 8554, number of negative: 26410
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.016668 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 13507
# [LightGBM] [Info] Number of data points in the train set: 34964, number of used features: 55
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.244652 -> initscore=-1.127344
# [LightGBM] [Info] Start training from score -1.127344
# [LightGBM] [Info] Number of positive: 8554, number of negative: 26410
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.015566 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12232
# [LightGBM] [Info] Number of data points in the train set: 34964, number of used features: 50
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.244652 -> initscore=-1.127344
# [LightGBM] [Info] Start training from score -1.127344

# %%
X_wrappered = X_rfe
display(X_wrappered.info(verbose=True, show_counts=True))
display(X_wrappered.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34964 entries, 0 to 34963
# Data columns (total 50 columns):
#  #   Column                                                                                 Non-Null Count  Dtype
# ---  ------                                                                                 --------------  -----
#  0   INTERACTION_contact_per_trans                                                          34964 non-null  float64
#  1   ENTROPY(comms.cat_c3)                                                                  34964 non-null  float64
#  2   MEAN(comms.contact_date_day_of_month_cos WHERE cat_c3 = 3)                             34964 non-null  float64
#  3   COUNT(comms WHERE cat_c4 = 2)                                                          34964 non-null  int64
#  4   ENTROPY(comms.cat_c5)                                                                  34964 non-null  float64
#  5   MEAN(comms.contact_date_day_of_month_sin WHERE cat_c4 = 2)                             34964 non-null  float64
#  6   MEAN(comms.contact_date_day_of_month_sin WHERE cat_c3 = 3)                             34964 non-null  float64
#  7   ENTROPY(comms.cat_c2)                                                                  34964 non-null  float64
#  8   PERCENT_TRUE(transactions.fl_c15)                                                      34964 non-null  float64
#  9   COUNT(comms WHERE cat_c3 = 3)                                                          34964 non-null  int64
#  10  BALANCE_savings_potential                                                              34964 non-null  float64
#  11  MEAN(transactions.float_c18)                                                           34964 non-null  float64
#  12  BALANCE_net_flow                                                                       34964 non-null  float64
#  13  MEAN(comms.contact_date_day_of_week_sin WHERE cat_c3 = 3)                              34964 non-null  float64
#  14  MEAN(activities.float_c12)                                                             34964 non-null  float64
#  15  SUM(transactions.int_c19 WHERE cat_c3 = 305)                                           34964 non-null  float64
#  16  ENTROPY(transactions.cat_c2)                                                           34964 non-null  float64
#  17  COUNT(transactions WHERE cat_c2 = 15)__30_days                                         34964 non-null  int64
#  18  COUNT(activities WHERE cat_c10 = True)                                                 34964 non-null  int64
#  19  MEAN(transactions.float_c18 WHERE fl_c13 = True)                                       34964 non-null  float64
#  20  contact_date_gap_days__autocorrelation__lag_1                                          34964 non-null  float64
#  21  PERCENT_TRUE(transactions.fl_c12)                                                      34964 non-null  float64
#  22  float_c18_diff__autocorrelation__lag_1                                                 34964 non-null  float64
#  23  MEAN(activities.activity_date_day_of_week_sin)__30_days                                34964 non-null  float64
#  24  KURTOSIS(activities.float_c14)                                                         34964 non-null  float64
#  25  float_c18_diff__skewness                                                               34964 non-null  float64
#  26  contact_date_gap_days__linear_trend__attr_"slope"                                      34964 non-null  float64
#  27  MEAN(transactions.tran_date_day_of_month_sin WHERE cat_c3 = 305)                       34964 non-null  float64
#  28  MEAN(activities.activity_date_day_of_month_sin WHERE cat_c10 = False)                  34964 non-null  float64
#  29  MEAN(transactions.int_c19 WHERE cat_c3 = 303)                                          34964 non-null  float64
#  30  STD(activities.float_c11)                                                              34964 non-null  float64
#  31  MEAN(comms.contact_date_day_of_week_sin WHERE cat_c4 = 2)                              34964 non-null  float64
#  32  contact_date_gap_days__skewness                                                        34964 non-null  float64
#  33  activity_date_gap_days__skewness                                                       34964 non-null  float64
#  34  MEAN(activities.activity_date_day_of_month_cos WHERE activity_date_is_weekend = True)  34964 non-null  float64
#  35  tran_date_gap_days__skewness                                                           34964 non-null  float64
#  36  MEAN(comms.contact_date_day_of_month_sin WHERE cat_c3 = 7)                             34964 non-null  float64
#  37  MEAN(transactions.float_c21 WHERE cat_c2 = 15)                                         34964 non-null  float64
#  38  PERCENT_TRUE(transactions.tran_date_is_weekend)                                        34964 non-null  float64
#  39  tran_date_gap_days__approximate_entropy__m_2__r_0.25                                   34964 non-null  float64
#  40  float_c18_diff__quantile__q_0.75                                                       34964 non-null  float64
#  41  MAX(activities.float_c11)                                                              34964 non-null  float64
#  42  STD(activities.float_c12 WHERE activity_date_is_weekend = True)                        34964 non-null  float64
#  43  MEAN(activities.activity_date_day_of_month_cos)__90_days                               34964 non-null  float64
#  44  MEAN(activities.activity_date_day_of_week_cos)                                         34964 non-null  float64
#  45  MEAN(activities.activity_date_day_of_week_cos WHERE activity_date_is_weekend = True)   34964 non-null  float64
#  46  SUM(transactions.float_c16)                                                            34964 non-null  float64
#  47  MEAN(transactions.tran_date_day_of_month_sin WHERE fl_c13 = True)                      34964 non-null  float64
#  48  MEAN(activities.activity_date_day_of_month_sin WHERE activity_date_is_weekend = True)  34964 non-null  float64
#  49  MEAN(transactions.int_c19)                                                             34964 non-null  float64
# dtypes: float64(46), int64(4)
# memory usage: 13.3 MB
# None
#        INTERACTION_contact_per_trans  ENTROPY(comms.cat_c3)  \
# count                          34964                  34964
# mean                               1                      0
# std                                1                      0
# min                                0                      0
# 25%                                1                      0
# 50%                                1                      0
# 75%                                1                      0
# max                               65                      1
#
#        MEAN(comms.contact_date_day_of_month_cos WHERE cat_c3 = 3)  \
# count                                              34964
# mean                                                   0
# std                                                    0
# min                                                    0
# 25%                                                    0
# 50%                                                    0
# 75%                                                    0
# max                                                    1
#
#        COUNT(comms WHERE cat_c4 = 2)  ENTROPY(comms.cat_c5)  \
# count                          34964                  34964
# mean                              42                      0
# std                               14                      0
# min                                0                      0
# 25%                               33                      0
# 50%                               42                      0
# 75%                               51                      0
# max                              362                      1
#
#        MEAN(comms.contact_date_day_of_month_sin WHERE cat_c4 = 2)  \
# count                                              34964
# mean                                                   0
# std                                                    0
# min                                                    0
# 25%                                                    0
# 50%                                                    0
# 75%                                                    0
# max                                                    0
#
#        MEAN(comms.contact_date_day_of_month_sin WHERE cat_c3 = 3)  \
# count                                              34964
# mean                                                   0
# std                                                    0
# min                                                    0
# 25%                                                    0
# 50%                                                    0
# 75%                                                    0
# max                                                    0
#
#        ENTROPY(comms.cat_c2)  PERCENT_TRUE(transactions.fl_c15)  \
# count                  34964                              34964
# mean                       2                                  0
# std                        0                                  0
# min                        0                                  0
# 25%                        2                                  0
# 50%                        2                                  0
# 75%                        2                                  0
# max                        4                                  0
#
#        COUNT(comms WHERE cat_c3 = 3)  ...  float_c18_diff__quantile__q_0.75  \
# count                          34964  ...                             34964
# mean                              13  ...                                27
# std                                5  ...                                58
# min                                0  ...                             -1097
# 25%                               10  ...                                 7
# 50%                               13  ...                                14
# 75%                               17  ...                                28
# max                              115  ...                              3228
#
#        MAX(activities.float_c11)  \
# count                      34964
# mean                          51
# std                           28
# min                            0
# 25%                           25
# 50%                           54
# 75%                           77
# max                           99
#
#        STD(activities.float_c12 WHERE activity_date_is_weekend = True)  \
# count                                              34964
# mean                                                  21
# std                                                    5
# min                                                    0
# 25%                                                   19
# 50%                                                   22
# 75%                                                   25
# max                                                   54
#
#        MEAN(activities.activity_date_day_of_month_cos)__90_days  \
# count                                              34964
# mean                                                   0
# std                                                    0
# min                                                    0
# 25%                                                    0
# 50%                                                    0
# 75%                                                    0
# max                                                    1
#
#        MEAN(activities.activity_date_day_of_week_cos)  \
# count                                           34964
# mean                                                0
# std                                                 0
# min                                                -1
# 25%                                                 0
# 50%                                                 0
# 75%                                                 0
# max                                                 1
#
#        MEAN(activities.activity_date_day_of_week_cos WHERE activity_date_is_weekend = True)  \
# count                                              34964
# mean                                                   0
# std                                                    0
# min                                                    0
# 25%                                                    0
# 50%                                                    0
# 75%                                                    0
# max                                                    1
#
#        SUM(transactions.float_c16)  \
# count                        34964
# mean                            13
# std                             28
# min                             -6
# 25%                              0
# 50%                              2
# 75%                             15
# max                           1185
#
#        MEAN(transactions.tran_date_day_of_month_sin WHERE fl_c13 = True)  \
# count                                              34964
# mean                                                   0
# std                                                    0
# min                                                    0
# 25%                                                    0
# 50%                                                    0
# 75%                                                    0
# max                                                    0
#
#        MEAN(activities.activity_date_day_of_month_sin WHERE activity_date_is_weekend = True)  \
# count                                              34964
# mean                                                   0
# std                                                    0
# min                                                    0
# 25%                                                    0
# 50%                                                    0
# 75%                                                    0
# max                                                    0
#
#        MEAN(transactions.int_c19)
# count                       34964
# mean                            0
# std                             0
# min                            -1
# 25%                             0
# 50%                             0
# 75%                             0
# max                             1
#
# [8 rows x 50 columns]

# %%
WRAPPERED_OUT_PATH = '../data/features_selected/features_v{}_wrappered_v{}.csv'.format(FEATURES_VERSION, SELECTION_VERSION)

pd.concat([X_wrappered, clients_data], axis=1).to_csv(WRAPPERED_OUT_PATH, index=False)
